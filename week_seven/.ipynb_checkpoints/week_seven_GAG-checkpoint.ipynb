# %% [markdown]
# # Processing real text (from out on the interwebs)
#
# ** Exercise: Just a couple of examples from the book: Work through the exercises NLPP1e 3.12: 6, 30. **

# %%
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ** 12. ○ Write a for loop to print out the characters of a string, one per line. **

# %%
mobydick_str = " ".join(text1[0:120])

# %%
mobydick_str
# Out:
# u'[ Moby Dick by Herman Melville 1851 ] ETYMOLOGY . ( Supplied by a Late Consumptive Usher to a Grammar School ) The pale Usher -- threadbare in coat , heart , body , and brain ; I see him now . He was ever dusting his old lexicons and grammars , with a queer handkerchief , mockingly embellished with all the gay flags of all the known nations of the world . He loved to dust his old grammars ; it somehow mildly reminded him of his mortality . " While you take in hand to school others , and to teach them by what name a whale - fish is to be called in our tongue leaving out'

# %% [markdown]
# ** 13. ○ What is the difference between calling split on a string with no argument and one with ' ' as the argument, e.g., sent.split() versus sent.split(' ')? What happens when the string being split contains tab characters, consecutive space characters, or a sequence of tabs and spaces? (In IDLE you will need to use '\t' to enter a tab character.) **
#
# .split(' ') only splits on " " but .split() splits on both tabs and spaces. You can clearly see the difference in the following example.

# %%
temp = "my mom is a good\nperson"

temp.split()
# Out:
# ['my', 'mom', 'is', 'a', 'good', 'person']

# %%
temp.split(' ')
# Out:
# ['my', 'mom', 'is', 'a', 'good\nperson']

# %% [markdown]
# **14. ○ Create a variable words containing a list of words. Experiment with words.sort() and sorted(words). What is the difference?**

# %%
words = text1[0:100]

# %%
print words.sort()
# Out:
# None

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6bfccf0866ff> in <module>()
# ----> 1 print sorted(word)
#
# NameError: name 'word' is not defined

# %% [markdown]
# **15. ○ Explore the difference between strings and integers by typing the following at a Python prompt: "3" * 7 and 3 * 7. Try converting between strings and integers using int("3") and str(3).**

# %%
"3" * 7

# %%
3*7

# %% [markdown]
# **16. ○ Earlier, we asked you to use a text editor to create a file called test.py, containing the single line monty = 'Monty Python'. If you haven’t already done this (or can’t find the file), go ahead and do it now. Next, start up a new session with the Python interpreter, and enter the expression monty at the prompt. You will get an error from the interpreter. Now, try the following (note that you have to leave off the .py part of the filename):**
#
#     -> from test import msg
#     -> msg
#
#
# **This time, Python should return with a value. You can also try import test, in which case Python should be able to evaluate the expression test.monty at the prompt.**
#
#
# NENNI ÞESSU EKKI. OF LÉTT

# %% [markdown]
# **30. ◑ Use the Porter Stemmer to normalize some tokenized text, calling the stemmer on each word. Do the same thing with the Lancaster Stemmer, and see if you ob- serve any differences.**

# %%
porter  = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()

text1_porter = [porter.stem(word) for word in text1]
text1_lancaster = [lancaster.stem(word) for word in text1]

# %%
text1_porter

# %%
text1_lancasterporter  = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()
​
text1_porter = [porter.stem(word) for word in text1]
text1_lancaster = [lancaster.stem(word) for word in text1]
In [ ]:

text1_porter
text1_porter
In [ ]:

text1_lancaster
text1_lancaster

# %% [markdown]
# # Words that characterize the branches
#
# In the exercise we'll use a very simple weighting scheme called TF-IDF to find the important words within each branch of philosophy (according to wikipedia).
#
# **First**, check out the wikipedia page for [TF-IDF](https://en.wikipedia.org/wiki/Tf%E2%80%93idf). Explain in your own words the point of TF-IDF.
#     - What does TF stand for?
#     - What does IDF stand for?
#
# **Point of tf-idf** is to evaluate numerically how important a word is to a document in a collection or corpus. The ft-df value increases proportionally to the number of times a word appears in the document, but is often offset by the frequency of the word in the corpus, which helps to adjust for the fact that some words appear more frequently in general.
#
# tf-idf is the product of two statistics, term frequency and inverse document frequency. Note that there are various ways for determining the exect values of both statistics.
#
# **Term frequency** tf(t,d), the simplest choice is to use the raw count of a term in a document, i.e. the number of times that term t occurs in document d. There are some other possibilities to evaluate the term frequency which can be found in the wikipedia page.
#
# ** Inverse document frequency** is a measure of how much information the word provides, that is, whether the term is common or rare accross all documents. It is the logarithmically scaled inverse fraction of the documents that contain the word, obtained by dividing the total number of documents by number of documents containing the term, and then taking the logarithm of that quotient. See [wikipage](https://en.wikipedia.org/wiki/Tf%E2%80%93idf) for detail about equaltion

# %% [markdown]
# **Since we want to find out which words are important for each branch, so we're going to create six large documents, one per branch of philosophy. Tokenize the pages, and combine the tokens into one long list per branch. Remember the bullets below for success**

# %% [markdown]
# **1.** We start by getting the philosophers name and maintain the information about each philosopher in a dictionary

# %%
import urllib2
import re

philosophers = {
    "aestheticians":{
        "title":"title=List_of_aestheticians",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    },
    "epistemologists":{
        "title":"title=List_of_epistemologists",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    },
    "ethicists":{
        "title":"title=List_of_ethicists",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    },
    "logicians":{
        "title":"title=List_of_logicians",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    },
    "metaphysicians":{
        "title":"title=List_of_metaphysicians",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    },
    "social and political philosophers":{
        "title":"title=Index_of_sociopolitical_thinkers",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    }
}

#'https://en.wikipedia.org/w/index.php?title=List_of_aestheticians&action=edit'

# set the parameters (explained in detail here https://www.mediawiki.org/wiki/API:Tutorial)
baseurl = "https://en.wikipedia.org/w/index.php?"
title = ""
action = "action=edit"

for i in philosophers:
    # construct the query
    query = "{}{}&{}".format(
    baseurl,
    philosophers[i]["title"],
    action)
    # use urllib and regex to get the list of philosophers
    wikiresponse = urllib2.urlopen(query)
    wikisource = wikiresponse.read()
    philosophers[i]["names"] = re.findall(r'\*.*?\[\[(.*?)[\]\|]', wikisource)

# Because the last 4 elements of the ethicists list and social and political philosophers are not philosophers
# they are left out
philosophers["ethicists"]["names"] = philosophers["ethicists"]["names"][:-4]
philosophers["social and political philosophers"]["names"] = philosophers["social and political philosophers"]["names"][:-4]

# Get all philosophers into one list
all_philo = []
for i in philosophers:
    all_philo = all_philo + philosophers[i]["names"]
all_philo = set(all_philo) # erase all duplicates

# %% [markdown]
# **2.** Next we go through all of the philosophers in each branch and we create a large document for each brand. Therefore we end up with six large documents that contain all the text of each brands philosopher´s wikipedia pages. The workflow is as follows:
#     - Tokenize the pages
#     - combine the tokens into a long list per branch

# %%
import json
import io
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords


run = False

if run :
    # set the parameters for the query (explained in detail here https://www.mediawiki.org/wiki/API:Tutorial)
    baseurl = "https://en.wikipedia.org/w/api.php?"
    actions = "action=query"
    title = "titles="
    #content = "prop=revisions&rvprop=content"
    content = "prop=extracts&exlimit=max&explaintext&rvprop=content"
    dataformat = "format=json"


    # iterate through the philosophers and for each philosphers download his wikipedia page
    # The list comprehension goes through the list of philosophers and replaces " " for "_"
    for philo in [name.replace(" ","_") for name in set(all_philo)]:
        query = "{}{}&{}{}&{}&{}".format(baseurl,actions,title,philo.replace(" ","_"),content,dataformat)
        print query
        wikiresponse = urllib2.urlopen(query)
        wikisource = json.loads(wikiresponse.read())

        # Create the uri for the file in the os file system
        fileUri = "/Users/GretarAtli/Dropbox/Dtu/Social_graphs_and_interactions/Philosophers_text/{}.txt".format(philo)
        #print fileUri
        f = io.open(fileUri, 'w', encoding='utf-8')
        f.write(unicode(json.dumps(wikisource)))

# %%
import json
import io
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

baseurl = "https://en.wikipedia.org/w/api.php?"
actions = "action=query"
title = "titles="
#content = "prop=revisions&rvprop=content"
content = "prop=extracts&exlimit=max&explaintext&rvprop=content"
dataformat = "format=json"


# iterate through each philosophers brand
# The list comprehension goes through the list of philosophers and replaces " " for "_"
for brand in philosophers:
    for philosopher in philosophers[brand]["names"]:
        #-------- CODE TO GET TEXT DIRECTLY FROM URL ----------
        #query = "{}{}&{}{}&{}&{}".format(baseurl,actions,title,philosopher.replace(" ","_"),content,dataformat)
        #print query
        
        # Get the page data in json format
        #wikiresponse = urllib2.urlopen(query)
        #wikisource = json.loads(wikiresponse.read())
        
        #--------- CODE TO GET TEXT FROM FILE ----------
        # Create the uri for the file in the os file system
        fileUri = "/Users/GretarAtli/Dropbox/Dtu/Social_graphs_and_interactions/Philosophers_text/{}.txt".format(philosopher.replace(" ","_"))

        # Open the file and get the content 
        print philosopher
        file = open(fileUri,'r') 
    
        try:
            # Drill down the json to get only the text of each page
            wikisource = json.loads(file.read())
            text = wikisource["query"]["pages"].values()[0]['extract'].lower().encode("utf-8")
             
        except BaseException:
            print "{} has an empty wikipedia page".format(philosopher)
            continue
        
        # We start by excluding the philosopher names from the text
        for philo in all_philo:
            text = text.replace(philo.lower(),"")

        # Next we clean the data by removing all \n \\n and \\u from the text.
        text = re.sub(r"\n+"," ",text)
        text = re.sub(r"\\n+"," ",text)
        text = re.sub(r"\\u+"," ",text)

        tokenizer = RegexpTokenizer(r'\w+')  # We choose to use regularexpression tokenizer
        tokens = tokenizer.tokenize(text) # Get all tokens with the tokenizer
        # filter out the stop words and digits
        filtered_words = [w for w in tokens if not w in stopwords.words('english') if not w.isdigit()] 

        # Get unique set of the words
        filtered_words =  set(filtered_words)

        # Add the tokens from this specific wikipage to the dictionary
        philosophers[brand]["tokens"] = philosophers[brand]["tokens"] + list(filtered_words)
# Out:
# Abraham Joshua Heschel
# /Users/GretarAtli/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:55: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
# Abul Kalam Azad
# Adam Müller
# Adolf Hitler
# Adrian Johnston (philosopher)
# Alan Carter (philosopher)
# Alan Ryan
# Alastair Norcross
# Alexander of Aphrodisias
# Alexis de Tocqueville
# Alfred Rosenberg
# Al-Ghazali
# Ali Shariati
# Alon Ben-Meir
# Andrei Marga
# António Castanheira Neves
# Antonio Negri
# Aristotle
# Armin Mohler
# Arthur Linton Corbin
# Arthur Moeller van den Bruck
# Auberon Herbert
# Averroes
# Axel Honneth
# Ayn Rand
# Benjamin Tucker
# Bertrand de Jouvenel
# Bertrand Russell
# B. R. Ambedkar
# Boris Furlan
# Bruce Lee
# Bruno Leoni
# Bryan Caplan
# Carl Joachim Friedrich
# Carl Schmitt
# Carlo Lottieri
# Chanakya
# Charles C. Ragin
# Charles Taylor (philosopher)
# C. Wright Mills
# Cheng Hao
# Cheng Yi (philosopher)
# Cicero
# Claude Lefort
# Claude Lévi-Strauss
# Claudio Canaparo
# Confucius
# Constantin Rădulescu-Motru
# Cornel West
# Cornelius Castoriadis
# Costas Douzinas
# Dana Ward
# Daniel Guérin
# David D. Friedman
# David Hume
# David Kolb
# David Miller (political theorist)
# David Prychitko
# Democritus
# Dimitris Dimitrakos
# Disciples of Confucius
# Dong Zhongshu
# Duncan Kennedy (legal philosopher)
# Edmund Burke
# Edward Burnett Tylor
# Edward Said
# Emma Goldman
# Enrique Dussel
# Eric Voegelin
# Ernest Wamba dia Wamba
# Ernst Bloch
# Étienne de La Boétie
# Eugen Rosenstock-Huessy
# Félix Guattari
# Felix Kaufmann
# Ferdinand de Saussure
# Francesco D'Andrea
# Francis Bacon
# Francis Fukuyama
# Francis Parker Yockey
# Frank Meyer (political philosopher)
# Franz Boas
# Frédéric Bastiat
# Fred Poché
# Friedrich Engels
# Friedrich Hayek
# Friedrich Schleiermacher
# Fujiwara Seika
# Gary Chartier
# Gene Callahan (economist)
# Gene Callahan (economist) has an empty wikipedia page
# Georg Jellinek
# Georg Wilhelm Friedrich Hegel
# George Kateb
# George Ohsawa
# Georges Bataille
# Gerald Cohen
# Gerald Dworkin
# Gerrard Winstanley
# Giacomo Marramao
# Giambattista Vico
# Gianfranco Sanguinetti
# Giannina Braschi
# Giorgio Agamben
# Giorgio Del Vecchio
# Gottfried Leibniz
# Gustave de Molinari
# Guy Aldred
# Guy Debord
# H. B. Acton
# H. L. A. Hart
# Han Fei
# Han Ryner
# Hannah Arendt
# Hans Achterhuis
# Hans-Hermann Hoppe
# Hans Kelsen
# Hans Köchler
# Hans Singer
# Har Dayal
# Harriet Martineau
# Harriet Taylor Mill
# Hayashi Razan
# Hendrik Verwoerd
# Henri Lefebvre
# Henry David Thoreau
# Henry George
# Henry Home, Lord Kames
# Henry Pachter
# Henry Sidgwick
# Herbert Spencer
# Herman Oliphant
# Hirata Atsutane
# Horace Romano Harré
# Houston Stewart Chamberlain
# Howard Zinn
# Hugo Grotius
# Igor Pribac
# Immanuel Kant
# Inayatullah Khan Mashriqi
# Iris Marion Young
# Isabel Paterson
# Isaiah Berlin
# Israr Ahmed
# Itō Jinsai
# Ivan Sviták
# J. J. C. Smart
# Jacques Lacan
# Jacques Rancière
# Jack Russell Weinstein
# James Brusseau
# James Tully (philosopher)
# Jamie Whyte
# Janet Biehl
# Janet Coleman
# Jawaharlal Nehru
# Jean Bodin
# Jean-François Lyotard
# Jean-Jacques Rousseau
# Jeffrey Friedman (political scientist)
# Jeremy Bentham
# John Austin (legal philosopher)
# John Burnheim
# John Finnis
# John Hospers
# John Locke
# John Oswald (activist)
# John Rawls
# John Searle
# John Stuart Mill
# John William Miller
# John Zerzan
# Jonathan Wolff (philosopher)
# Joseph de Torre
# Joseph Priestley
# Joseph Raz
# Joshua Cohen (philosopher)
# Joxe Azurmendi
# Judith Butler
# Julian Gumperz
# Julien Offray de La Mettrie
# Julius Binder
# Jürgen Habermas
# Kaibara Ekken
# Karl Loewenstein
# Karl Marx
# Karl Popper
# Karl-Otto Apel
# Kevin Carson

# %% [markdown]
# ** Now, we're ready to calculate the TF for each word. Use the method of your choice to find the top 5 terms within each branch. **
#     - Describe similarities and differences between the branches.
#     - Why aren't the TFs not necessarily a good description of the branches?

# %%
philosophers.keys()

# %%
import operator

for branch in philosophers.keys():
    philosophers[branch]["tf"] = sorted(FreqDist(philosophers[branch]["tokens"]).items(),
                                           key=operator.itemgetter(1),
                                            reverse=True)
    # Print out the top 5 terms 
    print "{} : ".format(branch)
    print philosophers[branch]["tf"][:5]
    print ""
# Out:
# social and political philosophers :
# [('also', 576), ('external', 574), ('links', 572), ('university', 570), ('references', 564)]
#
# aestheticians :
# [('university', 208), ('work', 198), ('also', 196), ('\xe2', 196), ('external', 190)]
#
# logicians :
# [('university', 480), ('references', 456), ('logic', 452), ('links', 440), ('external', 440)]
#
# epistemologists :
# [('also', 178), ('university', 174), ('sophy', 168), ('external', 168), ('links', 166)]
#
# metaphysicians :
# [('sophy', 178), ('university', 176), ('also', 170), ('sopher', 164), ('external', 162)]
#
# ethicists :
# [('university', 462), ('links', 456), ('external', 456), ('references', 444), ('also', 440)]

# %% [markdown]
# ** Next, we calculate IDF for every word. **
#     - What base logarithm did you use? Is that important?

# %%
from collections import Counter
import numpy as np
from __future__ import division

# we first create a array of all words
all_tokens = []
tokens_sum = 0
N = len(philosophers.keys()) # The number of branches

for branch in philosophers.keys():
    all_tokens = all_tokens + philosophers[branch]["tokens"]
    tokens_sum += len(philosophers[branch]["tokens"])
    
# Then count the freq of each word
all_tokens_counted = Counter(all_tokens)
idf = []

for token, freq in all_tokens_counted.items():
    idf.append(
        (
            token,
            np.log10(N/freq)
        )
    )

# %%
idf
# Out:
# [('belligerence', 0.0),
#  ('schlegel', -0.66900678095857558),
#  ('foucaultiani', 0.17609125905568124),
#  ('d\xc3\xbctas', 0.47712125471966244),
#  ('sophengalerie', 0.47712125471966244),
#  ('sowell', 0.47712125471966244),
#  ('sonja', -0.22184874961635639),
#  ('ungel\xc3', 0.47712125471966244),
#  ('epimeteo', 0.47712125471966244),
#  ('woods', -0.77815125038364363),
#  ('vertrauensschutz', 0.47712125471966244),
#  ('pantheistic', -0.47712125471966244),
#  ('phenomenologist', -0.47712125471966244),
#  ('hanging', -0.63682209758717434),
#  ('impermanence', 0.47712125471966244),
#  ('francesca', -0.3010299956639812),
#  ('trawling', 0.47712125471966244),
#  ('pawe\xc5', 0.47712125471966244),
#  ('comically', -0.12493873660829995),
#  ('localized', 0.47712125471966244),
#  ('nordisk', 0.47712125471966244),
#  ('regularize', 0.17609125905568124),
#  ('disobeying', -0.42596873227228116),
#  ('saylor', 0.47712125471966244),
#  ('yanagisawa', 0.47712125471966244),
#  ('ministration', 0.47712125471966244),
#  ('mathison', 0.17609125905568124),
#  ('sprague', 0.47712125471966244),
#  ('caney', 0.47712125471966244),
#  ('reasons\xe2', 0.17609125905568124),
#  ('logices', 0.47712125471966244),
#  ('synderinden', 0.0),
#  ('originality', -1.0142404391146103),
#  ('error\xe2', 0.17609125905568124),
#  ('caned', -0.12493873660829995),
#  ('unnecessarily', -0.22184874961635639),
#  ('alphabetic', 0.47712125471966244),
#  ('hermann', -1.4722687519252504),
#  ('patriarchy', -0.3010299956639812),
#  ('paternalists', 0.47712125471966244),
#  ('hollerbach', 0.47712125471966244),
#  ('liberismo', 0.47712125471966244),
#  ('dra\xc5\xbea', 0.47712125471966244),
#  ('27\xe2', -0.75332766665861151),
#  ('bendau', 0.47712125471966244),
#  ('wracked', 0.17609125905568124),
#  ('bragia', 0.47712125471966244),
#  ('wolzogen', 0.17609125905568124),
#  ('schlegelschen', 0.47712125471966244),
#  ('yogas', 0.47712125471966244),
#  ('eugenics', -0.47712125471966244),
#  ('sauvagnargues', 0.47712125471966244),
#  ('appropriation', -0.75332766665861151),
#  ('transvestism', 0.47712125471966244),
#  ('taj', 0.47712125471966244),
#  ('unipress', 0.47712125471966244),
#  ('politician', -1.3082085802911045),
#  ('bringing', -1.414973347970818),
#  ('rabinovitch', 0.47712125471966244),
#  ('higman', 0.47712125471966244),
#  ('marxismo', 0.47712125471966244),
#  ('wooded', 0.47712125471966244),
#  ('sperryville', 0.47712125471966244),
#  ('liaisons', -0.42596873227228116),
#  ('metamatemathics', 0.47712125471966244),
#  ('nature\xe2', -0.6020599913279624),
#  ('broiles', 0.47712125471966244),
#  ('wooden', -0.52287874528033762),
#  ('physiologique', 0.47712125471966244),
#  ('1725\xe2', 0.17609125905568124),
#  ('orixe', 0.17609125905568124),
#  ('entwickelung', 0.17609125905568124),
#  ('hsu', 0.47712125471966244),
#  ('rauno', 0.47712125471966244),
#  ('induktion', 0.47712125471966244),
#  ('multital\xe2', 0.47712125471966244),
#  ('elgar', -0.42596873227228116),
#  ('stereotypical', 0.47712125471966244),
#  ('busybody', 0.17609125905568124),
#  ('immunities', -0.12493873660829995),
#  ('braakhuis', 0.47712125471966244),
#  ('nadaud', 0.47712125471966244),
#  ('fuera', 0.0),
#  ('bochur', 0.47712125471966244),
#  ('thrace', -0.22184874961635639),
#  ('kublai', 0.17609125905568124),
#  ('drachmann', 0.47712125471966244),
#  ('aldizkaria', 0.17609125905568124),
#  ('radulescu', 0.17609125905568124),
#  ('punning', 0.0),
#  ('precocity', 0.17609125905568124),
#  ('wissensch', 0.47712125471966244),
#  ('axiomatize', 0.17609125905568124),
#  ('feasibility', -0.12493873660829995),
#  ('bannister', 0.47712125471966244),
#  ('hadow', 0.47712125471966244),
#  ('gorman', -0.12493873660829995),
#  ('sustaining', -0.63682209758717434),
#  ('consenting', -0.42596873227228116),
#  ('washerman', 0.17609125905568124),
#  ('scraped', 0.47712125471966244),
#  ('targa', 0.47712125471966244),
#  ('prosody', 0.0),
#  ('inanimate', -0.77815125038364363),
#  ('uality', -0.3010299956639812),
#  ('minns', 0.47712125471966244),
#  ('jesociety', 0.47712125471966244),
#  ('errors', -1.3489535479811641),
#  ('dialogs', 0.47712125471966244),
#  ('aphoristically', 0.17609125905568124),
#  ('tiered', 0.17609125905568124),
#  ('reeling', 0.47712125471966244),
#  ('cooking', -0.12493873660829995),
#  ('welfarism', 0.0),
#  ('disunion', 0.17609125905568124),
#  ('yaakov', -0.12493873660829995),
#  ('usener', 0.17609125905568124),
#  ('vassals', 0.0),
#  ('designing', -0.75332766665861151),
#  ('dialogo', 0.0),
#  ('bochum', 0.17609125905568124),
#  ('pharisees', 0.17609125905568124),
#  ('succumb', 0.47712125471966244),
#  ('xive', 0.0),
#  ('shocks', -0.12493873660829995),
#  ('evolutionism', -0.42596873227228116),
#  ('1997b', 0.47712125471966244),
#  ('tambi\xc3', 0.47712125471966244),
#  ('m\xc3\xbcntzer', 0.17609125905568124),
#  ('machtkampf', 0.47712125471966244),
#  ('jubilantly', 0.47712125471966244),
#  ('proctorship', 0.47712125471966244),
#  ('pourparlers', 0.47712125471966244),
#  ('affiliates', 0.47712125471966244),
#  ('alpena', 0.47712125471966244),
#  ('chine', 0.17609125905568124),
#  ('ching', -0.36797678529459443),
#  ('mutinied', 0.17609125905568124),
#  ('china', -1.5006023505691852),
#  ('herbrand', 0.0),
#  ('affiliated', -1.0413926851582249),
#  ('offence\xe2', 0.47712125471966244),
#  ('armack', 0.17609125905568124),
#  ('chini', 0.47712125471966244),
#  ('anonym', 0.47712125471966244),
#  ('1670s', 0.47712125471966244),
#  ('finkel', 0.47712125471966244),
#  ('natured', 0.0),
#  ('tensed', 0.17609125905568124),
#  ('kids', -0.36797678529459443),
#  ('ansgar', 0.47712125471966244),
#  ('uplifting', -0.12493873660829995),
#  ('naturel', 0.47712125471966244),
#  ('slaveholders', 0.0),
#  ('deferring', 0.47712125471966244),
#  ('controversy', -1.7507654498940111),
#  ('muirhead', 0.17609125905568124),
#  ('kidd', -0.12493873660829995),
#  ('kide', 0.17609125905568124),
#  ('natures', -0.66900678095857558),
#  ('neurologist', -0.12493873660829995),
#  ('seaver', 0.47712125471966244),
#  ('1939\xe2', -0.52287874528033762),
#  ('gottlob', -0.52287874528033762),
#  ('kido', 0.47712125471966244),
#  ('inextended', 0.47712125471966244),
#  ('golden', -1.3802112417116061),
#  ('stamatu', 0.47712125471966244),
#  ('projection', -0.95424250943932487),
#  ('engi', 0.47712125471966244),
#  ('panslavic', 0.47712125471966244),
#  ('wikimedia', -0.9852767431792937),
#  ('dorrien', 0.47712125471966244),
#  ('diametrically', 0.17609125905568124),
#  ('s\xc3\xbcje', 0.47712125471966244),
#  ('117\xe2', -0.47712125471966244),
#  ('stern', -1.1026623418971477),
#  ('battista', -0.42596873227228116),
#  ('samskrutige', 0.17609125905568124),
#  ('agassi', 0.0),
#  ('prescriptivity', 0.47712125471966244),
#  ('dna', -0.75332766665861151),
#  ('ratzingerfanclub', 0.47712125471966244),
#  ('constitutio', 0.47712125471966244),
#  ('insecurity', -0.12493873660829995),
#  ('bindreiter', 0.47712125471966244),
#  ('century', -2.2679535368623949),
#  ('grahame', 0.17609125905568124),
#  ('andratx', 0.47712125471966244),
#  ('cannibal', 0.47712125471966244),
#  ('galil\xc3', -0.52287874528033762),
#  ('definiteness', 0.17609125905568124),
#  ('lacuscurtius', 0.17609125905568124),
#  ('music', -1.787696568289874),
#  ('therefore', -2.0086001717619175),
#  ('distortions', -0.3010299956639812),
#  ('reasserting', 0.17609125905568124),
#  ('musik', -0.36797678529459443),
#  ('kottam', 0.17609125905568124),
#  ('liberative', 0.47712125471966244),
#  ('benedikt', 0.17609125905568124),
#  ('matmos', 0.47712125471966244),
#  ('adventism', 0.47712125471966244),
#  ('populations', -0.66900678095857558),
#  ('chirkov', 0.47712125471966244),
#  ('yahoo', 0.17609125905568124),
#  ('f\xc3\xbchrertum', 0.47712125471966244),
#  ('rickman', -0.12493873660829995),
#  ('milestones', -0.12493873660829995),
#  ('expeditionary', 0.17609125905568124),
#  ('tomes', 0.0),
#  ('serially', 0.0),
#  ('primeval', -0.63682209758717434),
#  ('circumstances', -1.6931404606752949),
#  ('hezekiah', 0.47712125471966244),
#  ('briansk', 0.47712125471966244),
#  ('intake', 0.47712125471966244),
#  ('morally', -1.4366925976640543),
#  ('locked', -0.66900678095857558),
#  ('arndt', 0.17609125905568124),
#  ('commentaire', 0.17609125905568124),
#  ('semanov', 0.47712125471966244),
#  ('matanot', 0.47712125471966244),
#  ('meadows', 0.17609125905568124),
#  ('karanth', 0.17609125905568124),
#  ('sed\xc5', 0.47712125471966244),
#  ('gershom', -0.47712125471966244),
#  ('busyness', 0.0),
#  ('gershon', 0.17609125905568124),
#  ('chapters\xe2', 0.47712125471966244),
#  ('radicalisation', 0.47712125471966244),
#  ('akenson', 0.47712125471966244),
#  ('contemporaines', 0.0),
#  ('ofte', 0.17609125905568124),
#  ('phane', -0.47712125471966244),
#  ('bajjah', 0.47712125471966244),
#  ('cadernos', 0.47712125471966244),
#  ('irrationalist', 0.17609125905568124),
#  ('wang', -0.86530142610254379),
#  ('wand', 0.17609125905568124),
#  ('wane', -0.42596873227228116),
#  ('brague', 0.47712125471966244),
#  ('unjust', -1.2388820889151366),
#  ('kaprow', 0.17609125905568124),
#  ('lindemann', 0.17609125905568124),
#  ('individuationsproblems', 0.47712125471966244),
#  ('munzer', 0.47712125471966244),
#  ('paaas', 0.47712125471966244),
#  ('disparagement', -0.12493873660829995),
#  ('kingdoms', -0.66900678095857558),
#  ('want', -1.587336734507256),
#  ('contextes', 0.47712125471966244),
#  ('carew', 0.0),
#  ('pinto', -0.22184874961635639),
#  ('irrationalism', -0.22184874961635639),
#  ('absolute', -1.7507654498940111),
#  ('183\xe2', -0.12493873660829995),
#  ('zvezi', 0.47712125471966244),
#  ('njami\xcb', 0.17609125905568124),
#  ('tchaikovsky', -0.3010299956639812),
#  ('beyer', 0.0),
#  ('travel', -1.4259687322722812),
#  ('graham\xe2', 0.47712125471966244),
#  ('clews', 0.0),
#  ('satygraha', 0.17609125905568124),
#  ('fructu', 0.47712125471966244),
#  ('\xd0\xb9\xd1', 0.47712125471966244),
#  ('vaishnav', 0.47712125471966244),
#  ('cadence', -0.47712125471966244),
#  ('musicien', 0.47712125471966244),
#  ('alekos', 0.47712125471966244),
#  ('barbra', 0.47712125471966244),
#  ('pietas', 0.17609125905568124),
#  ('excessu', 0.47712125471966244),
#  ('exposited', -0.3010299956639812),
#  ('calde', 0.47712125471966244),
#  ('assimilated', -0.82390874094431876),
#  ('castelvecchi', 0.47712125471966244),
#  ('apocrypha', 0.0),
#  ('dinosaurs', 0.47712125471966244),
#  ('modest', -1.2218487496163564),
#  ('papazisis', 0.47712125471966244),
#  ('\xd6', -0.3010299956639812),
#  ('untreated', 0.0),
#  ('mallet', 0.47712125471966244),
#  ('1670\xe2', 0.47712125471966244),
#  ('souci', 0.17609125905568124),
#  ('opted', -0.42596873227228116),
#  ('locke\xe2', 0.17609125905568124),
#  ('chandos', 0.0),
#  ('ritables', 0.47712125471966244),
#  ('mellifluous', 0.47712125471966244),
#  ('recombination', 0.0),
#  ('amaya', 0.47712125471966244),
#  ('verschiedenen', -0.22184874961635639),
#  ('tulip', 0.47712125471966244),
#  ('unprovability', 0.17609125905568124),
#  ('18th', -1.4366925976640543),
#  ('mansley', 0.47712125471966244),
#  ('machamer', 0.47712125471966244),
#  ('concoction', 0.17609125905568124),
#  ('arranges', -0.22184874961635639),
#  ('nonsensical', -0.42596873227228116),
#  ('bouvery', 0.47712125471966244),
#  ('reinert', 0.17609125905568124),
#  ('potts', 0.47712125471966244),
#  ('kuen', 0.17609125905568124),
#  ('khallal', 0.47712125471966244),
#  ('libertie', 0.0),
#  ('welcomed', -0.93785209325115548),
#  ('gateavisa', 0.47712125471966244),
#  ('incamination', 0.47712125471966244),
#  ('patricide', 0.0),
#  ('stoicism', -0.82390874094431876),
#  ('peut', 0.47712125471966244),
#  ('robberts', 0.47712125471966244),
#  ('partnered', 0.47712125471966244),
#  ('malby', 0.47712125471966244),
#  ('haaggadot', 0.47712125471966244),
#  ('incoherences', 0.47712125471966244),
#  ('rewarded', -0.77815125038364363),
#  ('sentry', 0.47712125471966244),
#  ('374\xe2', 0.17609125905568124),
#  ('burleigh', 0.0),
#  ('guyau\xc2', 0.17609125905568124),
#  ('g\xc3\xaanes', 0.47712125471966244),
#  ('tailings', 0.47712125471966244),
#  ('fit', -1.4259687322722812),
#  ('fiu', 0.47712125471966244),
#  ('fractal', -0.3010299956639812),
#  ('fix', -0.75332766665861151),
#  ('striking', -1.2388820889151366),
#  ('townshend', 0.47712125471966244),
#  ('naturality', 0.47712125471966244),
#  ('calhoun', 0.47712125471966244),
#  ('waley', 0.0),
#  ('unire', 0.47712125471966244),
#  ('fig', 0.17609125905568124),
#  ('undecidability', -0.66900678095857558),
#  ('wales', -1.0669467896306133),
#  ('menachem', 0.17609125905568124),
#  ('influentially', -0.47712125471966244),
#  ('fin', -0.56427143043856265),
#  ('bankrupts', 0.47712125471966244),
#  ('fil', 0.47712125471966244),
#  ('fim', 0.47712125471966244),
#  ('39\xe2', -0.63682209758717434),
#  ('zucker', 0.47712125471966244),
#  ('beilharz', 0.47712125471966244),
#  ('tomin', 0.47712125471966244),
#  ('paterfamilias', 0.47712125471966244),
#  ('spray', 0.47712125471966244),
#  ('municipality', 0.47712125471966244),
#  ('worringer', 0.17609125905568124),
#  ('abdu', 0.47712125471966244),
#  ('jenkins\xe2', 0.47712125471966244),
#  ('basics', -0.6020599913279624),
#  ('maslansky', 0.47712125471966244),
#  ('effects', -1.7297046213121872),
#  ('adroitness', 0.47712125471966244),
#  ('verhaeren', 0.47712125471966244),
#  ('touchant', 0.17609125905568124),
#  ('sova', 0.47712125471966244),
#  ('multidimensional', 0.0),
#  ('sixteen', -1.0543576623225928),
#  ('undeveloped', -0.36797678529459443),
#  ('multiverses', 0.47712125471966244),
#  ('saddened', 0.17609125905568124),
#  ('2001b', 0.47712125471966244),
#  ('hospitalier', 0.0),
#  ('giusti', 0.17609125905568124),
#  ('giusto', 0.47712125471966244),
#  ('viaticum', 0.47712125471966244),
#  ('protosemiotic', 0.47712125471966244),
#  ('phenotype', 0.17609125905568124),
#  ('giusta', 0.47712125471966244),
#  ('barton', -0.22184874961635639),
#  ('telekom', 0.47712125471966244),
#  ('disconnection', 0.47712125471966244),
#  ('s\xc3\xbcnde', 0.47712125471966244),
#  ('pornographer', 0.47712125471966244),
#  ('flp033', 0.47712125471966244),
#  ('arrow', -0.69897000433601875),
#  ('ingrid', -0.12493873660829995),
#  ('klinger', 0.0),
#  ('flavour', -0.12493873660829995),
#  ('gunston', 0.47712125471966244),
#  ('antimilitarists', 0.17609125905568124),
#  ('burial', -1.0669467896306133),
#  ('revelatory', -0.12493873660829995),
#  ('udayan\xc4', 0.47712125471966244),
#  ('telescope', -0.42596873227228116),
#  ('canoeist', 0.47712125471966244),
#  ('tantalisingly', 0.47712125471966244),
#  ('zaher', 0.47712125471966244),
#  ('representable', 0.0),
#  ('allah', -0.22184874961635639),
#  ('allan', -1.0543576623225928),
#  ('phoenicians', 0.0),
#  ('wednesday', -0.12493873660829995),
#  ('olscamp', 0.0),
#  ('currencies', 0.0),
#  ('klostermann', 0.0),
#  ('internalism', -0.36797678529459443),
#  ('sosman', 0.47712125471966244),
#  ('allay', 0.47712125471966244),
#  ('hijacked', 0.17609125905568124),
#  ('stabilised', 0.47712125471966244),
#  ('toleration', -0.9852767431792937),
#  ('callicrates', 0.47712125471966244),
#  ('thoukyd\xc3', 0.47712125471966244),
#  ('cinel', 0.47712125471966244),
#  ('naturkausalit\xc3', 0.17609125905568124),
#  ('mannerheim', 0.47712125471966244),
#  ('oprah', 0.47712125471966244),
#  ('cologies', 0.47712125471966244),
#  ('indiscretion', -0.12493873660829995),
#  ('brutish', -0.36797678529459443),
#  ('gradation', -0.36797678529459443),
#  ('mason', -0.90308998699194354),
#  ('toute', 0.47712125471966244),
#  ('lnahma', 0.47712125471966244),
#  ('encourage', -1.2304489213782739),
#  ('branch', -1.5006023505691852),
#  ('adapt', -0.92081875395237522),
#  ('esoterics', 0.47712125471966244),
#  ('noica', 0.47712125471966244),
#  ('gomarists', 0.17609125905568124),
#  ('perturbed', 0.0),
#  ('adamsmith', 0.47712125471966244),
#  ('\xd8\xb3\xd8\xaa\xe2', 0.47712125471966244),
#  ('smithfield', 0.47712125471966244),
#  ('outburst', 0.47712125471966244),
#  ('misrepresentations', 0.0),
#  ('einordnung', 0.47712125471966244),
#  ('abbott', -0.47712125471966244),
#  ('correcte', 0.47712125471966244),
#  ('effect\xe2', -0.22184874961635639),
#  ('imamichi', 0.17609125905568124),
#  ('underfoot', 0.17609125905568124),
#  ('strata', 0.17609125905568124),
#  ('wenberg', 0.47712125471966244),
#  ('timorese', 0.17609125905568124),
#  ('allmusic', 0.47712125471966244),
#  ('cranfield', 0.47712125471966244),
#  ('reisel', -0.12493873660829995),
#  ('estimate', -0.93785209325115548),
#  ('preunderstanding', 0.47712125471966244),
#  ('universally', -1.2632414347745815),
#  ('leela', 0.17609125905568124),
#  ('strawson', -0.86530142610254379),
#  ('nevinson', 0.17609125905568124),
#  ('petschenig', 0.47712125471966244),
#  ('steadfastness', 0.47712125471966244),
#  ('rutenberg', 0.17609125905568124),
#  ('dortigen', 0.47712125471966244),
#  ('chiara', 0.47712125471966244),
#  ('connive', 0.47712125471966244),
#  ('metafizic\xc4', 0.17609125905568124),
#  ('periodization', 0.17609125905568124),
#  ('ministries', -0.36797678529459443),
#  ('disturbed', -1.0),
#  ('competed', -0.36797678529459443),
#  ('dentures', 0.47712125471966244),
#  ('portmanteau', 0.0),
#  ('loudness', 0.47712125471966244),
#  ('stebbing', 0.47712125471966244),
#  ('berdyczewski', 0.17609125905568124),
#  ('juergen', -0.3010299956639812),
#  ('popularise', -0.3010299956639812),
#  ('1340s', 0.47712125471966244),
#  ('vieth', 0.47712125471966244),
#  ('behaviourist', 0.0),
#  ('menstruation', 0.17609125905568124),
#  ('klebe', 0.17609125905568124),
#  ('reintroduced', 0.0),
#  ('vieta', 0.17609125905568124),
#  ('reciprocally', -0.47712125471966244),
#  ('maladies', 0.0),
#  ('generaledit', 0.17609125905568124),
#  ('dinstein', 0.47712125471966244),
#  ('stylistics', 0.47712125471966244),
#  ('kfc', 0.47712125471966244),
#  ('viereck', 0.47712125471966244),
#  ('humanos\xc2', 0.17609125905568124),
#  ('antilles', 0.0),
#  ('behaviourism', 0.17609125905568124),
#  ('specially', -0.92081875395237522),
#  ('seizures', -0.12493873660829995),
#  ('monatsschrift', -0.36797678529459443),
#  ('genesim', 0.47712125471966244),
#  ('moorfields', 0.47712125471966244),
#  ('renovated', -0.22184874961635639),
#  ('service', -1.8808135922807914),
#  ('eikon', 0.47712125471966244),
#  ('shuter', 0.47712125471966244),
#  ('ethnocentrism', 0.47712125471966244),
#  ('reuben', 0.0),
#  ('needed', -1.6595993124367443),
#  ('peacham', 0.0),
#  ('phan', 0.17609125905568124),
#  ('master', -1.8808135922807914),
#  ('ragioni', 0.17609125905568124),
#  ('ensaios', 0.17609125905568124),
#  ('ragione', 0.47712125471966244),
#  ('fuzziness', 0.0),
#  ('genesis', -1.2304489213782739),
#  ('rouayheb', 0.47712125471966244),
#  ('chieftains', 0.47712125471966244),
#  ('rewards', -0.93785209325115548),
#  ('nauwelaerts', 0.17609125905568124),
#  ('975\xe2', 0.17609125905568124),
#  ('quotidiana', 0.17609125905568124),
#  ('travers', -0.42596873227228116),
#  ('task', -1.6368220975871743),
#  ('mutilated', -0.12493873660829995),
#  ('prakseologiczne', 0.47712125471966244),
#  ('fatherlands', 0.47712125471966244),
#  ('lyndon', -0.22184874961635639),
#  ('681\xe2', 0.0),
#  ('positively', -0.97003677662255683),
#  ('spuriousness', 0.47712125471966244),
#  ('ahmed', -0.6020599913279624),
#  ('asaph', 0.47712125471966244),
#  ('mollusks', 0.47712125471966244),
#  ('saeed', 0.47712125471966244),
#  ('duckworth', -0.84509804001425681),
#  ('ferien', 0.47712125471966244),
#  ('\xed', 0.47712125471966244),
#  ('idly', 0.0),
#  ('bronislava', 0.47712125471966244),
#  ('regulator', 0.17609125905568124),
#  ('idle', -0.95424250943932487),
#  ('exclaimed', -0.47712125471966244),
#  ('schuur', 0.47712125471966244),
#  ('sheen', 0.47712125471966244),
#  ('moneyless', 0.17609125905568124),
#  ('feeling', -1.5947607525864629),
#  ('clinamen', 0.17609125905568124),
#  ('legibus', 0.47712125471966244),
#  ('assertiveness', 0.17609125905568124),
#  ('similitude', 0.17609125905568124),
#  ('bassolis', 0.47712125471966244),
#  ('miscellanea', -0.3010299956639812),
#  ('hadot', -0.3010299956639812),
#  ('spectrum', -0.88460658129793046),
#  ('craven', -0.22184874961635639),
#  ('housman', -0.12493873660829995),
#  ('longo', -0.12493873660829995),
#  ('mishra', -0.22184874961635639),
#  ('arousal', 0.17609125905568124),
#  ('thaw', 0.47712125471966244),
#  ('postkonventionellen', 0.17609125905568124),
#  ('shwe', 0.47712125471966244),
#  ('ufo', 0.47712125471966244),
#  ('hanau', 0.0),
#  ('dozen', -1.0669467896306133),
#  ('foundational', -1.1356626020000731),
#  ('affairs', -1.713210443450629),
#  ('haxton', 0.47712125471966244),
#  ('apostel', 0.17609125905568124),
#  ('wholesome', -0.22184874961635639),
#  ('mostly', -1.6751670896633941),
#  ('hymen', 0.47712125471966244),
#  ('neudruck', 0.47712125471966244),
#  ('judaean', 0.47712125471966244),
#  ('uncouth', 0.47712125471966244),
#  ('sturt', -0.12493873660829995),
#  ('christelijcke', 0.17609125905568124),
#  ('old\xe2', 0.47712125471966244),
#  ('affaire', 0.0),
#  ('sitis', 0.47712125471966244),
#  ('hymes', 0.47712125471966244),
#  ('greenback', 0.47712125471966244),
#  ('gandillac', 0.17609125905568124),
#  ('shipments', 0.17609125905568124),
#  ('totalitarismus', 0.47712125471966244),
#  ('committing', -1.0669467896306133),
#  ('unterrified', 0.47712125471966244),
#  ('lahn', 0.47712125471966244),
#  ('limitless', -0.22184874961635639),
#  ('diminishing', -0.47712125471966244),
#  ('cinematic', -0.12493873660829995),
#  ('resonates', -0.42596873227228116),
#  ('metrics', -0.42596873227228116),
#  ('simplify', -0.52287874528033762),
#  ('\xe1\xbd\xba', 0.47712125471966244),
#  ('mouth', -0.92081875395237522),
#  ('reverence', -1.0910804693473326),
#  ('conceded', -0.6020599913279624),
#  ('resonated', -0.12493873660829995),
#  ('anteckningar', 0.47712125471966244),
#  ('dailey', 0.47712125471966244),
#  ('transverse', 0.17609125905568124),
#  ('northamptonshire', 0.47712125471966244),
#  ('pseudonymously', 0.17609125905568124),
#  ('bradford', -0.77815125038364363),
#  ('lapeyre', 0.47712125471966244),
#  ('singer', -1.1760912590556813),
#  ('sandflea', 0.47712125471966244),
#  ('baldy', 0.17609125905568124),
#  ('majd', 0.17609125905568124),
#  ('mesmerist', 0.47712125471966244),
#  ('purges', -0.42596873227228116),
#  ('callinicos', -0.36797678529459443),
#  ('ranulph', 0.47712125471966244),
#  ('multiracial', 0.47712125471966244),
#  ('tech', -0.6020599913279624),
#  ('fugitives', 0.17609125905568124),
#  ('calventianus', 0.47712125471966244),
#  ('thunder', 0.0),
#  ('birzeit', 0.17609125905568124),
#  ('syncategoremata', 0.17609125905568124),
#  ('purged', -0.7269987279362623),
#  ('bouddha', 0.47712125471966244),
#  ('saying', -1.8653014261025438),
#  ('nominalization', 0.17609125905568124),
#  ('herakleitos', 0.47712125471966244),
#  ('propylaen', 0.47712125471966244),
#  ('leichtentritt', 0.47712125471966244),
#  ('disassociation', 0.47712125471966244),
#  ('teresa', -0.47712125471966244),
#  ('halpern', 0.17609125905568124),
#  ('broddgeltir', 0.47712125471966244),
#  ('rediscovery', -0.84509804001425681),
#  ('ber\xc3\xbchmter', 0.47712125471966244),
#  ('gurdjieff', 0.47712125471966244),
#  ('1531\xe2', 0.47712125471966244),
#  ('weltfish', 0.17609125905568124),
#  ('rediscovers', 0.47712125471966244),
#  ('ir\xc3', 0.0),
#  ('thai', -0.12493873660829995),
#  ('hounded', 0.47712125471966244),
#  ('approccio', 0.47712125471966244),
#  ('orleans', -0.36797678529459443),
#  ('faure', -0.12493873660829995),
#  ('musikbl\xc3', 0.47712125471966244),
#  ('kazantzakis', 0.47712125471966244),
#  ('excavator', 0.47712125471966244),
#  ('dreuz', 0.47712125471966244),
#  ('nontrinitarian', 0.47712125471966244),
#  ('rics', 0.47712125471966244),
#  ('gibbard\xe2', 0.47712125471966244),
#  ('badiou', -0.47712125471966244),
#  ('rico', -0.36797678529459443),
#  ('midshipmen', 0.47712125471966244),
#  ('huanggang', 0.17609125905568124),
#  ('sidgwickian', -0.12493873660829995),
#  ('rick', -0.3010299956639812),
#  ('rich', -1.5006023505691852),
#  ('495\xe2', 0.47712125471966244),
#  ('rice', -0.84509804001425681),
#  ('photographers', 0.47712125471966244),
#  ('677\xe2', 0.0),
#  ('rica', -0.3010299956639812),
#  ('stourbridge', 0.47712125471966244),
#  ('plate', -0.36797678529459443),
#  ('remotest', 0.17609125905568124),
#  ('plata', 0.0),
#  ('faculties\xe2', 0.17609125905568124),
#  ('vener', 0.47712125471966244),
#  ('marczewski', 0.17609125905568124),
#  ('umbilical', 0.47712125471966244),
#  ('firenze', -0.42596873227228116),
#  ('derridean', 0.47712125471966244),
#  ('platt', 0.47712125471966244),
#  ('cudworth', 0.47712125471966244),
#  ('obscur', 0.17609125905568124),
#  ('altogether', -1.2632414347745815),
#  ('rugged', 0.0),
#  ('intorno', 0.17609125905568124),
#  ('ironies', 0.47712125471966244),
#  ('ultimacy', 0.47712125471966244),
#  ('platz', -0.22184874961635639),
#  ('segregate', 0.17609125905568124),
#  ('berlin42', 0.47712125471966244),
#  ('jaguar', 0.17609125905568124),
#  ('mazinani', 0.47712125471966244),
#  ('boarder', 0.17609125905568124),
#  ('federman', 0.47712125471966244),
#  ('totman', 0.47712125471966244),
#  ('gobi', 0.47712125471966244),
#  ('guizhou', 0.17609125905568124),
#  ('guilli', 0.47712125471966244),
#  ('juvenilia', -0.22184874961635639),
#  ('viehweg', 0.47712125471966244),
#  ('anonymorum', 0.47712125471966244),
#  ('haevarim', 0.47712125471966244),
#  ('conant', -0.52287874528033762),
#  ('programmatic', -0.47712125471966244),
#  ('sociocybernetics', 0.47712125471966244),
#  ('shrewdly', 0.0),
#  ('clarified', -0.77815125038364363),
#  ('edgars', 0.47712125471966244),
#  ('sensitivity', -0.80163234623316659),
#  ('tolstaya', 0.47712125471966244),
#  ('zahlen', 0.17609125905568124),
#  ('1997a', 0.47712125471966244),
#  ('howse', 0.47712125471966244),
#  ('pinot', 0.47712125471966244),
#  ('tyndale', -0.12493873660829995),
#  ('culo', 0.47712125471966244),
#  ('sophiarum', 0.0),
#  ('semenov', 0.47712125471966244),
#  ('erika', -0.22184874961635639),
#  ('profundus', 0.47712125471966244),
#  ('ric\xc5', -0.12493873660829995),
#  ('taught\xe2', 0.47712125471966244),
#  ('ragazzini', 0.47712125471966244),
#  ('clarifies', -0.36797678529459443),
#  ('giffey', 0.47712125471966244),
#  ('morucci', 0.47712125471966244),
#  ('egunak', 0.17609125905568124),
#  ('baldford', 0.17609125905568124),
#  ('wainhouse', 0.17609125905568124),
#  ('belzen', 0.17609125905568124),
#  ('lots', -0.47712125471966244),
#  ('buhle', 0.47712125471966244),
#  ('arbeiterpartei', 0.17609125905568124),
#  ('convex', 0.17609125905568124),
#  ('solace', -0.52287874528033762),
#  ('collectaneum', 0.47712125471966244),
#  ('droves', 0.0),
#  ('xvi', -1.1026623418971477),
#  ('mellor', 0.47712125471966244),
#  ('payette', 0.47712125471966244),
#  ('patrologia', 0.17609125905568124),
#  ('w\xc3\xbcrzburg', -0.56427143043856265),
#  ('zinman', 0.17609125905568124),
#  ('immuniti\xc3', 0.47712125471966244),
#  ('ira', -0.6020599913279624),
#  ('adnan', 0.47712125471966244),
#  ('nuestro', 0.47712125471966244),
#  ('xve', 0.47712125471966244),
#  ('ire', -0.12493873660829995),
#  ('requisites', 0.17609125905568124),
#  ('wage', -1.0543576623225928),
#  ('natura', -0.90308998699194354),
#  ('naturf', 0.47712125471966244),
#  ('extend', -1.2471546148811266),
#  ('nature', -2.2244467303362652),
#  ('dullea', 0.47712125471966244),
#  ('optimist', 0.47712125471966244),
#  ('ukcatalogue', 0.17609125905568124),
#  ('anatomie', 0.47712125471966244),
#  ('rgs', 0.47712125471966244),
#  ('aiga', 0.47712125471966244),
#  ('extent', -1.6690067809585756),
#  ('accessed', -0.84509804001425681),
#  ('smn', 0.47712125471966244),
#  ('canonizations', 0.47712125471966244),
#  ('literackie', 0.47712125471966244),
#  ('epoche', 0.47712125471966244),
#  ('tyranny', -1.1249387366082999),
#  ('dysfunctionally', 0.47712125471966244),
#  ('boardman', 0.47712125471966244),
#  ('pleasuring', 0.17609125905568124),
#  ('ryerson', 0.47712125471966244),
#  ('seleucids', 0.47712125471966244),
#  ('miyake', 0.47712125471966244),
#  ('sparta', -0.42596873227228116),
#  ('heating', 0.17609125905568124),
#  ('incense', 0.17609125905568124),
#  ('excitantur', 0.17609125905568124),
#  ('poetry\xe2', 0.47712125471966244),
#  ('levitating', -0.3010299956639812),
#  ('windham', 0.47712125471966244),
#  ('welche', 0.17609125905568124),
#  ('anatomic', 0.47712125471966244),
#  ('melinda', 0.17609125905568124),
#  ('veel', 0.17609125905568124),
#  ('dynamick\xc3', 0.47712125471966244),
#  ('veen', -0.3010299956639812),
#  ('neofeminism', 0.47712125471966244),
#  ('southeastern', -0.12493873660829995),
#  ('moravia', 0.17609125905568124),
#  ('eradicate', -0.3010299956639812),
#  ('obscenity', -0.36797678529459443),
#  ('unsymmetrical', 0.47712125471966244),
#  ('cddc', 0.47712125471966244),
#  ('maclaine', 0.17609125905568124),
#  ('honorarprofessor', 0.17609125905568124),
#  ('limitedly', 0.47712125471966244),
#  ('marramao', 0.47712125471966244),
#  ('meaningfulness', 0.17609125905568124),
#  ('goebel', -0.12493873660829995),
#  ('gypsies', 0.0),
#  ('\xe4\xbe', 0.0),
#  ('1889\xe2', -0.56427143043856265),
#  ('\xe4\xbc', -0.12493873660829995),
#  ('\xe4\xbd', 0.17609125905568124),
#  ('\xe4\xba', -0.56427143043856265),
#  ('blanquerna', 0.47712125471966244),
#  ('\xe4\xb9', -0.36797678529459443),
#  ('secoli', 0.47712125471966244),
#  ('cze\xc5\xbcowski', 0.47712125471966244),
#  ('truthful', -0.52287874528033762),
#  ('solaire', 0.0),
#  ('quomodo', 0.47712125471966244),
#  ('godhead', 0.0),
#  ('fra', -0.12493873660829995),
#  ('gradualista', 0.17609125905568124),
#  ('frf', 0.47712125471966244),
#  ('trivialities', 0.17609125905568124),
#  ('triviality', 0.47712125471966244),
#  ('union', -1.8512583487190752),
#  ('odifreddi', 0.17609125905568124),
#  ('suffragette', 0.0),
#  ('fro', 0.47712125471966244),
#  ('frn', 0.17609125905568124),
#  ('invocatory', 0.17609125905568124),
#  ('communicants', 0.47712125471966244),
#  ('frs', -0.82390874094431876),
#  ('vergessener', 0.47712125471966244),
#  ('much', -2.2192351340136698),
#  ('wyman', 0.0),
#  ('fru', -0.12493873660829995),
#  ('progenitor', -0.36797678529459443),
#  ('dehumanised', 0.47712125471966244),
#  ('sextus', -0.56427143043856265),
#  ('choniates', 0.47712125471966244),
#  ('distinctio', 0.47712125471966244),
#  ('spir', 0.17609125905568124),
#  ('familles', 0.47712125471966244),
#  ('gallantry', 0.47712125471966244),
#  ('retrospect', -0.56427143043856265),
#  ('spit', 0.17609125905568124),
#  ('fikret', 0.47712125471966244),
#  ('nibb\xc4', 0.47712125471966244),
#  ('bilbays', 0.47712125471966244),
#  ('causarum', 0.47712125471966244),
#  ('davy', 0.17609125905568124),
#  ('synod', -0.66900678095857558),
#  ('yongzheng', 0.47712125471966244),
#  ('dave', -0.63682209758717434),
#  ('juran', 0.47712125471966244),
#  ('geistesgeschichte', 0.47712125471966244),
#  ('dava', 0.47712125471966244),
#  ('doubts', -1.2041199826559248),
#  ('oldenbarnevelt', 0.17609125905568124),
#  ('stepdad', 0.47712125471966244),
#  ('spin', -0.52287874528033762),
#  ('skilfully', 0.47712125471966244),
#  ('emploi', 0.47712125471966244),
#  ('didaktik', 0.47712125471966244),
#  ('kennan', 0.47712125471966244),
#  ('participatory', -0.63682209758717434),
#  ('tertullian', -0.36797678529459443),
#  ('heresie', 0.0),
#  ('zalman', 0.0),
#  ('juraj', 0.47712125471966244),
#  ('contingencies', -0.22184874961635639),
#  ('professionally', -0.47712125471966244),
#  ('fabbriciani', 0.47712125471966244),
#  ('employ', -1.146128035678238),
#  ('misconstrued', 0.17609125905568124),
#  ('linguagem', 0.47712125471966244),
#  ('bate', 0.47712125471966244),
#  ('prostrate', -0.42596873227228116),
#  ('reunion', -0.22184874961635639),
#  ('elaborate', -1.2304489213782739),
#  ('zalmay', 0.47712125471966244),
#  ('adulterous', 0.0),
#  ('fr\xc3', -0.75332766665861151),
#  ('majid', 0.47712125471966244),
#  ('climbed', 0.17609125905568124),
#  ('canoeing', 0.47712125471966244),
#  ('prefixed', -0.42596873227228116),
#  ('walkerdine', 0.47712125471966244),
#  ('zhuxi', 0.17609125905568124),
#  ('kohn', -0.12493873660829995),
#  ('libya\xe2', 0.47712125471966244),
#  ('leontief', 0.17609125905568124),
#  ('conditioned', -0.69897000433601875),
#  ('elmira', 0.47712125471966244),
#  ('eighteen', -1.156347200859924),
#  ('aristoclea', 0.47712125471966244),
#  ('koht', 0.47712125471966244),
#  ('abnormalities', 0.47712125471966244),
#  ('musicianship', 0.47712125471966244),
#  ('oxymoron', 0.47712125471966244),
#  ('insatiable', -0.36797678529459443),
#  ('serialisation', 0.47712125471966244),
#  ('hone', 0.47712125471966244),
#  ('hond', 0.47712125471966244),
#  ('memorial', -1.568201724066995),
#  ('memoriam', -0.84509804001425681),
#  ('mudrarakshasa', 0.17609125905568124),
#  ('malefactors', 0.17609125905568124),
#  ('remand', -0.12493873660829995),
#  ('memoriae', 0.17609125905568124),
#  ('mummified', 0.17609125905568124),
#  ('principale', 0.17609125905568124),
#  ('provinciale', -0.3010299956639812),
#  ('democracies', -0.86530142610254379),
#  ('snje\xc5\xbeana', 0.47712125471966244),
#  ('yocheved', 0.47712125471966244),
#  ('split', -1.3290587192642247),
#  ('hons', -0.3010299956639812),
#  ('ueber', -0.36797678529459443),
#  ('dunkirk', 0.47712125471966244),
#  ('hony', 0.17609125905568124),
#  ('memorias', 0.17609125905568124),
#  ('junge', -0.12493873660829995),
#  ('ritiers', 0.47712125471966244),
#  ('almoravid', 0.47712125471966244),
#  ('sycophant\xe2', 0.47712125471966244),
#  ('505h', 0.47712125471966244),
#  ('communally', 0.47712125471966244),
#  ('inadvertently', -0.3010299956639812),
#  ('marcher', 0.47712125471966244),
#  ('frenchmen', -0.22184874961635639),
#  ('anaxagoreans', 0.17609125905568124),
#  ('refir', 0.47712125471966244),
#  ('qualifications', -0.69897000433601875),
#  ('workforce', -0.12493873660829995),
#  ('marched', -0.66900678095857558),
#  ('rozwojowe', 0.47712125471966244),
#  ('boiler', 0.47712125471966244),
#  ('suppes', -0.42596873227228116),
#  ('sturbridge', 0.47712125471966244),
#  ('vierter', 0.47712125471966244),
#  ('torpedoed', 0.17609125905568124),
#  ('koblizek', 0.17609125905568124),
#  ('dodecaphony', 0.47712125471966244),
#  ('extenuating', 0.47712125471966244),
#  ('parik\xe1\xb9', 0.47712125471966244),
#  ('noblewoman', 0.17609125905568124),
#  ('kamina', 0.47712125471966244),
#  ('mentors', -0.3010299956639812),
#  ('climber', 0.0),
#  ('academic', -2.1471608411160057),
#  ('stillness', 0.47712125471966244),
#  ('academia', -1.481920137601431),
#  ('abitur', 0.47712125471966244),
#  ('glerh\xc3\xbas', 0.47712125471966244),
#  ('academie', 0.17609125905568124),
#  ('muehlmann', 0.17609125905568124),
#  ('corporate', -0.97003677662255683),
#  ('eurylochus', 0.47712125471966244),
#  ('plaque', -0.95424250943932487),
#  ('browsing', 0.17609125905568124),
#  ('benignity', 0.47712125471966244),
#  ('publicization', 0.0),
#  ('outlived', -0.42596873227228116),
#  ('bellow', 0.47712125471966244),
#  ('cam', 0.0),
#  ('etica', 0.0),
#  ('absurdities', 0.17609125905568124),
#  ('appropriately', -0.90308998699194354),
#  ('connell', -0.22184874961635639),
#  ('antagonists', 0.17609125905568124),
#  ('tedman', 0.47712125471966244),
#  ('necnon', 0.17609125905568124),
#  ('psychometrics', 0.47712125471966244),
#  ('homogeneity', -0.47712125471966244),
#  ('scheler', 0.17609125905568124),
#  ('topography', 0.47712125471966244),
#  ('maketh', 0.0),
#  ('belloc', -0.36797678529459443),
#  ('portrayed', -1.2632414347745815),
#  ('amps', 0.47712125471966244),
#  ('coomarswamy', 0.47712125471966244),
#  ('hai', 0.0),
#  ('ih', 0.47712125471966244),
#  ('lincean', 0.47712125471966244),
#  ('hal', -0.36797678529459443),
#  ('ham', 0.47712125471966244),
#  ('han', -0.80163234623316659),
#  ('hao', -0.36797678529459443),
#  ('haa', 0.47712125471966244),
#  ('hab', 0.47712125471966244),
#  ('espouses', -0.36797678529459443),
#  ('advancement', -1.156347200859924),
#  ('watercolour', 0.17609125905568124),
#  ('yeping', 0.47712125471966244),
#  ('hay', -0.52287874528033762),
#  ('rodziewicz', 0.47712125471966244),
#  ('beloved', -0.95424250943932487),
#  ('haq', 0.0),
#  ('espoused', -1.1139433523068367),
#  ('shamanology', 0.47712125471966244),
#  ('haw', 0.47712125471966244),
#  ('panpsychism', -0.22184874961635639),
#  ('municipal', -0.80163234623316659),
#  ('confidentially', 0.47712125471966244),
#  ('frisch', 0.0),
#  ('elders', -0.77815125038364363),
#  ('survival', -1.3862016054007935),
#  ('gulations', 0.47712125471966244),
#  ('unequivocally', -0.3010299956639812),
#  ('palazzo', -0.3010299956639812),
#  ('otherworldly', 0.47712125471966244),
#  ('indicative', -0.77815125038364363),
#  ('amiguetus', 0.47712125471966244),
#  ('thibaut', 0.47712125471966244),
#  ('clustered', 0.17609125905568124),
#  ('s11229', 0.47712125471966244),
#  ('shadow', -1.0280287236002434),
#  ('hamas', -0.22184874961635639),
#  ...]

# %% [markdown]
# ** We're ready to calculate TF-IDF. Do that for each branch. **
#
#     - List the 10 top words for each branch.
#     -  Are these 10 words more descriptive of the branch? If yes, what is it about IDF that makes the words more informative?

# %%
# first change the philosophers[branch]["idf"] array of tuples into a dictionry to make it easier to look up a word


tf_idfs = {
    "aestheticians":{
        "tf-idf":[]
    },
    "epistemologists":{
        "tf-idf":[]
    },
    "ethicists":{
        "tf-idf":[]
    },
    "logicians":{
        "tf-idf":[]
    },
    "metaphysicians":{
        "tf-idf":[]
    },
    "social and political philosophers":{
        "tf-idf":[]
    }
}

idf_dict = dict(idf)

for branch in philosophers.keys():
    tf_idfs[branch]["tf-idf"] = sorted([(token, idf_dict[token]*freq) for token,freq in philosophers[branch]["tf"]],
                                       key=operator.itemgetter(1),
                                       reverse=True)

# %%
for branch in tf_idfs:
    print "-----------"
    print branch
    print "----------"
    top_10 =  tf_idfs[branch]["tf-idf"][:10]
    for word,freq in top_10:
        print word,freq
# Out:
# -----------
# social and political philosophers
# ----------
# epimeteo 0.954242509439
# nordisk 0.954242509439
# saylor 0.954242509439
# yanagisawa 0.954242509439
# caney 0.954242509439
# paternalists 0.954242509439
# hollerbach 0.954242509439
# draža 0.954242509439
# transvestism 0.954242509439
# unipress 0.954242509439
# -----------
# aestheticians
# ----------
# sprague 0.954242509439
# alphabetic 0.954242509439
# schlegelschen 0.954242509439
# broiles 0.954242509439
# crotch 0.954242509439
# stereotypical 0.954242509439
# steadfastness 0.954242509439
# chanussot 0.954242509439
# jesociety 0.954242509439
# familles 0.954242509439
# -----------
# logicians
# ----------
# pawe� 0.954242509439
# logices 0.954242509439
# isaim 0.954242509439
# higman 0.954242509439
# induktion 0.954242509439
# braakhuis 0.954242509439
# wissensch 0.954242509439
# 1997b 0.954242509439
# 1997a 0.954242509439
# stagnators 0.954242509439
# -----------
# epistemologists
# ----------
# tulip 0.954242509439
# smartmoney 0.954242509439
# meantnn 0.954242509439
# jenkins� 0.954242509439
# sefardi 0.954242509439
# sociocybernetics 0.954242509439
# walkerdine 0.954242509439
# bellow 0.954242509439
# psychometrics 0.954242509439
# shamanology 0.954242509439
# -----------
# metaphysicians
# ----------
# clottes 0.954242509439
# ungel� 0.954242509439
# bendau 0.954242509439
# dialogs 0.954242509439
# pourparlers 0.954242509439
# meteorologist 0.954242509439
# barbra 0.954242509439
# amaya 0.954242509439
# incoherences 0.954242509439
# ponêra 0.954242509439
# -----------
# ethicists
# ----------
# dütas 0.954242509439
# sowell 0.954242509439
# trawling 0.954242509439
# localized 0.954242509439
# liberative 0.954242509439
# deferment 0.954242509439
# ioannidis 0.954242509439
# siyyid 0.954242509439
# sundt 0.954242509439
# bochur 0.954242509439

# %% [markdown]
# ** Normally, TF-IDF is used for single documents. What does TF-IDF tell us about the content of a single document in a collection. **

# %% [markdown]
# # Word cloud
#
#  - The package needs a string to work on. The way that I converted my TF-IDF results to a string was to simply combine all words together in one long string (separated by spaces), repeating each word according to its TF-IDF score (rounded up to the nearest integer value).
#  - Now, create word-cloud for each branch of philosophy. Feel free to make it as fancy or non-fancy as you like. Comment on the results.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import math
  
#text = "Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum."
#text = "Gretar Atli Gretarsson Gretar Atli Gretarsson Gretar Atli Gretarsson"

text = ""
for word,tfidf in tf_idfs[branch]["tf-idf"][:60]:
    text = text + int(round(tfidf))*word + " "
    
    
wordcloud = WordCloud().generate(text)
img=plt.imshow(wordcloud)
plt.axis("off")
plt.show()
  
#or save as png
#img.write_png("wordcloud.png")

# %%
text
# Out:
# 'reassertingfigmenachemstratagwynunoshawkentirthankaratrailsavicennism'

# %% [markdown]
# # Sentiment Analysis
#
# Sentiment analysis is another highly useful technique. It doesn't tie in strongly with our work on Wikipedia (more on that in the video), but we'll go through it here because experience shows that sentiment analysis might well be very useful when you get to the project stage of the class.

# %% [markdown]
# ** Download the LabMT wordlist. It's available as supplementary material from Temporal Patterns of Happiness and Information in a Global Social Network: Hedonometrics and Twitter (Data Set S1). Describe briefly how the list was generated. **
#
# - The dataset was constructed with human evaluations of thw top 5000 (sorted by frequency of each word in the text) from the text sources: Twitter, Google Books, music lyrics and New York times. The overall list is 10222 words. For evaluation of happyness of each word they asked users on Mechanical Turk to rate how a given word made them feel on a nine point integer scale, obtaining 50 independent evaluations per word.

# %% [markdown]
# ** Based on the LabMT word list, write a function that calculates sentiment given a list of tokens (the tokens should be lower case, etc). The function should complain if there are no words with sentiment attached. **
#
#
# The level of happiness in a text is calculated with the following equation
# $ \sum_{i=1}^{N} h_{avg}(w_i)* p_i $, where $p_i = f_i / \sum_{i=1}^{N} f_j$ and $h_{avg}(w_i)$ is the estimate of average happiness of that word.

# %% [markdown]
# We start of by getting the average happiness of each word in Data set S1 into a dictionary. We do this by reading dat set line by line and for each line (exept the first 4 lines) into a dictionary

# %%
from collections import defaultdict

# counter to count the number of lines that have been processed
counter = 0

happyness_rank = defaultdict(float)

with open('/Users/GretarAtli/Documents/GitHub/Dtu/Dtu-SocialGraphsAndInteractions/week_seven/SensitivityAnalysisDataset1/Data_Set_S1.txt') as f:
    for line in f:
        counter += 1
        
        # we want to skip the first 4 lines of the file
        if counter > 4:
            line = line.split()
            word = line[0]  # get the word from the line
            happiness_average = float(line[2]) # get the word happiness average
            happyness_rank[word] = happiness_average

# %% [markdown]
# Now we are ready to create a function that calculates the sentiment of a given list of tokens

# %%
import numpy as np

from __future__ import division

# Takes in a list of tokens and happiness_keys which is the list of words in data set 1
# returns the mean value of the happiness rank that was found in the tokens array
# if no value was found then the function returns 0
def estimateHappiness(tokens,happiness_keys):
    
    happiness_avg = [] # an array that contains the average happyness values of the tokens
    
    for token in tokens:
        if token in happiness_keys: # only include the words that can be found in the data set
            #print happyness_rank[token]
            happiness_avg.append(happyness_rank[token])

    if len(happiness_avg) == 0:
        return 0 # If no word in the tokens array is found in the dataset then we return 0
    else : 
        return np.mean(happiness_avg)

# %% [markdown]
# ** Calculate a sentiment profile for the novels in NLPP1e chapter 1. The sentiment profile has sentiment on the y-axis and position in the text on the x-axis. Use a moving average to show how the sentiment changes. Create profiles for sliding windows of length 15 words, 50 words, 100 words, 500 words. **

# %%
def getSentimentProfileData(text): 
    x = defaultdict(list) # container for the sentiment results for each sliding window length
    y = defaultdict(list) # container for the y axis for each sliding window length
    happiness_keys = set(happyness_rank.keys()) # The words in the data set 1
    steps = [15,50,100,500]

    for step in steps: 
        xkey = "x{}".format(step)
        ykey = "y{}".format(step)

        for i in range(len(text)-step):
            x[xkey].append(i)
            y[ykey].append(estimateHappiness(text[i:i + step], happiness_keys))
            
    return x, y

# %% [markdown]
# Finally everything is ready to calculate the sentiment profile for the novels in NLPP1e chapter 1. The novels are three and can be found in the nltk module under books.
#
# The novels are the following texts:
#
#     - text1: Moby Dick by Herman Melville 1851
#     - text2: Sense and Sensibility by Jane Austen 1811
#     - text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# Get the novels from the nltk module

import nltk
from nltk.book import *

novels = [text1,text2,text9]

# %% [markdown]
# Finally everything is ready to run our functions. This will result in profiles for each text for sliding windows of length 15 words, 50 words, 100 words, 500 words

# %%
colors = ["blue","red","green"]
titles = ["Moby Dick", "Sense and Sensibility", "The Man Who Was Thursday"]

for i,novel in enumerate(novels):
    
    print titles[i]
    
    # Calculate the sentiment profile for the novel
    x, y = getSentimentProfileData(novel)

    # plot the result
    plt.figure(figsize=(20,12))

    # sliding window of length 15
    plt.subplot(221)
    plt.plot(x["x15"], y["y15"], color=colors[i])
    plt.xlabel("Text position")
    plt.ylabel("Sentiment")
    plt.title('{} - sliding window of 15'.format(titles[i]))
    plt.grid(True)

    # sliding window of length 50
    plt.subplot(222)
    plt.plot(x["x50"], y["y50"], color=colors[i])
    plt.xlabel("Text position")
    plt.ylabel("Sentiment")
    plt.title('{} - sliding window of 50'.format(titles[i]))
    plt.grid(True)

    # sliding window of length 100
    plt.subplot(223)
    plt.plot(x["x100"], y["y100"], color=colors[i])
    plt.xlabel("Text position")
    plt.ylabel("Sentiment")
    plt.title('{} - sliding window of 100'.format(titles[i]))
    plt.grid(True)

    # sliding window of length 500
    plt.subplot(224)
    plt.plot(x["x500"], y["y500"], color=colors[i])
    plt.xlabel("Text position")
    plt.ylabel("Sentiment")
    plt.title('{} - sliding window of 500'.format(titles[i]))
    plt.grid(True)

    plt.show()

# %% [markdown]
# ** Comment on the sentiment profiles. Do they show a similar pattern? What is the effect of changing the size of the sliding window? **
#
# TODO Svara þessu
