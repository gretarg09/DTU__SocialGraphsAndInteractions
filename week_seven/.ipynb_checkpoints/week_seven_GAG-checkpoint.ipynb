# %% [markdown]
# # Processing real text (from out on the interwebs)
#
# ** Exercise: Just a couple of examples from the book: Work through the exercises NLPP1e 3.12: 6, 30. **

# %%
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ** 12. ○ Write a for loop to print out the characters of a string, one per line. **

# %%
mobydick_str = " ".join(text1[0:120])

for char in mobydick_str:
    print char
# Out:
# [
#
# M
# o
# b
# y
#
# D
# i
# c
# k
#
# b
# y
#
# H
# e
# r
# m
# a
# n
#
# M
# e
# l
# v
# i
# l
# l
# e
#
# 1
# 8
# 5
# 1
#
# ]
#
# E
# T
# Y
# M
# O
# L
# O
# G
# Y
#
# .
#
# (
#
# S
# u
# p
# p
# l
# i
# e
# d
#
# b
# y
#
# a
#
# L
# a
# t
# e
#
# C
# o
# n
# s
# u
# m
# p
# t
# i
# v
# e
#
# U
# s
# h
# e
# r
#
# t
# o
#
# a
#
# G
# r
# a
# m
# m
# a
# r
#
# S
# c
# h
# o
# o
# l
#
# )
#
# T
# h
# e
#
# p
# a
# l
# e
#
# U
# s
# h
# e
# r
#
# -
# -
#
# t
# h
# r
# e
# a
# d
# b
# a
# r
# e
#
# i
# n
#
# c
# o
# a
# t
#
# ,
#
# h
# e
# a
# r
# t
#
# ,
#
# b
# o
# d
# y
#
# ,
#
# a
# n
# d
#
# b
# r
# a
# i
# n
#
# ;
#
# I
#
# s
# e
# e
#
# h
# i
# m
#
# n
# o
# w
#
# .
#
# H
# e
#
# w
# a
# s
#
# e
# v
# e
# r
#
# d
# u
# s
# t
# i
# n
# g
#
# h
# i
# s
#
# o
# l
# d
#
# l
# e
# x
# i
# c
# o
# n
# s
#
# a
# n
# d
#
# g
# r
# a
# m
# m
# a
# r
# s
#
# ,
#
# w
# i
# t
# h
#
# a
#
# q
# u
# e
# e
# r
#
# h
# a
# n
# d
# k
# e
# r
# c
# h
# i
# e
# f
#
# ,
#
# m
# o
# c
# k
# i
# n
# g
# l
# y
#
# e
# m
# b
# e
# l
# l
# i
# s
# h
# e
# d
#
# w
# i
# t
# h
#
# a
# l
# l
#
# t
# h
# e
#
# g
# a
# y
#
# f
# l
# a
# g
# s
#
# o
# f
#
# a
# l
# l
#
# t
# h
# e
#
# k
# n
# o
# w
# n
#
# n
# a
# t
# i
# o
# n
# s
#
# o
# f
#
# t
# h
# e
#
# w
# o
# r
# l
# d
#
# .
#
# H
# e
#
# l
# o
# v
# e
# d
#
# t
# o
#
# d
# u
# s
# t
#
# h
# i
# s
#
# o
# l
# d
#
# g
# r
# a
# m
# m
# a
# r
# s
#
# ;
#
# i
# t
#
# s
# o
# m
# e
# h
# o
# w
#
# m
# i
# l
# d
# l
# y
#
# r
# e
# m
# i
# n
# d
# e
# d
#
# h
# i
# m
#
# o
# f
#
# h
# i
# s
#
# m
# o
# r
# t
# a
# l
# i
# t
# y
#
# .
#
# "
#
# W
# h
# i
# l
# e
#
# y
# o
# u
#
# t
# a
# k
# e
#
# i
# n
#
# h
# a
# n
# d
#
# t
# o
#
# s
# c
# h
# o
# o
# l
#
# o
# t
# h
# e
# r
# s
#
# ,
#
# a
# n
# d
#
# t
# o
#
# t
# e
# a
# c
# h
#
# t
# h
# e
# m
#
# b
# y
#
# w
# h
# a
# t
#
# n
# a
# m
# e
#
# a
#
# w
# h
# a
# l
# e
#
# -
#
# f
# i
# s
# h
#
# i
# s
#
# t
# o
#
# b
# e
#
# c
# a
# l
# l
# e
# d
#
# i
# n
#
# o
# u
# r
#
# t
# o
# n
# g
# u
# e
#
# l
# e
# a
# v
# i
# n
# g
#
# o
# u
# t

# %%
mobydick_str
# Out:
# u'[ Moby Dick by Herman Melville 1851 ] ETYMOLOGY . ( Supplied by a Late Consumptive Usher to a Grammar School ) The pale Usher -- threadbare in coat , heart , body , and brain ; I see him now . He was ever dusting his old lexicons and grammars , with a queer handkerchief , mockingly embellished with all the gay flags of all the known nations of the world . He loved to dust his old grammars ; it somehow mildly reminded him of his mortality . " While you take in hand to school others , and to teach them by what name a whale - fish is to be called in our tongue leaving out'

# %% [markdown]
# ** 13. ○ What is the difference between calling split on a string with no argument and one with ' ' as the argument, e.g., sent.split() versus sent.split(' ')? What happens when the string being split contains tab characters, consecutive space characters, or a sequence of tabs and spaces? (In IDLE you will need to use '\t' to enter a tab character.) **
#
# .split(' ') only splits on " " but .split() splits on both tabs and spaces. You can clearly see the difference in the following example.

# %%
temp = "my mom is a good\nperson"

temp.split()
# Out:
# ['my', 'mom', 'is', 'a', 'good', 'person']

# %%
temp.split(' ')
# Out:
# ['my', 'mom', 'is', 'a', 'good\nperson']

# %% [markdown]
# **14. ○ Create a variable words containing a list of words. Experiment with words.sort() and sorted(words). What is the difference?**

# %%
words = text1[0:100]

# %%
print words.sort()
# Out:
# None

# %%
print sorted(word)
# Out:
# [u'"', u'(', u')', u',', u',', u',', u',', u',', u',', u'--', u'.', u'.', u'.', u'.', u'1851', u';', u';', u'Consumptive', u'Dick', u'ETYMOLOGY', u'Grammar', u'He', u'He', u'Herman', u'I', u'Late', u'Melville', u'Moby', u'School', u'Supplied', u'The', u'Usher', u'Usher', u'While', u'[', u']', u'a', u'a', u'a', u'all', u'all', u'and', u'and', u'body', u'brain', u'by', u'by', u'coat', u'dust', u'dusting', u'embellished', u'ever', u'flags', u'gay', u'grammars', u'grammars', u'hand', u'handkerchief', u'heart', u'him', u'him', u'his', u'his', u'his', u'in', u'in', u'it', u'known', u'lexicons', u'loved', u'mildly', u'mockingly', u'mortality', u'nations', u'now', u'of', u'of', u'of', u'old', u'old', u'others', u'pale', u'queer', u'reminded', u'school', u'see', u'somehow', u'take', u'the', u'the', u'the', u'threadbare', u'to', u'to', u'to', u'was', u'with', u'with', u'world', u'you']

# %% [markdown]
# **15. ○ Explore the difference between strings and integers by typing the following at a Python prompt: "3" * 7 and 3 * 7. Try converting between strings and integers using int("3") and str(3).**

# %%
"3" * 7
# Out:
# '3333333'

# %%
3*7
# Out:
# 21

# %% [markdown]
# **16. ○ Earlier, we asked you to use a text editor to create a file called test.py, containing the single line monty = 'Monty Python'. If you haven’t already done this (or can’t find the file), go ahead and do it now. Next, start up a new session with the Python interpreter, and enter the expression monty at the prompt. You will get an error from the interpreter. Now, try the following (note that you have to leave off the .py part of the filename):**
#
#     -> from test import msg
#     -> msg
#
#
# **This time, Python should return with a value. You can also try import test, in which case Python should be able to evaluate the expression test.monty at the prompt.**
#
#
# NENNI ÞESSU EKKI. OF LÉTT

# %% [markdown]
# **30. ◑ Use the Porter Stemmer to normalize some tokenized text, calling the stemmer on each word. Do the same thing with the Lancaster Stemmer, and see if you ob- serve any differences.**

# %%
porter  = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()

text1_porter = [porter.stem(word) for word in text1]
text1_lancaster = [lancaster.stem(word) for word in text1]

# %%
text1_porter
# Out:
# [u'[',
#  u'mobi',
#  u'dick',
#  u'by',
#  u'herman',
#  u'melvil',
#  u'1851',
#  u']',
#  u'etymolog',
#  u'.',
#  u'(',
#  u'suppli',
#  u'by',
#  u'a',
#  u'late',
#  u'consumpt',
#  u'usher',
#  u'to',
#  u'a',
#  u'grammar',
#  u'school',
#  u')',
#  u'the',
#  u'pale',
#  u'usher',
#  u'--',
#  u'threadbar',
#  u'in',
#  u'coat',
#  u',',
#  u'heart',
#  u',',
#  u'bodi',
#  u',',
#  u'and',
#  u'brain',
#  u';',
#  u'I',
#  u'see',
#  u'him',
#  u'now',
#  u'.',
#  u'He',
#  u'wa',
#  u'ever',
#  u'dust',
#  u'hi',
#  u'old',
#  u'lexicon',
#  u'and',
#  u'grammar',
#  u',',
#  u'with',
#  u'a',
#  u'queer',
#  u'handkerchief',
#  u',',
#  u'mockingli',
#  u'embellish',
#  u'with',
#  u'all',
#  u'the',
#  u'gay',
#  u'flag',
#  u'of',
#  u'all',
#  u'the',
#  u'known',
#  u'nation',
#  u'of',
#  u'the',
#  u'world',
#  u'.',
#  u'He',
#  u'love',
#  u'to',
#  u'dust',
#  u'hi',
#  u'old',
#  u'grammar',
#  u';',
#  u'it',
#  u'somehow',
#  u'mildli',
#  u'remind',
#  u'him',
#  u'of',
#  u'hi',
#  u'mortal',
#  u'.',
#  u'"',
#  u'while',
#  u'you',
#  u'take',
#  u'in',
#  u'hand',
#  u'to',
#  u'school',
#  u'other',
#  u',',
#  u'and',
#  u'to',
#  u'teach',
#  u'them',
#  u'by',
#  u'what',
#  u'name',
#  u'a',
#  u'whale',
#  u'-',
#  u'fish',
#  u'is',
#  u'to',
#  u'be',
#  u'call',
#  u'in',
#  u'our',
#  u'tongu',
#  u'leav',
#  u'out',
#  u',',
#  u'through',
#  u'ignor',
#  u',',
#  u'the',
#  u'letter',
#  u'H',
#  u',',
#  u'which',
#  u'almost',
#  u'alon',
#  u'maketh',
#  u'the',
#  u'signif',
#  u'of',
#  u'the',
#  u'word',
#  u',',
#  u'you',
#  u'deliv',
#  u'that',
#  u'which',
#  u'is',
#  u'not',
#  u'true',
#  u'."',
#  u'--',
#  u'hackluyt',
#  u'"',
#  u'whale',
#  u'.',
#  u'...',
#  u'Sw',
#  u'.',
#  u'and',
#  u'dan',
#  u'.',
#  u'hval',
#  u'.',
#  u'thi',
#  u'anim',
#  u'is',
#  u'name',
#  u'from',
#  u'round',
#  u'or',
#  u'roll',
#  u';',
#  u'for',
#  u'in',
#  u'dan',
#  u'.',
#  u'hvalt',
#  u'is',
#  u'arch',
#  u'or',
#  u'vault',
#  u'."',
#  u'--',
#  u'webster',
#  u"'",
#  u'S',
#  u'dictionari',
#  u'"',
#  u'whale',
#  u'.',
#  u'...',
#  u'It',
#  u'is',
#  u'more',
#  u'immedi',
#  u'from',
#  u'the',
#  u'dut',
#  u'.',
#  u'and',
#  u'ger',
#  u'.',
#  u'wallen',
#  u';',
#  u'A',
#  u'.',
#  u'S',
#  u'.',
#  u'walw',
#  u'-',
#  u'ian',
#  u',',
#  u'to',
#  u'roll',
#  u',',
#  u'to',
#  u'wallow',
#  u'."',
#  u'--',
#  u'richardson',
#  u"'",
#  u'S',
#  u'dictionari',
#  u'keto',
#  u',',
#  u'greek',
#  u'.',
#  u'cetu',
#  u',',
#  u'latin',
#  u'.',
#  u'whoel',
#  u',',
#  u'anglo',
#  u'-',
#  u'saxon',
#  u'.',
#  u'hvalt',
#  u',',
#  u'danish',
#  u'.',
#  u'wal',
#  u',',
#  u'dutch',
#  u'.',
#  u'hwal',
#  u',',
#  u'swedish',
#  u'.',
#  u'whale',
#  u',',
#  u'iceland',
#  u'.',
#  u'whale',
#  u',',
#  u'english',
#  u'.',
#  u'balein',
#  u',',
#  u'french',
#  u'.',
#  u'ballena',
#  u',',
#  u'spanish',
#  u'.',
#  u'peke',
#  u'-',
#  u'nuee',
#  u'-',
#  u'nuee',
#  u',',
#  u'fege',
#  u'.',
#  u'peke',
#  u'-',
#  u'nuee',
#  u'-',
#  u'nuee',
#  u',',
#  u'erromangoan',
#  u'.',
#  u'extract',
#  u'(',
#  u'suppli',
#  u'by',
#  u'a',
#  u'sub',
#  u'-',
#  u'sub',
#  u'-',
#  u'librarian',
#  u').',
#  u'It',
#  u'will',
#  u'be',
#  u'seen',
#  u'that',
#  u'thi',
#  u'mere',
#  u'painstak',
#  u'burrow',
#  u'and',
#  u'grub',
#  u'-',
#  u'worm',
#  u'of',
#  u'a',
#  u'poor',
#  u'devil',
#  u'of',
#  u'a',
#  u'sub',
#  u'-',
#  u'sub',
#  u'appear',
#  u'to',
#  u'have',
#  u'gone',
#  u'through',
#  u'the',
#  u'long',
#  u'vatican',
#  u'and',
#  u'street',
#  u'-',
#  u'stall',
#  u'of',
#  u'the',
#  u'earth',
#  u',',
#  u'pick',
#  u'up',
#  u'whatev',
#  u'random',
#  u'allus',
#  u'to',
#  u'whale',
#  u'he',
#  u'could',
#  u'anyway',
#  u'find',
#  u'in',
#  u'ani',
#  u'book',
#  u'whatsoev',
#  u',',
#  u'sacr',
#  u'or',
#  u'profan',
#  u'.',
#  u'therefor',
#  u'you',
#  u'must',
#  u'not',
#  u',',
#  u'in',
#  u'everi',
#  u'case',
#  u'at',
#  u'least',
#  u',',
#  u'take',
#  u'the',
#  u'higgledi',
#  u'-',
#  u'piggledi',
#  u'whale',
#  u'statement',
#  u',',
#  u'howev',
#  u'authent',
#  u',',
#  u'in',
#  u'these',
#  u'extract',
#  u',',
#  u'for',
#  u'verit',
#  u'gospel',
#  u'cetolog',
#  u'.',
#  u'far',
#  u'from',
#  u'it',
#  u'.',
#  u'As',
#  u'touch',
#  u'the',
#  u'ancient',
#  u'author',
#  u'gener',
#  u',',
#  u'as',
#  u'well',
#  u'as',
#  u'the',
#  u'poet',
#  u'here',
#  u'appear',
#  u',',
#  u'these',
#  u'extract',
#  u'are',
#  u'sole',
#  u'valuabl',
#  u'or',
#  u'entertain',
#  u',',
#  u'as',
#  u'afford',
#  u'a',
#  u'glanc',
#  u'bird',
#  u"'",
#  u's',
#  u'eye',
#  u'view',
#  u'of',
#  u'what',
#  u'ha',
#  u'been',
#  u'promiscu',
#  u'said',
#  u',',
#  u'thought',
#  u',',
#  u'fanci',
#  u',',
#  u'and',
#  u'sung',
#  u'of',
#  u'leviathan',
#  u',',
#  u'by',
#  u'mani',
#  u'nation',
#  u'and',
#  u'gener',
#  u',',
#  u'includ',
#  u'our',
#  u'own',
#  u'.',
#  u'So',
#  u'fare',
#  u'thee',
#  u'well',
#  u',',
#  u'poor',
#  u'devil',
#  u'of',
#  u'a',
#  u'sub',
#  u'-',
#  u'sub',
#  u',',
#  u'whose',
#  u'comment',
#  u'I',
#  u'am',
#  u'.',
#  u'thou',
#  u'belongest',
#  u'to',
#  u'that',
#  u'hopeless',
#  u',',
#  u'sallow',
#  u'tribe',
#  u'which',
#  u'no',
#  u'wine',
#  u'of',
#  u'thi',
#  u'world',
#  u'will',
#  u'ever',
#  u'warm',
#  u';',
#  u'and',
#  u'for',
#  u'whom',
#  u'even',
#  u'pale',
#  u'sherri',
#  u'would',
#  u'be',
#  u'too',
#  u'rosi',
#  u'-',
#  u'strong',
#  u';',
#  u'but',
#  u'with',
#  u'whom',
#  u'one',
#  u'sometim',
#  u'love',
#  u'to',
#  u'sit',
#  u',',
#  u'and',
#  u'feel',
#  u'poor',
#  u'-',
#  u'devilish',
#  u',',
#  u'too',
#  u';',
#  u'and',
#  u'grow',
#  u'convivi',
#  u'upon',
#  u'tear',
#  u';',
#  u'and',
#  u'say',
#  u'to',
#  u'them',
#  u'bluntli',
#  u',',
#  u'with',
#  u'full',
#  u'eye',
#  u'and',
#  u'empti',
#  u'glass',
#  u',',
#  u'and',
#  u'in',
#  u'not',
#  u'altogeth',
#  u'unpleas',
#  u'sad',
#  u'--',
#  u'give',
#  u'it',
#  u'up',
#  u',',
#  u'sub',
#  u'-',
#  u'sub',
#  u'!',
#  u'for',
#  u'by',
#  u'how',
#  u'much',
#  u'the',
#  u'more',
#  u'pain',
#  u'ye',
#  u'take',
#  u'to',
#  u'pleas',
#  u'the',
#  u'world',
#  u',',
#  u'by',
#  u'so',
#  u'much',
#  u'the',
#  u'more',
#  u'shall',
#  u'ye',
#  u'for',
#  u'ever',
#  u'go',
#  u'thankless',
#  u'!',
#  u'would',
#  u'that',
#  u'I',
#  u'could',
#  u'clear',
#  u'out',
#  u'hampton',
#  u'court',
#  u'and',
#  u'the',
#  u'tuileri',
#  u'for',
#  u'ye',
#  u'!',
#  u'but',
#  u'gulp',
#  u'down',
#  u'your',
#  u'tear',
#  u'and',
#  u'hie',
#  u'aloft',
#  u'to',
#  u'the',
#  u'royal',
#  u'-',
#  u'mast',
#  u'with',
#  u'your',
#  u'heart',
#  u';',
#  u'for',
#  u'your',
#  u'friend',
#  u'who',
#  u'have',
#  u'gone',
#  u'befor',
#  u'are',
#  u'clear',
#  u'out',
#  u'the',
#  u'seven',
#  u'-',
#  u'stori',
#  u'heaven',
#  u',',
#  u'and',
#  u'make',
#  u'refuge',
#  u'of',
#  u'long',
#  u'-',
#  u'pamper',
#  u'gabriel',
#  u',',
#  u'michael',
#  u',',
#  u'and',
#  u'raphael',
#  u',',
#  u'against',
#  u'your',
#  u'come',
#  u'.',
#  u'here',
#  u'ye',
#  u'strike',
#  u'but',
#  u'splinter',
#  u'heart',
#  u'togeth',
#  u'--',
#  u'there',
#  u',',
#  u'ye',
#  u'shall',
#  u'strike',
#  u'unsplinter',
#  u'glass',
#  u'!',
#  u'extract',
#  u'.',
#  u'"',
#  u'and',
#  u'god',
#  u'creat',
#  u'great',
#  u'whale',
#  u'."',
#  u'--',
#  u'genesi',
#  u'.',
#  u'"',
#  u'leviathan',
#  u'maketh',
#  u'a',
#  u'path',
#  u'to',
#  u'shine',
#  u'after',
#  u'him',
#  u';',
#  u'one',
#  u'would',
#  u'think',
#  u'the',
#  u'deep',
#  u'to',
#  u'be',
#  u'hoari',
#  u'."',
#  u'--',
#  u'job',
#  u'.',
#  u'"',
#  u'now',
#  u'the',
#  u'lord',
#  u'had',
#  u'prepar',
#  u'a',
#  u'great',
#  u'fish',
#  u'to',
#  u'swallow',
#  u'up',
#  u'jonah',
#  u'."',
#  u'--',
#  u'jonah',
#  u'.',
#  u'"',
#  u'there',
#  u'go',
#  u'the',
#  u'ship',
#  u';',
#  u'there',
#  u'is',
#  u'that',
#  u'leviathan',
#  u'whom',
#  u'thou',
#  u'hast',
#  u'made',
#  u'to',
#  u'play',
#  u'therein',
#  u'."',
#  u'--',
#  u'psalm',
#  u'.',
#  u'"',
#  u'In',
#  u'that',
#  u'day',
#  u',',
#  u'the',
#  u'lord',
#  u'with',
#  u'hi',
#  u'sore',
#  u',',
#  u'and',
#  u'great',
#  u',',
#  u'and',
#  u'strong',
#  u'sword',
#  u',',
#  u'shall',
#  u'punish',
#  u'leviathan',
#  u'the',
#  u'pierc',
#  u'serpent',
#  u',',
#  u'even',
#  u'leviathan',
#  u'that',
#  u'crook',
#  u'serpent',
#  u';',
#  u'and',
#  u'he',
#  u'shall',
#  u'slay',
#  u'the',
#  u'dragon',
#  u'that',
#  u'is',
#  u'in',
#  u'the',
#  u'sea',
#  u'."',
#  u'--',
#  u'isaiah',
#  u'"',
#  u'and',
#  u'what',
#  u'thing',
#  u'soever',
#  u'besid',
#  u'cometh',
#  u'within',
#  u'the',
#  u'chao',
#  u'of',
#  u'thi',
#  u'monster',
#  u"'",
#  u's',
#  u'mouth',
#  u',',
#  u'be',
#  u'it',
#  u'beast',
#  u',',
#  u'boat',
#  u',',
#  u'or',
#  u'stone',
#  u',',
#  u'down',
#  u'it',
#  u'goe',
#  u'all',
#  u'incontin',
#  u'that',
#  u'foul',
#  u'great',
#  u'swallow',
#  u'of',
#  u'hi',
#  u',',
#  u'and',
#  u'perisheth',
#  u'in',
#  u'the',
#  u'bottomless',
#  u'gulf',
#  u'of',
#  u'hi',
#  u'paunch',
#  u'."',
#  u'--',
#  u'holland',
#  u"'",
#  u'S',
#  u'plutarch',
#  u"'",
#  u'S',
#  u'moral',
#  u'.',
#  u'"',
#  u'the',
#  u'indian',
#  u'sea',
#  u'breedeth',
#  u'the',
#  u'most',
#  u'and',
#  u'the',
#  u'biggest',
#  u'fish',
#  u'that',
#  u'are',
#  u':',
#  u'among',
#  u'which',
#  u'the',
#  u'whale',
#  u'and',
#  u'whirlpool',
#  u'call',
#  u'balaen',
#  u',',
#  u'take',
#  u'up',
#  u'as',
#  u'much',
#  u'in',
#  u'length',
#  u'as',
#  u'four',
#  u'acr',
#  u'or',
#  u'arpen',
#  u'of',
#  u'land',
#  u'."',
#  u'--',
#  u'holland',
#  u"'",
#  u'S',
#  u'plini',
#  u'.',
#  u'"',
#  u'scarc',
#  u'had',
#  u'we',
#  u'proceed',
#  u'two',
#  u'day',
#  u'on',
#  u'the',
#  u'sea',
#  u',',
#  u'when',
#  u'about',
#  u'sunris',
#  u'a',
#  u'great',
#  u'mani',
#  u'whale',
#  u'and',
#  u'other',
#  u'monster',
#  u'of',
#  u'the',
#  u'sea',
#  u',',
#  u'appear',
#  u'.',
#  u'among',
#  u'the',
#  u'former',
#  u',',
#  u'one',
#  u'wa',
#  u'of',
#  u'a',
#  u'most',
#  u'monstrou',
#  u'size',
#  u'.',
#  u'...',
#  u'thi',
#  u'came',
#  u'toward',
#  u'us',
#  u',',
#  u'open',
#  u'-',
#  u'mouth',
#  u',',
#  u'rais',
#  u'the',
#  u'wave',
#  u'on',
#  u'all',
#  u'side',
#  u',',
#  u'and',
#  u'beat',
#  u'the',
#  u'sea',
#  u'befor',
#  u'him',
#  u'into',
#  u'a',
#  u'foam',
#  u'."',
#  u'--',
#  u'took',
#  u"'",
#  u'S',
#  u'lucian',
#  u'.',
#  u'"',
#  u'the',
#  u'true',
#  u'histori',
#  u'."',
#  u'"',
#  u'He',
#  u'visit',
#  u'thi',
#  u'countri',
#  u'also',
#  u'with',
#  u'a',
#  u'view',
#  u'of',
#  u'catch',
#  u'hors',
#  u'-',
#  u'whale',
#  u',',
#  u'which',
#  u'had',
#  u'bone',
#  u'of',
#  u'veri',
#  u'great',
#  u'valu',
#  u'for',
#  u'their',
#  u'teeth',
#  u',',
#  u'of',
#  u'which',
#  u'he',
#  u'brought',
#  u'some',
#  u'to',
#  u'the',
#  u'king',
#  u'.',
#  u'...',
#  u'the',
#  u'best',
#  u'whale',
#  u'were',
#  u'catch',
#  u'in',
#  u'hi',
#  u'own',
#  u'countri',
#  u',',
#  u'of',
#  u'which',
#  u'some',
#  u'were',
#  u'forti',
#  u'-',
#  u'eight',
#  u',',
#  u'some',
#  u'fifti',
#  u'yard',
#  u'long',
#  u'.',
#  u'He',
#  ...]

# %%
text1_lancaster
# Out:
# [u'[',
#  u'moby',
#  u'dick',
#  u'by',
#  u'herm',
#  u'melvil',
#  u'1851',
#  u']',
#  u'etymolog',
#  u'.',
#  u'(',
#  u'supply',
#  u'by',
#  u'a',
#  u'lat',
#  u'consum',
#  u'ush',
#  u'to',
#  u'a',
#  u'gramm',
#  u'school',
#  u')',
#  u'the',
#  u'pal',
#  u'ush',
#  u'--',
#  u'threadbare',
#  u'in',
#  u'coat',
#  u',',
#  u'heart',
#  u',',
#  u'body',
#  u',',
#  u'and',
#  u'brain',
#  u';',
#  u'i',
#  u'see',
#  u'him',
#  u'now',
#  u'.',
#  u'he',
#  u'was',
#  u'ev',
#  u'dust',
#  u'his',
#  u'old',
#  u'lexicon',
#  u'and',
#  u'gramm',
#  u',',
#  u'with',
#  u'a',
#  u'que',
#  u'handkerchief',
#  u',',
#  u'mock',
#  u'embel',
#  u'with',
#  u'al',
#  u'the',
#  u'gay',
#  u'flag',
#  u'of',
#  u'al',
#  u'the',
#  u'known',
#  u'nat',
#  u'of',
#  u'the',
#  u'world',
#  u'.',
#  u'he',
#  u'lov',
#  u'to',
#  u'dust',
#  u'his',
#  u'old',
#  u'gramm',
#  u';',
#  u'it',
#  u'somehow',
#  u'mild',
#  u'remind',
#  u'him',
#  u'of',
#  u'his',
#  u'mort',
#  u'.',
#  u'"',
#  u'whil',
#  u'you',
#  u'tak',
#  u'in',
#  u'hand',
#  u'to',
#  u'school',
#  u'oth',
#  u',',
#  u'and',
#  u'to',
#  u'teach',
#  u'them',
#  u'by',
#  u'what',
#  u'nam',
#  u'a',
#  u'whal',
#  u'-',
#  u'fish',
#  u'is',
#  u'to',
#  u'be',
#  u'cal',
#  u'in',
#  u'our',
#  u'tongu',
#  u'leav',
#  u'out',
#  u',',
#  u'through',
#  u'ign',
#  u',',
#  u'the',
#  u'let',
#  u'h',
#  u',',
#  u'which',
#  u'almost',
#  u'alon',
#  u'make',
#  u'the',
#  u'sign',
#  u'of',
#  u'the',
#  u'word',
#  u',',
#  u'you',
#  u'del',
#  u'that',
#  u'which',
#  u'is',
#  u'not',
#  u'tru',
#  u'."',
#  u'--',
#  u'hackluyt',
#  u'"',
#  u'whal',
#  u'.',
#  u'...',
#  u'sw',
#  u'.',
#  u'and',
#  u'dan',
#  u'.',
#  u'hval',
#  u'.',
#  u'thi',
#  u'anim',
#  u'is',
#  u'nam',
#  u'from',
#  u'round',
#  u'or',
#  u'rol',
#  u';',
#  u'for',
#  u'in',
#  u'dan',
#  u'.',
#  u'hvalt',
#  u'is',
#  u'arch',
#  u'or',
#  u'vault',
#  u'."',
#  u'--',
#  u'webst',
#  u"'",
#  u's',
#  u'dict',
#  u'"',
#  u'whal',
#  u'.',
#  u'...',
#  u'it',
#  u'is',
#  u'mor',
#  u'immedy',
#  u'from',
#  u'the',
#  u'dut',
#  u'.',
#  u'and',
#  u'ger',
#  u'.',
#  u'wal',
#  u';',
#  u'a',
#  u'.',
#  u's',
#  u'.',
#  u'walw',
#  u'-',
#  u'ian',
#  u',',
#  u'to',
#  u'rol',
#  u',',
#  u'to',
#  u'wallow',
#  u'."',
#  u'--',
#  u'richardson',
#  u"'",
#  u's',
#  u'dict',
#  u'keto',
#  u',',
#  u'greek',
#  u'.',
#  u'cet',
#  u',',
#  u'latin',
#  u'.',
#  u'whoel',
#  u',',
#  u'anglo',
#  u'-',
#  u'saxon',
#  u'.',
#  u'hvalt',
#  u',',
#  u'dan',
#  u'.',
#  u'wal',
#  u',',
#  u'dutch',
#  u'.',
#  u'hwal',
#  u',',
#  u'swed',
#  u'.',
#  u'whal',
#  u',',
#  u'iceland',
#  u'.',
#  u'whal',
#  u',',
#  u'engl',
#  u'.',
#  u'balein',
#  u',',
#  u'french',
#  u'.',
#  u'ballen',
#  u',',
#  u'span',
#  u'.',
#  u'pek',
#  u'-',
#  u'nue',
#  u'-',
#  u'nue',
#  u',',
#  u'feg',
#  u'.',
#  u'pek',
#  u'-',
#  u'nue',
#  u'-',
#  u'nue',
#  u',',
#  u'erromango',
#  u'.',
#  u'extract',
#  u'(',
#  u'supply',
#  u'by',
#  u'a',
#  u'sub',
#  u'-',
#  u'sub',
#  u'-',
#  u'libr',
#  u').',
#  u'it',
#  u'wil',
#  u'be',
#  u'seen',
#  u'that',
#  u'thi',
#  u'mer',
#  u'painstak',
#  u'burrow',
#  u'and',
#  u'grub',
#  u'-',
#  u'worm',
#  u'of',
#  u'a',
#  u'poor',
#  u'devil',
#  u'of',
#  u'a',
#  u'sub',
#  u'-',
#  u'sub',
#  u'appear',
#  u'to',
#  u'hav',
#  u'gon',
#  u'through',
#  u'the',
#  u'long',
#  u'vat',
#  u'and',
#  u'street',
#  u'-',
#  u'stal',
#  u'of',
#  u'the',
#  u'ear',
#  u',',
#  u'pick',
#  u'up',
#  u'whatev',
#  u'random',
#  u'allud',
#  u'to',
#  u'whal',
#  u'he',
#  u'could',
#  u'anyway',
#  u'find',
#  u'in',
#  u'any',
#  u'book',
#  u'whatsoev',
#  u',',
#  u'sacr',
#  u'or',
#  u'prof',
#  u'.',
#  u'theref',
#  u'you',
#  u'must',
#  u'not',
#  u',',
#  u'in',
#  u'every',
#  u'cas',
#  u'at',
#  u'least',
#  u',',
#  u'tak',
#  u'the',
#  u'higgledy',
#  u'-',
#  u'piggledy',
#  u'whal',
#  u'stat',
#  u',',
#  u'howev',
#  u'auth',
#  u',',
#  u'in',
#  u'thes',
#  u'extract',
#  u',',
#  u'for',
#  u'verit',
#  u'gospel',
#  u'cetolog',
#  u'.',
#  u'far',
#  u'from',
#  u'it',
#  u'.',
#  u'as',
#  u'touch',
#  u'the',
#  u'ant',
#  u'auth',
#  u'gen',
#  u',',
#  u'as',
#  u'wel',
#  u'as',
#  u'the',
#  u'poet',
#  u'her',
#  u'appear',
#  u',',
#  u'thes',
#  u'extract',
#  u'ar',
#  u'sol',
#  u'valu',
#  u'or',
#  u'entertain',
#  u',',
#  u'as',
#  u'afford',
#  u'a',
#  u'glant',
#  u'bird',
#  u"'",
#  u's',
#  u'ey',
#  u'view',
#  u'of',
#  u'what',
#  u'has',
#  u'been',
#  u'promiscu',
#  u'said',
#  u',',
#  u'thought',
#  u',',
#  u'fant',
#  u',',
#  u'and',
#  u'sung',
#  u'of',
#  u'leviath',
#  u',',
#  u'by',
#  u'many',
#  u'nat',
#  u'and',
#  u'gen',
#  u',',
#  u'includ',
#  u'our',
#  u'own',
#  u'.',
#  u'so',
#  u'far',
#  u'the',
#  u'wel',
#  u',',
#  u'poor',
#  u'devil',
#  u'of',
#  u'a',
#  u'sub',
#  u'-',
#  u'sub',
#  u',',
#  u'whos',
#  u'com',
#  u'i',
#  u'am',
#  u'.',
#  u'thou',
#  u'belongest',
#  u'to',
#  u'that',
#  u'hopeless',
#  u',',
#  u'sallow',
#  u'trib',
#  u'which',
#  u'no',
#  u'win',
#  u'of',
#  u'thi',
#  u'world',
#  u'wil',
#  u'ev',
#  u'warm',
#  u';',
#  u'and',
#  u'for',
#  u'whom',
#  u'ev',
#  u'pal',
#  u'sherry',
#  u'would',
#  u'be',
#  u'too',
#  u'rosy',
#  u'-',
#  u'strong',
#  u';',
#  u'but',
#  u'with',
#  u'whom',
#  u'on',
#  u'sometim',
#  u'lov',
#  u'to',
#  u'sit',
#  u',',
#  u'and',
#  u'feel',
#  u'poor',
#  u'-',
#  u'devil',
#  u',',
#  u'too',
#  u';',
#  u'and',
#  u'grow',
#  u'conv',
#  u'upon',
#  u'tear',
#  u';',
#  u'and',
#  u'say',
#  u'to',
#  u'them',
#  u'blunt',
#  u',',
#  u'with',
#  u'ful',
#  u'ey',
#  u'and',
#  u'empty',
#  u'glass',
#  u',',
#  u'and',
#  u'in',
#  u'not',
#  u'altogeth',
#  u'unpleas',
#  u'sad',
#  u'--',
#  u'giv',
#  u'it',
#  u'up',
#  u',',
#  u'sub',
#  u'-',
#  u'sub',
#  u'!',
#  u'for',
#  u'by',
#  u'how',
#  u'much',
#  u'the',
#  u'mor',
#  u'pain',
#  u'ye',
#  u'tak',
#  u'to',
#  u'pleas',
#  u'the',
#  u'world',
#  u',',
#  u'by',
#  u'so',
#  u'much',
#  u'the',
#  u'mor',
#  u'shal',
#  u'ye',
#  u'for',
#  u'ev',
#  u'go',
#  u'thankless',
#  u'!',
#  u'would',
#  u'that',
#  u'i',
#  u'could',
#  u'clear',
#  u'out',
#  u'hampton',
#  u'court',
#  u'and',
#  u'the',
#  u'tuilery',
#  u'for',
#  u'ye',
#  u'!',
#  u'but',
#  u'gulp',
#  u'down',
#  u'yo',
#  u'tear',
#  u'and',
#  u'hie',
#  u'aloft',
#  u'to',
#  u'the',
#  u'roy',
#  u'-',
#  u'mast',
#  u'with',
#  u'yo',
#  u'heart',
#  u';',
#  u'for',
#  u'yo',
#  u'friend',
#  u'who',
#  u'hav',
#  u'gon',
#  u'bef',
#  u'ar',
#  u'clear',
#  u'out',
#  u'the',
#  u'sev',
#  u'-',
#  u'story',
#  u'heav',
#  u',',
#  u'and',
#  u'mak',
#  u'refug',
#  u'of',
#  u'long',
#  u'-',
#  u'pamp',
#  u'gabriel',
#  u',',
#  u'michael',
#  u',',
#  u'and',
#  u'raphael',
#  u',',
#  u'against',
#  u'yo',
#  u'com',
#  u'.',
#  u'her',
#  u'ye',
#  u'strike',
#  u'but',
#  u'splintered',
#  u'heart',
#  u'togeth',
#  u'--',
#  u'ther',
#  u',',
#  u'ye',
#  u'shal',
#  u'strike',
#  u'unsplint',
#  u'glass',
#  u'!',
#  u'extract',
#  u'.',
#  u'"',
#  u'and',
#  u'god',
#  u'cre',
#  u'gre',
#  u'whal',
#  u'."',
#  u'--',
#  u'genes',
#  u'.',
#  u'"',
#  u'leviath',
#  u'make',
#  u'a',
#  u'path',
#  u'to',
#  u'shin',
#  u'aft',
#  u'him',
#  u';',
#  u'on',
#  u'would',
#  u'think',
#  u'the',
#  u'deep',
#  u'to',
#  u'be',
#  u'hoary',
#  u'."',
#  u'--',
#  u'job',
#  u'.',
#  u'"',
#  u'now',
#  u'the',
#  u'lord',
#  u'had',
#  u'prep',
#  u'a',
#  u'gre',
#  u'fish',
#  u'to',
#  u'swallow',
#  u'up',
#  u'jonah',
#  u'."',
#  u'--',
#  u'jonah',
#  u'.',
#  u'"',
#  u'ther',
#  u'go',
#  u'the',
#  u'ship',
#  u';',
#  u'ther',
#  u'is',
#  u'that',
#  u'leviath',
#  u'whom',
#  u'thou',
#  u'hast',
#  u'mad',
#  u'to',
#  u'play',
#  u'therein',
#  u'."',
#  u'--',
#  u'psalm',
#  u'.',
#  u'"',
#  u'in',
#  u'that',
#  u'day',
#  u',',
#  u'the',
#  u'lord',
#  u'with',
#  u'his',
#  u'sor',
#  u',',
#  u'and',
#  u'gre',
#  u',',
#  u'and',
#  u'strong',
#  u'sword',
#  u',',
#  u'shal',
#  u'pun',
#  u'leviath',
#  u'the',
#  u'pierc',
#  u'serp',
#  u',',
#  u'ev',
#  u'leviath',
#  u'that',
#  u'crook',
#  u'serp',
#  u';',
#  u'and',
#  u'he',
#  u'shal',
#  u'slay',
#  u'the',
#  u'dragon',
#  u'that',
#  u'is',
#  u'in',
#  u'the',
#  u'sea',
#  u'."',
#  u'--',
#  u'isaiah',
#  u'"',
#  u'and',
#  u'what',
#  u'thing',
#  u'soev',
#  u'besid',
#  u'come',
#  u'within',
#  u'the',
#  u'chao',
#  u'of',
#  u'thi',
#  u'monst',
#  u"'",
#  u's',
#  u'mou',
#  u',',
#  u'be',
#  u'it',
#  u'beast',
#  u',',
#  u'boat',
#  u',',
#  u'or',
#  u'ston',
#  u',',
#  u'down',
#  u'it',
#  u'goe',
#  u'al',
#  u'incontin',
#  u'that',
#  u'foul',
#  u'gre',
#  u'swallow',
#  u'of',
#  u'his',
#  u',',
#  u'and',
#  u'perishe',
#  u'in',
#  u'the',
#  u'bottomless',
#  u'gulf',
#  u'of',
#  u'his',
#  u'paunch',
#  u'."',
#  u'--',
#  u'holland',
#  u"'",
#  u's',
#  u'plutarch',
#  u"'",
#  u's',
#  u'mor',
#  u'.',
#  u'"',
#  u'the',
#  u'ind',
#  u'sea',
#  u'breede',
#  u'the',
#  u'most',
#  u'and',
#  u'the',
#  u'biggest',
#  u'fish',
#  u'that',
#  u'ar',
#  u':',
#  u'among',
#  u'which',
#  u'the',
#  u'whal',
#  u'and',
#  u'whirlpool',
#  u'cal',
#  u'bala',
#  u',',
#  u'tak',
#  u'up',
#  u'as',
#  u'much',
#  u'in',
#  u'leng',
#  u'as',
#  u'four',
#  u'acr',
#  u'or',
#  u'arp',
#  u'of',
#  u'land',
#  u'."',
#  u'--',
#  u'holland',
#  u"'",
#  u's',
#  u'pliny',
#  u'.',
#  u'"',
#  u'scarc',
#  u'had',
#  u'we',
#  u'process',
#  u'two',
#  u'day',
#  u'on',
#  u'the',
#  u'sea',
#  u',',
#  u'when',
#  u'about',
#  u'sunr',
#  u'a',
#  u'gre',
#  u'many',
#  u'whal',
#  u'and',
#  u'oth',
#  u'monst',
#  u'of',
#  u'the',
#  u'sea',
#  u',',
#  u'appear',
#  u'.',
#  u'among',
#  u'the',
#  u'form',
#  u',',
#  u'on',
#  u'was',
#  u'of',
#  u'a',
#  u'most',
#  u'monst',
#  u'siz',
#  u'.',
#  u'...',
#  u'thi',
#  u'cam',
#  u'toward',
#  u'us',
#  u',',
#  u'op',
#  u'-',
#  u'mouth',
#  u',',
#  u'rais',
#  u'the',
#  u'wav',
#  u'on',
#  u'al',
#  u'sid',
#  u',',
#  u'and',
#  u'beat',
#  u'the',
#  u'sea',
#  u'bef',
#  u'him',
#  u'into',
#  u'a',
#  u'foam',
#  u'."',
#  u'--',
#  u'took',
#  u"'",
#  u's',
#  u'luc',
#  u'.',
#  u'"',
#  u'the',
#  u'tru',
#  u'hist',
#  u'."',
#  u'"',
#  u'he',
#  u'visit',
#  u'thi',
#  u'country',
#  u'also',
#  u'with',
#  u'a',
#  u'view',
#  u'of',
#  u'catch',
#  u'hors',
#  u'-',
#  u'whal',
#  u',',
#  u'which',
#  u'had',
#  u'bon',
#  u'of',
#  u'very',
#  u'gre',
#  u'valu',
#  u'for',
#  u'their',
#  u'tee',
#  u',',
#  u'of',
#  u'which',
#  u'he',
#  u'brought',
#  u'som',
#  u'to',
#  u'the',
#  u'king',
#  u'.',
#  u'...',
#  u'the',
#  u'best',
#  u'whal',
#  u'wer',
#  u'catch',
#  u'in',
#  u'his',
#  u'own',
#  u'country',
#  u',',
#  u'of',
#  u'which',
#  u'som',
#  u'wer',
#  u'forty',
#  u'-',
#  u'eight',
#  u',',
#  u'som',
#  u'fifty',
#  u'yard',
#  u'long',
#  u'.',
#  u'he',
#  ...]

# %% [markdown]
# # Words that characterize the branches
#
# In the exercise we'll use a very simple weighting scheme called TF-IDF to find the important words within each branch of philosophy (according to wikipedia).
#
# **First**, check out the wikipedia page for [TF-IDF](https://en.wikipedia.org/wiki/Tf%E2%80%93idf). Explain in your own words the point of TF-IDF.
#     - What does TF stand for?
#     - What does IDF stand for?
#
# **Point of tf-idf** is to evaluate numerically how important a word is to a document in a collection or corpus. The ft-df value increases proportionally to the number of times a word appears in the document, but is often offset by the frequency of the word in the corpus, which helps to adjust for the fact that some words appear more frequently in general.
#
# tf-idf is the product of two statistics, term frequency and inverse document frequency. Note that there are various ways for determining the exect values of both statistics.
#
# **Term frequency** tf(t,d), the simplest choice is to use the raw count of a term in a document, i.e. the number of times that term t occurs in document d. There are some other possibilities to evaluate the term frequency which can be found in the wikipedia page.
#
# ** Inverse document frequency** is a measure of how much information the word provides, that is, whether the term is common or rare accross all documents. It is the logarithmically scaled inverse fraction of the documents that contain the word, obtained by dividing the total number of documents by number of documents containing the term, and then taking the logarithm of that quotient. See [wikipage](https://en.wikipedia.org/wiki/Tf%E2%80%93idf) for detail about equaltion

# %% [markdown]
# **Since we want to find out which words are important for each branch, so we're going to create six large documents, one per branch of philosophy. Tokenize the pages, and combine the tokens into one long list per branch. Remember the bullets below for success**

# %% [markdown]
# **1.** We start by getting the philosophers name and maintain the information about each philosopher in a dictionary

# %%
import urllib2
import re

philosophers = {
    "aestheticians":{
        "title":"title=List_of_aestheticians",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    },
    "epistemologists":{
        "title":"title=List_of_epistemologists",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    },
    "ethicists":{
        "title":"title=List_of_ethicists",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    },
    "logicians":{
        "title":"title=List_of_logicians",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    },
    "metaphysicians":{
        "title":"title=List_of_metaphysicians",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    },
    "social and political philosophers":{
        "title":"title=Index_of_sociopolitical_thinkers",
        "names":"",
        "tokens":[],
        "tf":[],
        "idf":[]
    }
}

#'https://en.wikipedia.org/w/index.php?title=List_of_aestheticians&action=edit'

# set the parameters (explained in detail here https://www.mediawiki.org/wiki/API:Tutorial)
baseurl = "https://en.wikipedia.org/w/index.php?"
title = ""
action = "action=edit"

for i in philosophers:
    # construct the query
    query = "{}{}&{}".format(
    baseurl,
    philosophers[i]["title"],
    action)
    # use urllib and regex to get the list of philosophers
    wikiresponse = urllib2.urlopen(query)
    wikisource = wikiresponse.read()
    philosophers[i]["names"] = re.findall(r'\*.*?\[\[(.*?)[\]\|]', wikisource)

# Because the last 4 elements of the ethicists list and social and political philosophers are not philosophers
# they are left out
philosophers["ethicists"]["names"] = philosophers["ethicists"]["names"][:-4]
philosophers["social and political philosophers"]["names"] = philosophers["social and political philosophers"]["names"][:-4]

# Get all philosophers into one list
all_philo = []
for i in philosophers:
    all_philo = all_philo + philosophers[i]["names"]
all_philo = set(all_philo) # erase all duplicates

# %% [markdown]
# **2.** Next we go through all of the philosophers in each branch and we create a large document for each brand. Therefore we end up with six large documents that contain all the text of each brands philosopher´s wikipedia pages. The workflow is as follows:
#     - Tokenize the pages
#     - combine the tokens into a long list per branch

# %%
import json
import io
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords


run = True

if run :
    # set the parameters for the query (explained in detail here https://www.mediawiki.org/wiki/API:Tutorial)
    baseurl = "https://en.wikipedia.org/w/api.php?"
    actions = "action=query"
    title = "titles="
    #content = "prop=revisions&rvprop=content"
    content = "prop=extracts&exlimit=max&explaintext&rvprop=content"
    dataformat = "format=json"


    # iterate through the philosophers and for each philosphers download his wikipedia page
    # The list comprehension goes through the list of philosophers and replaces " " for "_"
    for philo in [name.replace(" ","_") for name in set(all_philo)]:
        query = "{}{}&{}{}&{}&{}".format(baseurl,actions,title,philo.replace(" ","_"),content,dataformat)
        print query
        wikiresponse = urllib2.urlopen(query)
        wikisource = json.loads(wikiresponse.read())

        # Create the uri for the file in the os file system
        fileUri = "/Users/GretarAtli/Dropbox/Dtu/Social_graphs_and_interactions/Philosophers_text/{}.txt".format(philo)
        #print fileUri
        f = io.open(fileUri, 'w', encoding='utf-8')
        f.write(unicode(json.dumps(wikisource)))
# Out:
# https://en.wikipedia.org/w/api.php?action=query&titles=Eli_Siegel&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Marsilius_of_Inghen&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Solomon_Passy&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hans_Pfitzner&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Mazen_Asfour&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Dong_Zhongshu&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Tenzin_Gyatso&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Moses&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Houston_Stewart_Chamberlain&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Roderick_Long&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Miguel_A._De_La_Torre&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Plato&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ruqaiya_Hasan&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Nosson_Tzvi_Finkel_(Slabodka)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Oswald_von_Nell-Breuning&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=J._M._E._McTaggart&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Holly_Martin_Smith&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Garlandus_Compotista&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_D._Friedman&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Makinson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Chanakya&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Kazimierz_Twardowski&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Michael_A._Smith&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Socrates&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Roberto_Mangabeira_Unger&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Giorgi_Japaridze&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Luitzen_Egbertus_Jan_Brouwer&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Richard_Routley&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Blaise_Pascal&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hilary_Kornblith&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Milo_Yiannopoulos&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Franco_Burgersdijk&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Mani_Kaul&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Lewis_H._Morgan&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Gregory_Chaitin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Leonard_Peikoff&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Arthur_Danto&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Mozi&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Monroe_Beardsley&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Virilio&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Stanisław_Leśniewski&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=William_K._Frankena&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Heraclitus&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ernst_Bloch&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Richard_Milton_Martin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_of_Spain_(author)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Igor_Pribac&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Axel_Honneth&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Martin_Buber&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Walter_Benjamin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Graham_Priest&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Conimbricenses&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Rada_Iveković&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Thomas_Nagel&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Mary_Daly&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=B._F._Skinner&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Julian_Gumperz&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Kateb&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Petrus_Ramus&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ehud_Hrushovski&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=G._E._M._Anscombe&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Marianne_Weber&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Samuel_Bailey&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jeffrey_Friedman_(political_scientist)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Cantor&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Bernard_Bolzano&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Max_Scheler&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=William_Alvin_Howard&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ruth_Benedict&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Henry_David_Thoreau&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Gilbert_de_la_Porrée&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Arthur_Moeller_van_den_Bruck&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Harriet_Taylor_Mill&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Nicolas_Malebranche&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hayashi_Razan&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Dag_Prawitz&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Michael_Oakeshott&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Frank_Meyer_(political_philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Chaïm_Perelman&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=R._M._Hare&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=C._D._Broad&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hans_Kelsen&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Xenocrates&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jack_Russell_Weinstein&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Richard_M._Weaver&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=James_Joyce&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_ibn_Daud&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Bjarni_Jónsson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Giacomo_Marramao&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Robert_M._Solovay&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alfred_Horn&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Austin_Osman_Spare&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Gottfried_Leibniz&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Sherrilyn_Roush&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Stefan_Molyneux&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Parmenides&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Noel_Preston&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Shadworth_Hodgson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Shelly_Kagan&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Thomas_Berry&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Friedrich_Nietzsche&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jack_Copeland&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Yusuf_Balasagun&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Etienne_Gilson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Isaac_Malitz&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Lunenfeld&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Catherine_Elgin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jerzy_Łoś&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Anton_Friedrich_Ast&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Raymond_Frey&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Þorsteinn_Gylfason&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Cage&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hermann_Theodor_Hettner&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Robert_Kowalski&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Walter_Burley&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Fazlur_Rahman&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Nigel_Warburton&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Philo_the_Dialectician&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Lauri_Ingman&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Étienne_de_La_Boétie&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jeff_Paris&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Cicero&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Wilhelm_Friedrich_Hegel&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_R._Steel&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Longinus_(literature)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Adolf_Hitler&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ronald_Paulson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Lucius_Annaeus_Seneca&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jawaharlal_Nehru&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jules_Vuillemin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Claudio_Canaparo&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Damon_Young&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Cornelius_Castoriadis&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Theodore_Slaman&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Giorgio_Del_Vecchio&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Lennart_Åqvist&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Steven_Poole&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Slavoj_Žižek&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alice_Crary&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Kenneth_Kunen&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Lamborn_Wilson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Raúl_Prebisch&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Hospers&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jessica_Wilson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Nomy_Arpaly&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Pierre_Bourdieu&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Leon_Chwistek&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Karl_Immanuel_Nitzsch&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Franz_Xaver_von_Baader&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Richard_Kilvington&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Galileo_Galilei&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Reinhold_Niebuhr&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Diodorus_Cronus&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Allan_Gibbard&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Xun_Kuang&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Johann_Albert_Fabricius&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Shmuel_Alexandrov&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Marcion_of_Sinope&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Martin_Löb&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Andrzej_Tadeusz_Kijowski&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Kaplan_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Michael_Fourman&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Moses_Schönfinkel&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Guy_Debord&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Arthur_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Edgar_Allan_Poe&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Har_Dayal&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Max_Stirner&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexander_Gottlieb_Baumgarten&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Phillip_H._Wiebe&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Malet_Armstrong&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Marilyn_McCord_Adams&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Carl_Schmitt&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Józef_Maria_Bocheński&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Anderson_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Tara_Smith_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Proclus_Lycaeus&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=William_Craig_(logician)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Mao_Zedong&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=James_Frederick_Ferrier&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Bruce_Lee&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Bohm&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Carew_Arthur_Meredith&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Julia_Driver&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Robert_Merrihew_Adams&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Michael_A._E._Dummett&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jean_Grondin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ronald_Dworkin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Penelope_Maddy&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Julia_Annas&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Cornel_West&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=W.K._Wimsatt&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Nelson_Goodman&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Gerhard_Gentzen&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Frank_Sibley_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Searle&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jacques_Maritain&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Vernon_Lee&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=William_of_Ockham&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Kellogg_Lewis&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Milan_Kangrga&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_M._Cooper_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Pyotr_Novikov&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Lon_L._Fuller&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Oskar_Negt&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Howard_Zinn&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Oliver_Wendell_Holmes,_Jr.&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ralf_Dahrendorf&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Richard_Wollheim&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Robert_Nozick&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_of_Venice&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Dugald_Macpherson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Dewey&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Gualtiero_Piccinini&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Xun_Zi&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Austin_(legal_philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Eric_Voegelin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Duncan_Kennedy_(legal_philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ivan_Sviták&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Charles_Sanders_Peirce&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Fujiwara_Seika&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Maimonides&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=William_Fontaine&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Umberto_Eco&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Per_Martin-Löf&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Daniel_Brock&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jean-Yves_Girard&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Adrian_Johnston_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Bertrand_Russell&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Aldo_Leopold&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ludwig_Wittgenstein&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Andrzej_Mostowski&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hans_Köchler&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alain_Badiou&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ludwig_von_Mises&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ismail_Raji'_al-Faruqi&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ernest_Wamba_dia_Wamba&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Hawthorne&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Richard_Ferrybridge&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Andrei_Marga&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Kurt_Schütte&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Vilfredo_Pareto&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Wesley_Newcomb_Hohfeld&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Democritus&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Giorgio_Agamben&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Octave_Mirbeau&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Antoine_Garaby_de_La_Luzerne&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Moshe_Chaim_Luzzatto&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Bruno_Leoni&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Monarchomachs&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Rushworth_Kidder&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jean_Anthelme_Brillat-Savarin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Edward_Nelson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ferruccio_Busoni&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Carl_Joachim_Friedrich&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Miller_(political_theorist)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Anandavardhana&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Tudor_Vianu&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jacques_Lacan&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_von_Neumann&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jeremy_Bentham&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=António_Castanheira_Neves&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Martha_Nussbaum&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hao_Wang_(academic)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Paolo_Virno&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Michael_Novak&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alvin_Goldman&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Tony_Honoré&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Pierre-André_Taguieff&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Friedrich_Strauss&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Geach&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Carrie_Ichikawa_Jenkins&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jean_Nicod&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=William_Ernest_Johnson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Nuel_Belnap&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Margaret_Canovan&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Yehoshua_Bar-Hillel&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Pappas&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Liu_Xie&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Karl_Marx&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Kolb&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Simplicius_of_Cilicia&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Julien_Offray_de_La_Mettrie&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Sol_Garfunkel&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Simone_Weil&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Leo_Harrington&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Mario_Tronti&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=G._E._Moore&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Wolfgang_Smith&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Victor_Basch&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Algernon_Charles_Swinburne&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Leonard_Borgzinner&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Moritz_Schlick&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Mihailo_Marković&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Judith_Butler&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Nicolas_Bourbaki&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Abhinavagupta&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Claude_Lefort&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Robert_S._Hartman&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Umar_bin_al-Khattab&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Zhuang_Zhou&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Emma_Rush&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Peters_Humphrey&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Heinz_von_Foerster&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Zalman_Schachter-Shalomi&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Pearce_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Holmes_Howison&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Julian_Savulescu&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexander_S._Kechris&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Muhammad_Iqbal&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Eduard_Hanslick&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Mohandas_Gandhi&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Karel_Lambert&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Raghunatha_Siromani&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Joachim_Lambek&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Thomas_Henry_Huxley&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alija_Izetbegović&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Wiggins&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Hume&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Zeno_of_Elea&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Francis_Jeffrey&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Harold_Bloom&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Anne_Sjerp_Troelstra&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Nader_El-Bizri&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jean_Piaget&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Edmund_Gettier&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jonathan_Dancy&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ghazali&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Voltaire&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=James_Earl_Baumgartner&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ernst_Zermelo&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_William_Miller&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=W._D._Ross&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Corcoran_(logician)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Confucius&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Averroes&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jean_Bodin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Howard_Jerome_Keisler&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Rosa_Luxemburg&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Rudolf_Steiner&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alan_Bundy&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Kivy&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Bahya_ibn_Paquda&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=W.V.O._Quine&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Langdon_Winner&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Yamaga_Sokō&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Niklas_Luhmann&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Per_Bauhn&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Lucretius&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Mohandas_Karamchand_Gandhi&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Gilbert_Simondon&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# ...
# https://en.wikipedia.org/w/api.php?action=query&titles=Richard_Brinkley&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Birkhoff&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Thomas_Hill_Green&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ralph_Strode&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Henri_Lefebvre&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jacob_M._Appel&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Raya_Dunayevskaya&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Walter_Terence_Stace&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Robert_Lawson_Vaught&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hui_Shi&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=René_Descartes&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jean_Van_Heijenoort&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jane_Jacobs&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Max_Black&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_McDowell&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Kaibara_Ekken&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Claude_Lévi-Strauss&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=James_Brusseau&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Richard_Meltzer&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Montesquieu&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Constantin_Rădulescu-Motru&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Edward_Said&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Edmund_Gurney&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jay_Rosenberg&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Toju_Nakae&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Carlos_Santiago_Nino&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Charles_Taylor_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Fred_Poché&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Dov_Gabbay&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Lorenzo_Peña&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jean-Jacques_Rousseau&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Mikelis_Avlichos&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Henry_Home,_Lord_Kames&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jean-François_Lyotard&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hans-Georg_Gadamer&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=William_Sweet&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_Joshua_Heschel&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Sosa&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jaakko_Hintikka&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Henri_Focillon&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Bahmanyār&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=André_Malraux&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Victor_Gollancz&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hugo_Grotius&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Victor_Cousin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Solomon_Feferman&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Menedemus&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexander_Campbell_Fraser&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Per_Lindström&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Manuel_De_Landa&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Israel_Kirzner&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Pagus&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Thoralf_Skolem&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Wilhelm_Dilthey&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Rainer_Forst&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Wau_Holland&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Trenton_Merricks&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Leo_Tolstoy&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Abelard&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Samuel_Edward_Konkin_III&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=John_Major_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Lewis_Carroll&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Grigori_Mints&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Arthur_Prior&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Stephen_Cole_Kleene&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Théodore_Simon_Jouffroy&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Tillich&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Jacopo_Zabarella&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Augustine_of_Hippo&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Andronicus_of_Rhodes&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Arthur_Schopenhauer&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Kazimierz_Ajdukiewicz&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_Robinson&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ashoka&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alfred_Rosenberg&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Thomas_Hobbes&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Nick_Bostrom&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Unger&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Gary_Chartier&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ambrose&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Goldie&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hans-Hermann_Hoppe&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Cohen_(mathematician)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Yamazaki_Ansai&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Pierre_Teilhard_de_Chardin&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Bertrand_de_Jouvenel&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Prodicus&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hugh_MacColl&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Isaac_Watts&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Noam_Chomsky&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Hsun_Tzu&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Friedrich_Schleiermacher&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Gilles_Deleuze&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ernest_Sosa&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Alfred_Tarski&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Harriet_Martineau&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Abul_Kalam_Azad&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Dirk_van_Dalen&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Antonio_Negri&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Albert_of_Saxony_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Harry_Binswanger&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Willard_Van_Orman_Quine&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Benjamin_Wiker&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Bob_Meyer_(logician)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Julius_Binder&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Anne_Conway_(philosopher)&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Ayn_Rand&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Glassen&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Carlo_Lottieri&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Rudolf_Carnap&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Johann_Georg_Walch&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Daniel_Wikler&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Thomas_Reid&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=S._Barry_Cooper&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Philip_Mazzei&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Dimitris_Dimitrakos&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json
# https://en.wikipedia.org/w/api.php?action=query&titles=Karl_Wilhelm_Ferdinand_Solger&prop=extracts&exlimit=max&explaintext&rvprop=content&format=json

# %%
baseurl = "https://en.wikipedia.org/w/api.php?"
actions = "action=query"
title = "titles="
#content = "prop=revisions&rvprop=content"
content = "prop=extracts&exlimit=max&explaintext&rvprop=content"
dataformat = "format=json"


# iterate through each philosophers brand
# The list comprehension goes through the list of philosophers and replaces " " for "_"
for brand in philosophers:
    for philosopher in philosophers[brand]["names"]:
        #-------- CODE TO GET TEXT DIRECTLY FROM URL ----------
        #query = "{}{}&{}{}&{}&{}".format(baseurl,actions,title,philosopher.replace(" ","_"),content,dataformat)
        #print query
        
        # Get the page data in json format
        #wikiresponse = urllib2.urlopen(query)
        #wikisource = json.loads(wikiresponse.read())
        
        #--------- CODE TO GET TEXT FROM FILE ----------
        # Create the uri for the file in the os file system
        fileUri = "/Users/GretarAtli/Dropbox/Dtu/Social_graphs_and_interactions/Philosophers_text/{}.txt".format(philosopher.replace(" ","_"))

        # Open the file and get the content 
        print philosopher
        file = open(fileUri,'r') 
    
        try:
            # Drill down the json to get only the text of each page
            wikisource = json.loads(file.read())
            text = wikisource["query"]["pages"].values()[0]['extract'].lower().encode("utf-8")
             
        except BaseException:
            print "{} has an empty wikipedia page".format(philosopher)
            continue
        
        # We start by excluding the philosopher names from the text
        for philo in all_philo:
            text = text.replace(philo.lower(),"")

        # Next we clean the data by removing all \n \\n and \\u from the text.
        text = re.sub(r"\n+"," ",text)
        text = re.sub(r"\\n+"," ",text)
        text = re.sub(r"\\u+"," ",text)

        tokenizer = RegexpTokenizer(r'\w+')  # We choose to use regularexpression tokenizer
        tokens = tokenizer.tokenize(text) # Get all tokens with the tokenizer
        # filter out the stop words and digits
        filtered_words = [w for w in tokens if not w in stopwords.words('english') if not w.isdigit()] 

        # Get unique set of the words
        filtered_words =  set(filtered_words)

        # Add the tokens from this specific wikipage to the dictionary
        philosophers[brand]["tokens"] = philosophers[brand]["tokens"] + list(filtered_words)
# Out:
# Abraham Joshua Heschel
# /Users/GretarAtli/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:50: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
# Abul Kalam Azad
# Adam Müller
# Adolf Hitler
# Adrian Johnston (philosopher)
# Alan Carter (philosopher)
# Alan Ryan
# Alastair Norcross
# Alexander of Aphrodisias
# Alexis de Tocqueville
# Alfred Rosenberg
# Al-Ghazali
# Ali Shariati
# Alon Ben-Meir
# Andrei Marga
# António Castanheira Neves
# Antonio Negri
# Aristotle
# Armin Mohler
# Arthur Linton Corbin
# Arthur Moeller van den Bruck
# Auberon Herbert
# Averroes
# Axel Honneth
# Ayn Rand
# Benjamin Tucker
# Bertrand de Jouvenel
# Bertrand Russell
# B. R. Ambedkar
# Boris Furlan
# Bruce Lee
# Bruno Leoni
# Bryan Caplan
# Carl Joachim Friedrich
# Carl Schmitt
# Carlo Lottieri
# Chanakya
# Charles C. Ragin
# Charles Taylor (philosopher)
# C. Wright Mills
# Cheng Hao
# Cheng Yi (philosopher)
# Cicero
# Claude Lefort
# Claude Lévi-Strauss
# Claudio Canaparo
# Confucius
# Constantin Rădulescu-Motru
# Cornel West
# Cornelius Castoriadis
# Costas Douzinas
# Dana Ward
# Daniel Guérin
# David D. Friedman
# David Hume
# David Kolb
# David Miller (political theorist)
# David Prychitko
# Democritus
# Dimitris Dimitrakos
# Disciples of Confucius
# Dong Zhongshu
# Duncan Kennedy (legal philosopher)
# Edmund Burke
# Edward Burnett Tylor
# Edward Said
# Emma Goldman
# Enrique Dussel
# Eric Voegelin
# Ernest Wamba dia Wamba
# Ernst Bloch
# Étienne de La Boétie
# Eugen Rosenstock-Huessy
# Félix Guattari
# Felix Kaufmann
# Ferdinand de Saussure
# Francesco D'Andrea
# Francis Bacon
# Francis Fukuyama
# Francis Parker Yockey
# Frank Meyer (political philosopher)
# Franz Boas
# Frédéric Bastiat
# Fred Poché
# Friedrich Engels
# Friedrich Hayek
# Friedrich Schleiermacher
# Fujiwara Seika
# Gary Chartier
# Gene Callahan (economist)
# Gene Callahan (economist) has an empty wikipedia page
# Georg Jellinek
# Georg Wilhelm Friedrich Hegel
# George Kateb
# George Ohsawa
# Georges Bataille
# Gerald Cohen
# Gerald Dworkin
# Gerrard Winstanley
# Giacomo Marramao
# Giambattista Vico
# Gianfranco Sanguinetti
# Giannina Braschi
# Giorgio Agamben
# Giorgio Del Vecchio
# Gottfried Leibniz
# Gustave de Molinari
# Guy Aldred
# Guy Debord
# H. B. Acton
# H. L. A. Hart
# Han Fei
# Han Ryner
# Hannah Arendt
# Hans Achterhuis
# Hans-Hermann Hoppe
# Hans Kelsen
# Hans Köchler
# Hans Singer
# Har Dayal
# Harriet Martineau
# Harriet Taylor Mill
# Hayashi Razan
# Hendrik Verwoerd
# Henri Lefebvre
# Henry David Thoreau
# Henry George
# Henry Home, Lord Kames
# Henry Pachter
# Henry Sidgwick
# Herbert Spencer
# Herman Oliphant
# Hirata Atsutane
# Horace Romano Harré
# Houston Stewart Chamberlain
# Howard Zinn
# Hugo Grotius
# Igor Pribac
# Immanuel Kant
# Inayatullah Khan Mashriqi
# Iris Marion Young
# Isabel Paterson
# Isaiah Berlin
# Israr Ahmed
# Itō Jinsai
# Ivan Sviták
# J. J. C. Smart
# Jacques Lacan
# Jacques Rancière
# Jack Russell Weinstein
# James Brusseau
# James Tully (philosopher)
# Jamie Whyte
# Janet Biehl
# Janet Coleman
# Jawaharlal Nehru
# Jean Bodin
# Jean-François Lyotard
# Jean-Jacques Rousseau
# Jeffrey Friedman (political scientist)
# Jeremy Bentham
# John Austin (legal philosopher)
# John Burnheim
# John Finnis
# John Hospers
# John Locke
# John Oswald (activist)
# John Rawls
# John Searle
# John Stuart Mill
# John William Miller
# John Zerzan
# Jonathan Wolff (philosopher)
# Joseph de Torre
# Joseph Priestley
# Joseph Raz
# Joshua Cohen (philosopher)
# Joxe Azurmendi
# Judith Butler
# Julian Gumperz
# Julien Offray de La Mettrie
# Julius Binder
# Jürgen Habermas
# Kaibara Ekken
# Karl Loewenstein
# Karl Marx
# Karl Popper
# Karl-Otto Apel
# Kevin Carson
# Langdon Winner
# Leonard Borgzinner
# Leonard Read
# Leonidas Donskis
# Lewis Call
# Lewis H. Morgan
# Lon L. Fuller
# Loren Lomasky
# Lorenzo Peña
# Louis Althusser
# Ludwig von Mises
# Lysander Spooner
# Magnus Hundt
# Manuel De Landa
# Mao Zedong
# Margaret Canovan
# Margaret Mead
# Marianne Weber
# Mario Bunge
# Mario Tronti
# Martha Nussbaum
# Martin Luther King, Jr.
# Maurice Brinton
# Maurice Cranston
# Max Baginski
# Max Horkheimer
# Max Stirner
# Max Weber
# Mazdak
# Mencius
# Michael Davis (philosopher)
# Michael Novak
# Michael Oakeshott
# Michael Otsuka
# Michel Foucault
# Michel Onfray
# Mihailo Marković
# Mikelis Avlichos
# Mikhail Bakunin
# Milan Kangrga
# Milo Yiannopoulos
# Mohandas Karamchand Gandhi
# Monarchomachs
# Montesquieu
# Mortimer Adler
# Mozi
# Muhammad Asad
# Muhammad Iqbal
# Murray Bookchin
# Murray Rothbard
# Nancy Cartwright (philosopher)
# Nestor Makhno
# Niccolò Machiavelli
# Nigel Warburton
# Noam Chomsky
# Norbert Bolz
# Norbert Leser
# Octave Mirbeau
# Ogyū Sorai
# Oliver Wendell Holmes, Jr.
# Oskar Negt
# Otto Casmann
# Paolo Virno
# Paul R. Patton
# Paul Virilio
# Pekka Himanen
# Per Bauhn
# Peter Kropotkin
# Peter Lamborn Wilson
# Peter Sloterdijk
# Phaleas of Chalcedon
# Philip Mazzei
# Philip Pettit
# Philippe Van Parijs
# Pierre Bourdieu
# Pierre-André Taguieff
# Plato
# Polybius
# Rada Iveković
# Rainer Forst
# Ralf Dahrendorf
# Raúl Prebisch
# Raya Dunayevskaya
# Raymond Geuss
# René Girard
# Richard M. Weaver
# Right Hegelians
# Robert K. Merton
# Roberto Esposito
# Robert Nozick
# Robert P. George
# Robert Paul Wolff
# Roberto Mangabeira Unger
# Roderick Long
# Ronald Dworkin
# Rosa Luxemburg
# Ruqaiya Hasan
# Russell Kirk
# Ruth Benedict
# Samuel Edward Konkin III
# Serge Moscovici
# Shmuel Alexandrov
# Simone Weil
# Slavoj Žižek
# Spencer Heath
# Stephen Bronner
# Sun Tzu
# Sun Yat-sen
# T. M. Scanlon
# Takis Fotopoulos
# Talcott Parsons
# Tan Sitong
# Tara Smith (philosopher)
# Theodor Sternberg
# Theodor W. Adorno
# Thiruvalluvar
# Thomas Aquinas
# Thomas Hill Green
# Thomas Hobbes
# Thomas Nagel
# Þorsteinn Gylfason
# Thucydides
# Todd May
# Toju Nakae
# Tony Honoré
# Tripp York
# Umar bin al-Khattab
# Vilfredo Pareto
# Voltaire
# Voltairine de Cleyre
# Walter Benjamin
# Warren Buffett
# Wesley Newcomb Hohfeld
# Wilhelm Dilthey
# William Fontaine
# William James
# William Lloyd Garrison
# William Paley
# William Sweet
# Wu Enyu
# Xun Zi
# Yamaga Sokō
# Yamazaki Ansai
# Yi I
# Young Hegelians
# Zhuang Zhou
# Virgil Aldrich
# Anandavardhana
# Sri Aurobindo
# John Anderson (philosopher)
# Yves Marie André
# Thomas Aquinas
# Aristotle
# Rudolf Arnheim
# Mazen Asfour
# Georg Anton Friedrich Ast
# Augustine of Hippo
# Jody Azzouni
# Abhinavagupta
# Victor Basch
# Yusuf Balasagun
# Roland Barthes
# Georges Bataille
# Alexander Gottlieb Baumgarten
# Monroe Beardsley
# Vissarion Belinsky
# Clive Bell
# Walter Benjamin
# Arnold Berleant
# George Birkhoff
# Max Black
# Maurice Blanchot
# Harold Bloom
# Georg Brandes
# Jean Anthelme Brillat-Savarin
# Ferruccio Busoni
# John Cage
# Cesare Brandi
# Stanley Cavell
# R. G. Collingwood
# Victor Cousin
# Benedetto Croce
# Gregory Currie
# Arthur Danto
# William C. Dowling
# John Dewey
# Jacques Derrida
# Umberto Eco
# Jonathan Edwards (theologian)
# Ralph Waldo Emerson
# Jerry Farber
# Valentin Feldman
# Henri Focillon
# Michel Foucault
# Hans-Georg Gadamer
# Alexander Gerard
# Nelson Goodman
# Edmund Gurney
# Etienne Gilson
# Paul Häberlin
# Garry Hagberg
# Ferdinand Gotthelf Hand
# Eduard Hanslick
# Georg Wilhelm Friedrich Hegel
# François Hemsterhuis
# Johann Friedrich Herbart
# Johann Gottfried Herder
# Hermann Theodor Hettner
# John Hospers
# Heinrich Gustav Hotho
# David Hume
# Francis Hutcheson (philosopher)
# Francis Ernest Jackson
# Christopher Janaway
# James Joyce
# Immanuel Kant
# Mani Kaul
# Søren Kierkegaard
# Peter Kivy
# Andrzej Tadeusz Kijowski
# Joseph Kosuth
# Susanne Langer
# Vernon Lee
# Gotthold Ephraim Lessing
# Jerrold Levinson
# Liu Xie
# Longinus (literature)
# Peter Lunenfeld
# Jean-François Lyotard
# György Lukács
# John Maeda
# André Malraux
# Jacques Maritain
# Georg Mehlis
# Richard Meltzer
# Theodor Mundt
# Friedrich Nietzsche
# Michael Oakeshott
# Lalita Pandit
# Walter Pater
# Ronald Paulson
# Hans Pfitzner
# Plato
# Edgar Allan Poe
# Steven Poole
# Ayn Rand
# Thomas Reid
# John Ruskin
# George Santayana
# Friedrich Wilhelm Joseph von Schelling
# Friedrich Schiller
# August Wilhelm Schlegel
# Karl Wilhelm Friedrich von Schlegel
# Arthur Schopenhauer
# Roger Scruton
# Calvin Seerveld
# Richard Shusterman
# Frank Sibley (philosopher)
# Eli Siegel
# Guy Sircello
# Karl Wilhelm Ferdinand Solger
# Karl Wilhelm Ferdinand Solger has an empty wikipedia page
# Michael Sprinker
# Algernon Charles Swinburne
# Socrates
# Tudor Vianu
# Kendall Walton
# Morris Weitz
# Oscar Wilde
# W.K. Wimsatt
# Richard Wollheim
# Peter Abelard
# Wilhelm Ackermann
# Sergei Adian
# Rodolphus Agricola
# Kazimierz Ajdukiewicz
# Alcuin
# Alan Ross Anderson
# Peter B. Andrews (mathematician)
# Thomas Aquinas
# Lennart Åqvist
# Aristotle
# Heiric of Auxerre
# Bahmanyār
# Alexander Bain
# Yehoshua Bar-Hillel
# Ruth Barcan Marcus
# Henk Barendregt
# Jon Barwise
# James Earl Baumgartner
# John Lane Bell
# Nuel Belnap
# Paul Benacerraf
# Johan van Benthem (logician)
# Paul Bernays
# Evert Willem Beth
# Jean-Yves Béziau
# Józef Maria Bocheński
# Boethius
# Bernard Bolzano
# Andrea Bonomì
# George Boole
# George Boolos
# Nicolas Bourbaki
# Thomas Bradwardine
# Richard Brinkley
# Luitzen Egbertus Jan Brouwer
# Alan Bundy
# Franco Burgersdijk
# Jean Buridan
# Walter Burley
# Chanakya
# Georg Cantor
# Rudolf Carnap
# Lewis Carroll
# Categoriae decem
# Gregory Chaitin
# Chrysippus
# Alonzo Church
# Leon Chwistek
# Paul Cohen (mathematician)
# Conimbricenses
# S. Barry Cooper
# Jack Copeland
# John Corcoran (logician)
# Newton da Costa
# William Craig (logician)
# Haskell Curry
# Tadeusz Czeżowski
# Dirk van Dalen
# Martin Davis
# Augustus De Morgan
# Dharmakirti
# Dignāga
# Diodorus Cronus
# :nl:Martinus Dorpius
# :nl:Martinus Dorpius has an empty wikipedia page
# John Dumbleton
# Michael A. E. Dummett
# Alexander Esenin-Volpin
# John Etchemendy
# Solomon Feferman
# Richard Ferrybridge
# Hartry Field
# Kit Fine
# Melvin Fitting
# Graeme Forbes
# Graeme Forbes has an empty wikipedia page
# Matthew Foreman
# Michael Fourman
# Roland Fraïssé
# Abraham Fraenkel
# Gottlob Frege
# Harvey Friedman
# Dov Gabbay
# L. T. F. Gamut
# Robin Gandy
# Sol Garfunkel
# Garlandus Compotista
# Nyāya Sūtras
# Peter Geach
# Gerhard Gentzen
# Joseph Diaz Gergonne
# Gilbert de la Porrée
# Jean-Yves Girard
# Kurt Gödel
# Reuben Louis Goodstein
# Siegfried Gottwald
# Jeroen Groenendijk
# Susan Haack
# Petr Hájek
# Leo Harrington
# Robert S. Hartman
# Georg Wilhelm Friedrich Hegel
# Jean Van Heijenoort
# Leon Henkin
# Jacques Herbrand
# Arend Heyting
# David Hilbert
# Jaakko Hintikka
# Alfred Horn
# William Alvin Howard
# Ehud Hrushovski
# Ibn Taymiyyah
# Marsilius of Inghen
# Giorgi Japaridze
# Stanisław Jaśkowski
# Richard Jeffrey
# Ronald Jensen
# William Stanley Jevons
# John of St. Thomas
# William Ernest Johnson
# Dick de Jongh
# Bjarni Jónsson
# Philip Jourdain
# Joachim Jungius
# David Kaplan (philosopher)
# Alexander S. Kechris
# Howard Jerome Keisler
# Ahmed Raza Khan
# Richard Kilvington
# Robert Kilwardby
# Stephen Cole Kleene
# Tadeusz Kotarbiński
# Robert Kowalski
# Georg Kreisel
# Saul Kripke
# Leopold Kronecker
# Kenneth Kunen
# Christine Ladd-Franklin
# Joachim Lambek
# Johann Heinrich Lambert
# Karel Lambert
# Gottfried Leibniz
# Stanisław Leśniewski
# Clarence Irving Lewis
# David Kellogg Lewis
# Adolf Lindenbaum
# Per Lindström
# Ramon Llull
# Martin Löb
# Paul Lorenzen
# Jerzy Łoś
# Hermann Lotze
# Leopold Löwenheim
# Jan Łukasiewicz
# Hugh MacColl
# Saunders MacLane
# Dugald Macpherson
# Penelope Maddy
# John Major (philosopher)
# David Makinson
# Isaac Malitz
# Gary R. Mar
# Ruth Barcan Marcus
# Donald A. Martin
# Richard Milton Martin
# Per Martin-Löf
# Yuri Matiyasevich
# Carew Arthur Meredith
# Bob Meyer (logician)
# John Stuart Mill
# Grigori Mints
# Richard Montague
# Yiannis N. Moschovakis
# Andrzej Mostowski
# Edward Nelson
# John von Neumann
# Jean Nicod
# Pyotr Novikov
# William of Ockham
# Piergiorgio Odifreddi
# Ivan Orlov (philosopher)
# John Pagus
# Jeff Paris
# Charles Parsons (philosopher)
# Solomon Passy
# Paul of Venice
# Giuseppe Peano
# Charles Sanders Peirce
# Lorenzo Peña
# Chaïm Perelman
# Rózsa Péter
# Paolo da Pergola
# Peter of Spain (author)
# Philo the Dialectician
# Walter Pitts
# Porphyry (philosopher)
# Henry Andrew Pogorzelski
# Emil Leon Post
# Dag Prawitz
# Mojżesz Presburger
# Graham Priest
# Arthur Prior
# Hilary Putnam
# PLATO
# Willard Van Orman Quine
# Michael O. Rabin
# Constantin Rădulescu-Motru
# Frank Plumpton Ramsey
# Petrus Ramus
# Helena Rasiowa
# Carveth Read
# Abraham Robinson
# Raphael M. Robinson
# J. Barkley Rosser
# Richard Routley
# Frederick Rowbottom
# Ian Rumfitt
# Bertrand Russell
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-374-957d467ef9e9> in <module>()
#      48         tokens = tokenizer.tokenize(text) # Get all tokens with the tokenizer
#      49         # filter out the stop words and digits
# ---> 50         filtered_words = [w for w in tokens if not w in stopwords.words('english') if not w.isdigit()]
#      51
#      52         # Get unique set of the words
#
# /Users/GretarAtli/anaconda/lib/python2.7/site-packages/nltk/corpus/reader/wordlist.pyc in words(self, fileids, ignore_lines_startswith)
#      20     def words(self, fileids=None, ignore_lines_startswith='\n'):
#      21         return [line for line in line_tokenize(self.raw(fileids))
# ---> 22                 if not line.startswith(ignore_lines_startswith)]
#      23
#      24     def raw(self, fileids=None):
#
# KeyboardInterrupt:

# %%
type(wikisource)
# Out:
# dict

# %% [markdown]
# ** Now, we're ready to calculate the TF for each word. Use the method of your choice to find the top 5 terms within each branch. **
#     - Describe similarities and differences between the branches.
#     - Why aren't the TFs not necessarily a good description of the branches?

# %%
philosophers.keys()
# Out:
# ['social and political philosophers',
#  'aestheticians',
#  'logicians',
#  'epistemologists',
#  'metaphysicians',
#  'ethicists']

# %%
import operator

sorted(FreqDist(philosophers["social and political philosophers"]["tokens"]).items(),key=operator.itemgetter(1),reverse=True)
# Out:
# [('also', 363),
#  ('university', 358),
#  ('external', 356),
#  ('links', 354),
#  ('references', 352),
#  ('born', 351),
#  ('sophy', 333),
#  ('political', 328),
#  ('\xe2', 328),
#  ('work', 328),
#  ('one', 320),
#  ('new', 320),
#  ('life', 311),
#  ('works', 302),
#  ('published', 299),
#  ('first', 296),
#  ('social', 290),
#  ('history', 289),
#  ('sopher', 285),
#  ('book', 283),
#  ('later', 278),
#  ('theory', 278),
#  ('time', 276),
#  ('early', 276),
#  ('world', 275),
#  ('press', 274),
#  ('two', 272),
#  ('books', 271),
#  ('became', 270),
#  ('school', 269),
#  ('thought', 267),
#  ('years', 266),
#  ('see', 264),
#  ('society', 262),
#  ('known', 259),
#  ('including', 256),
#  ('many', 256),
#  ('state', 250),
#  ('well', 246),
#  ('would', 245),
#  ('studies', 241),
#  ('may', 238),
#  ('called', 238),
#  ('century', 237),
#  ('people', 236),
#  ('part', 234),
#  ('wrote', 233),
#  ('professor', 233),
#  ('york', 232),
#  ('american', 230),
#  ('human', 230),
#  ('made', 227),
#  ('law', 226),
#  ('politics', 224),
#  ('study', 222),
#  ('modern', 222),
#  ('e', 221),
#  ('ideas', 221),
#  ('states', 220),
#  ('death', 220),
#  ('science', 219),
#  ('isbn', 218),
#  ('war', 215),
#  ('second', 215),
#  ('education', 214),
#  ('year', 212),
#  ('among', 211),
#  ('three', 211),
#  ('sophical', 211),
#  ('left', 209),
#  ('english', 208),
#  ('writings', 205),
#  ('since', 205),
#  ('several', 205),
#  ('based', 205),
#  ('power', 205),
#  ('written', 204),
#  ('age', 204),
#  ('national', 203),
#  ('family', 203),
#  ('like', 202),
#  ('died', 202),
#  ('reading', 202),
#  ('however', 201),
#  ('according', 200),
#  ('could', 199),
#  ('influence', 198),
#  ('ed', 198),
#  ('career', 198),
#  ('public', 198),
#  ('view', 197),
#  ('much', 196),
#  ('london', 196),
#  ('way', 195),
#  ('important', 195),
#  ('received', 195),
#  ('form', 194),
#  ('idea', 194),
#  ('man', 194),
#  ('order', 193),
#  ('nature', 192),
#  ('rather', 192),
#  ('considered', 192),
#  ('position', 192),
#  ('another', 191),
#  ('without', 191),
#  ('member', 191),
#  ('journal', 191),
#  ('de', 189),
#  ('right', 189),
#  ('others', 189),
#  ('great', 188),
#  ('argued', 188),
#  ('become', 187),
#  ('held', 187),
#  ('general', 187),
#  ('even', 187),
#  ('best', 186),
#  ('united', 186),
#  ('writing', 186),
#  ('father', 185),
#  ('following', 184),
#  ('began', 183),
#  ('system', 182),
#  ('research', 180),
#  ('long', 180),
#  ('critical', 180),
#  ('essays', 179),
#  ('last', 179),
#  ('biography', 179),
#  ('end', 179),
#  ('government', 179),
#  ('although', 179),
#  ('free', 179),
#  ('c', 179),
#  ('notes', 179),
#  ('john', 178),
#  ('movement', 178),
#  ('different', 177),
#  ('culture', 176),
#  ('historical', 175),
#  ('bibliography', 175),
#  ('use', 175),
#  ('group', 175),
#  ('self', 174),
#  ('institute', 174),
#  ('often', 174),
#  ('articles', 173),
#  ('took', 172),
#  ('upon', 172),
#  ('studied', 170),
#  ('german', 170),
#  ('international', 169),
#  ('academic', 168),
#  ('l', 168),
#  ('led', 168),
#  ('intellectual', 168),
#  ('major', 168),
#  ('concept', 167),
#  ('point', 167),
#  ('within', 167),
#  ('views', 167),
#  ('never', 166),
#  ('taught', 166),
#  ('non', 165),
#  ('development', 165),
#  ('co', 165),
#  ('natural', 165),
#  ('found', 165),
#  ('must', 165),
#  ('p', 164),
#  ('religion', 164),
#  ('edited', 164),
#  ('action', 163),
#  ('series', 163),
#  ('college', 163),
#  ('j', 163),
#  ('review', 163),
#  ('married', 162),
#  ('given', 162),
#  ('original', 162),
#  ('name', 162),
#  ('said', 162),
#  ('times', 161),
#  ('period', 161),
#  ('used', 160),
#  ('contemporary', 160),
#  ('example', 160),
#  ('french', 159),
#  ('developed', 158),
#  ('march', 158),
#  ('worked', 158),
#  ('influenced', 158),
#  ('particular', 158),
#  ('us', 157),
#  ('present', 157),
#  ('moral', 157),
#  ('cambridge', 157),
#  ('number', 156),
#  ('described', 156),
#  ('four', 156),
#  ('personal', 155),
#  ('thus', 155),
#  ('tradition', 155),
#  ('make', 155),
#  ('old', 155),
#  ('influential', 155),
#  ('paris', 155),
#  ('individual', 154),
#  ('came', 154),
#  ('young', 154),
#  ('author', 154),
#  ('various', 154),
#  ('means', 153),
#  ('city', 153),
#  ('text', 153),
#  ('role', 152),
#  ('third', 152),
#  ('ii', 152),
#  ('good', 152),
#  ('reason', 151),
#  ('economic', 150),
#  ('returned', 150),
#  ('believed', 149),
#  ('future', 149),
#  ('subject', 149),
#  ('though', 149),
#  ('set', 148),
#  ('understanding', 148),
#  ('freedom', 148),
#  ('served', 148),
#  ('november', 147),
#  ('party', 147),
#  ('volume', 147),
#  ('sense', 147),
#  ('language', 147),
#  ('late', 147),
#  ('oxford', 147),
#  ('place', 147),
#  ('june', 147),
#  ('working', 146),
#  ('religious', 146),
#  ('edition', 146),
#  ('european', 146),
#  ('support', 146),
#  ('former', 145),
#  ('interest', 145),
#  ('april', 145),
#  ('son', 145),
#  ('instead', 145),
#  ('along', 145),
#  ('founded', 144),
#  ('la', 144),
#  ('western', 144),
#  ('included', 144),
#  ('post', 144),
#  ('list', 143),
#  ('g', 143),
#  ('moved', 143),
#  ('rights', 143),
#  ('october', 143),
#  ('fact', 143),
#  ('president', 143),
#  ('day', 143),
#  ('take', 142),
#  ('case', 142),
#  ('together', 142),
#  ('towards', 142),
#  ('b', 142),
#  ('especially', 142),
#  ('essay', 141),
#  ('theories', 141),
#  ('main', 141),
#  ('introduction', 140),
#  ('mother', 140),
#  ('student', 140),
#  ('continued', 140),
#  ('went', 140),
#  ('scholars', 140),
#  ('gave', 139),
#  ('david', 139),
#  ('principles', 139),
#  ('basis', 138),
#  ('person', 138),
#  ('\xc3', 138),
#  ('liberal', 138),
#  ('anti', 138),
#  ('revolution', 138),
#  ('joined', 138),
#  ('every', 138),
#  ('civil', 138),
#  ('result', 138),
#  ('high', 138),
#  ('fellow', 138),
#  ('today', 137),
#  ('whose', 137),
#  ('common', 137),
#  ('class', 137),
#  ('full', 136),
#  ('central', 136),
#  ('sophers', 136),
#  ('criticism', 136),
#  ('british', 136),
#  ('pp', 136),
#  ('encyclopedia', 135),
#  ('throughout', 135),
#  ('art', 135),
#  ('translated', 135),
#  ('robert', 134),
#  ('lived', 134),
#  ('leading', 134),
#  ('thinking', 134),
#  ('william', 134),
#  ('children', 134),
#  ('widely', 134),
#  ('experience', 133),
#  ('still', 133),
#  ('knowledge', 133),
#  ('project', 133),
#  ('around', 133),
#  ('saw', 133),
#  ('opposed', 132),
#  ('home', 132),
#  ('men', 132),
#  ('forms', 132),
#  ('january', 132),
#  ('seen', 132),
#  ('archive', 132),
#  ('sciences', 131),
#  ('ethics', 131),
#  ('things', 131),
#  ('paul', 131),
#  ('title', 131),
#  ('radical', 131),
#  ('degree', 130),
#  ('article', 130),
#  ('account', 130),
#  ('scholar', 130),
#  ('library', 129),
#  ('august', 129),
#  ('meaning', 129),
#  ('critique', 129),
#  ('r', 129),
#  ('due', 129),
#  ('created', 129),
#  ('members', 129),
#  ('july', 129),
#  ('editor', 128),
#  ('include', 128),
#  ('possible', 128),
#  ('democracy', 128),
#  ('five', 128),
#  ('analysis', 128),
#  ('george', 128),
#  ('change', 127),
#  ('legal', 127),
#  ('true', 127),
#  ('democratic', 127),
#  ('internet', 126),
#  ('making', 126),
#  ('established', 126),
#  ('december', 126),
#  ('students', 126),
#  ('foundation', 126),
#  ('literature', 126),
#  ('practice', 126),
#  ('strong', 125),
#  ('famous', 125),
#  ('terms', 125),
#  ('publication', 125),
#  ('house', 125),
#  ('come', 125),
#  ('words', 125),
#  ('friend', 124),
#  ('named', 124),
#  ('classical', 123),
#  ('relationship', 123),
#  ('september', 123),
#  ('association', 123),
#  ('europe', 123),
#  ('involved', 123),
#  ('h', 123),
#  ('need', 123),
#  ('claimed', 123),
#  ('justice', 122),
#  ('charles', 122),
#  ('little', 122),
#  ('cultural', 122),
#  ('term', 122),
#  ('able', 122),
#  ('force', 122),
#  ('argues', 122),
#  ('collection', 122),
#  ('opposition', 122),
#  ('vol', 121),
#  ('process', 121),
#  ('supported', 121),
#  ('institutions', 121),
#  ('issues', 121),
#  ('far', 121),
#  ('america', 120),
#  ('popular', 120),
#  ('met', 120),
#  ('teaching', 120),
#  ('might', 120),
#  ('cannot', 120),
#  ('course', 120),
#  ('certain', 120),
#  ('claim', 120),
#  ('particularly', 120),
#  ('individuals', 119),
#  ('close', 119),
#  ('department', 119),
#  ('community', 119),
#  ('real', 119),
#  ('large', 119),
#  ('february', 119),
#  ('complete', 119),
#  ('james', 119),
#  ('beyond', 119),
#  ('france', 119),
#  ('living', 119),
#  ('therefore', 118),
#  ('wife', 118),
#  ('private', 118),
#  ('back', 118),
#  ('friends', 118),
#  ('taken', 117),
#  ('always', 117),
#  ('read', 117),
#  ('existence', 117),
#  ('god', 117),
#  ('belief', 117),
#  ('approach', 117),
#  ('related', 117),
#  ('control', 117),
#  ('body', 117),
#  ('attended', 117),
#  ('return', 117),
#  ('contributions', 117),
#  ('despite', 116),
#  ('selected', 116),
#  ('notion', 116),
#  ('faculty', 116),
#  ('character', 116),
#  ('less', 116),
#  ('translation', 116),
#  ('literary', 115),
#  ('principle', 115),
#  ('thinkers', 115),
#  ('publishing', 115),
#  ('remained', 115),
#  ('relations', 115),
#  ('claims', 115),
#  ('response', 115),
#  ('followed', 114),
#  ('necessary', 114),
#  ('short', 114),
#  ('traditional', 114),
#  ('middle', 114),
#  ('country', 114),
#  ('scientific', 114),
#  ('rejected', 114),
#  ('michael', 113),
#  ('act', 113),
#  ('w', 113),
#  ('publications', 113),
#  ('presented', 113),
#  ('economics', 113),
#  ('mind', 113),
#  ('give', 112),
#  ('argument', 112),
#  ('becoming', 112),
#  ('lectures', 112),
#  ('attempt', 112),
#  ('f', 112),
#  ('yet', 111),
#  ('founder', 111),
#  ('laws', 111),
#  ('six', 111),
#  ('appointed', 110),
#  ('liberty', 110),
#  ('question', 110),
#  ('legacy', 110),
#  ('brought', 110),
#  ('least', 110),
#  ('eventually', 110),
#  ('sources', 110),
#  ('active', 110),
#  ('find', 110),
#  ('service', 109),
#  ('germany', 109),
#  ('basic', 109),
#  ('20th', 109),
#  ('n', 109),
#  ('christian', 109),
#  ('des', 109),
#  ('associated', 109),
#  ('writer', 109),
#  ('soon', 109),
#  ('outside', 109),
#  ('nothing', 109),
#  ('problems', 109),
#  ('importance', 109),
#  ('west', 108),
#  ('hand', 108),
#  ('lost', 108),
#  ('et', 108),
#  ('referred', 108),
#  ('thesis', 108),
#  ('issue', 108),
#  ('criticized', 108),
#  ('accepted', 108),
#  ('joseph', 108),
#  ('noted', 108),
#  ('union', 107),
#  ('attention', 107),
#  ('events', 107),
#  ('latter', 107),
#  ('turn', 106),
#  ('put', 106),
#  ('arts', 106),
#  ('open', 106),
#  ('whether', 106),
#  ('something', 106),
#  ('policy', 105),
#  ('foreign', 105),
#  ('significant', 105),
#  ('spent', 105),
#  ('authority', 105),
#  ('material', 105),
#  ('beginning', 104),
#  ('proposed', 104),
#  ('version', 104),
#  ('capitalism', 104),
#  ('value', 104),
#  ('truth', 104),
#  ('say', 104),
#  ('final', 104),
#  ('small', 103),
#  ('letters', 103),
#  ('texts', 103),
#  ('harvard', 103),
#  ('introduced', 102),
#  ('whole', 102),
#  ('prominent', 102),
#  ('ancient', 102),
#  ('independent', 102),
#  ('women', 102),
#  ('problem', 101),
#  ('magazine', 101),
#  ('addition', 101),
#  ('taking', 101),
#  ('helped', 101),
#  ('toward', 100),
#  ('military', 100),
#  ('die', 100),
#  ('fall', 100),
#  ('stated', 100),
#  ('better', 100),
#  ('historian', 100),
#  ('chicago', 100),
#  ('subjects', 99),
#  ('special', 99),
#  ('strongly', 99),
#  ('understood', 99),
#  ('writes', 99),
#  ('page', 99),
#  ('either', 99),
#  ('organization', 99),
#  ('believe', 99),
#  ('similar', 98),
#  ('next', 98),
#  ('california', 98),
#  ('field', 98),
#  ('der', 98),
#  ('daughter', 98),
#  ('elected', 98),
#  ('socialism', 98),
#  ('struggle', 98),
#  ('method', 98),
#  ('reality', 98),
#  ('rise', 98),
#  ('economy', 97),
#  ('theorist', 97),
#  ('greatest', 97),
#  ('groups', 97),
#  ('interview', 97),
#  ('academy', 97),
#  ('stanford', 97),
#  ('greater', 97),
#  ('richard', 97),
#  ('ever', 97),
#  ('doctrine', 97),
#  ('awarded', 97),
#  ('interests', 96),
#  ('universal', 96),
#  ('figure', 96),
#  ('king', 96),
#  ('titled', 96),
#  ('head', 96),
#  ('st', 96),
#  ('expressed', 96),
#  ('practical', 96),
#  ('debate', 96),
#  ('originally', 95),
#  ('away', 95),
#  ('cause', 95),
#  ('papers', 95),
#  ('current', 95),
#  ('official', 95),
#  ('matter', 95),
#  ('felt', 95),
#  ('earlier', 95),
#  ('property', 95),
#  ('beliefs', 95),
#  ('actions', 95),
#  ('england', 95),
#  ('rule', 95),
#  ('effect', 95),
#  ('interpretation', 95),
#  ('ways', 95),
#  ('u', 94),
#  ('spirit', 94),
#  ('values', 94),
#  ('live', 94),
#  ('appeared', 94),
#  ('thomas', 94),
#  ('aspects', 94),
#  ('court', 94),
#  ('context', 94),
#  ('online', 94),
#  ('know', 94),
#  ('letter', 93),
#  ('center', 93),
#  ('already', 93),
#  ('theoretical', 93),
#  ('help', 93),
#  ('conditions', 93),
#  ('conflict', 93),
#  ('single', 93),
#  ('word', 93),
#  ('finally', 92),
#  ('create', 92),
#  ('respect', 92),
#  ('fundamental', 92),
#  ('highly', 92),
#  ('months', 92),
#  ('think', 92),
#  ('simply', 92),
#  ('concepts', 92),
#  ('forces', 92),
#  ('write', 92),
#  ('clear', 92),
#  ('higher', 91),
#  ('peace', 91),
#  ('birth', 91),
#  ('defined', 91),
#  ('evidence', 91),
#  ('model', 91),
#  ('entitled', 91),
#  ('speech', 91),
#  ('eds', 91),
#  ('east', 91),
#  ('berlin', 91),
#  ('scholarship', 91),
#  ('lecture', 91),
#  ('kind', 90),
#  ('love', 90),
#  ('almost', 90),
#  ('creation', 90),
#  ('near', 90),
#  ('nation', 90),
#  ('rest', 90),
#  ('church', 90),
#  ('focus', 90),
#  ('v', 90),
#  ('style', 90),
#  ('contributed', 90),
#  ('elements', 90),
#  ('generally', 90),
#  ('master', 89),
#  ('lives', 89),
#  ('director', 89),
#  ('ethical', 89),
#  ('regarded', 89),
#  ('includes', 89),
#  ('schools', 89),
#  ('allowed', 89),
#  ('socialist', 89),
#  ('writers', 89),
#  ('produced', 89),
#  ('using', 89),
#  ('south', 89),
#  ('brother', 89),
#  ('sometimes', 88),
#  ('speaking', 88),
#  ('arguing', 88),
#  ('republic', 88),
#  ('adopted', 88),
#  ('remains', 88),
#  ('chapter', 88),
#  ('volumes', 88),
#  ('perspective', 88),
#  ('saying', 87),
#  ('formed', 87),
#  ('situation', 87),
#  ('available', 87),
#  ('ideology', 87),
#  ('days', 87),
#  ('status', 87),
#  ('marriage', 87),
#  ('go', 87),
#  ('authors', 87),
#  ('show', 87),
#  ('italian', 87),
#  ('christianity', 87),
#  ('land', 86),
#  ('enough', 86),
#  ('conservative', 86),
#  ('distinguished', 86),
#  ('understand', 86),
#  ('k', 86),
#  ('bring', 86),
#  ('started', 86),
#  ('call', 86),
#  ('calls', 86),
#  ('von', 85),
#  ('primary', 85),
#  ('direct', 85),
#  ('exist', 85),
#  ('recent', 85),
#  ('jewish', 85),
#  ('columbia', 85),
#  ('provided', 85),
#  ('spring', 85),
#  ('peter', 85),
#  ('arguments', 85),
#  ('ideal', 85),
#  ('activities', 85),
#  ('essential', 85),
#  ('revolutionary', 85),
#  ('leader', 85),
#  ('affairs', 84),
#  ('production', 84),
#  ('critic', 84),
#  ('contrast', 84),
#  ('sent', 84),
#  ('indeed', 84),
#  ('le', 84),
#  ('advocated', 84),
#  ('sought', 84),
#  ('key', 84),
#  ('program', 84),
#  ('forced', 84),
#  ('mark', 84),
#  ('lead', 84),
#  ('shared', 83),
#  ('inspired', 83),
#  ('previously', 83),
#  ('north', 83),
#  ('communist', 83),
#  ('reference', 83),
#  ('attempted', 83),
#  ('relation', 83),
#  ('progress', 83),
#  ('vision', 82),
#  ('past', 82),
#  ('discussion', 82),
#  ('limited', 82),
#  ('seven', 82),
#  ('declared', 82),
#  ('local', 82),
#  ('failed', 82),
#  ('intellectuals', 82),
#  ('faith', 82),
#  ('leave', 82),
#  ('applied', 82),
#  ('largely', 82),
#  ('regard', 82),
#  ('concerned', 82),
#  ('office', 82),
#  ('business', 82),
#  ('earned', 82),
#  ('maintained', 82),
#  ('reform', 81),
#  ('parts', 81),
#  ('liberalism', 81),
#  ('questions', 81),
#  ('theology', 81),
#  ('critics', 81),
#  ('offered', 81),
#  ('serve', 81),
#  ('frequently', 81),
#  ('capital', 81),
#  ('catholic', 81),
#  ('hold', 81),
#  ('chief', 81),
#  ('half', 81),
#  ('suggested', 80),
#  ('defense', 80),
#  ('19th', 80),
#  ('child', 80),
#  ('sociology', 80),
#  ('attack', 80),
#  ('matters', 80),
#  ('emphasis', 80),
#  ('directly', 80),
#  ('reader', 80),
#  ('completed', 80),
#  ('ultimately', 80),
#  ('opinion', 80),
#  ('visiting', 80),
#  ('identified', 80),
#  ('wrong', 79),
#  ('poor', 79),
#  ('source', 79),
#  ('perhaps', 79),
#  ('line', 79),
#  ('dedicated', 79),
#  ('constitution', 79),
#  ('societies', 79),
#  ('logic', 79),
#  ('buried', 79),
#  ('domain', 79),
#  ('side', 79),
#  ('und', 79),
#  ('educated', 79),
#  ('tried', 79),
#  ('structure', 79),
#  ('army', 79),
#  ('contribution', 79),
#  ('thoughts', 79),
#  ('empire', 79),
#  ('placed', 78),
#  ('level', 78),
#  ('explained', 78),
#  ('makes', 78),
#  ('twenty', 78),
#  ('regarding', 78),
#  ('reasons', 78),
#  ('mass', 78),
#  ('heart', 78),
#  ('rules', 78),
#  ('collected', 78),
#  ('wealth', 78),
#  ('purpose', 78),
#  ('x', 78),
#  ('nations', 78),
#  ('asked', 78),
#  ('concerning', 78),
#  ('market', 78),
#  ('marxism', 78),
#  ('causes', 77),
#  ('develop', 77),
#  ('success', 77),
#  ('likely', 77),
#  ('remain', 77),
#  ('subsequently', 77),
#  ('council', 77),
#  ('money', 77),
#  ('minister', 77),
#  ('cited', 77),
#  ('committee', 77),
#  ('event', 77),
#  ('says', 77),
#  ('chair', 76),
#  ('caused', 76),
#  ('company', 76),
#  ('provide', 76),
#  ('royal', 76),
#  ('merely', 76),
#  ('across', 76),
#  ('crisis', 76),
#  ('morality', 76),
#  ('points', 76),
#  ('twentieth', 76),
#  ('raised', 76),
#  ('spiritual', 76),
#  ('agreed', 76),
#  ('italy', 76),
#  ('intended', 75),
#  ('parents', 75),
#  ('positions', 75),
#  ('entered', 75),
#  ('ability', 75),
#  ('organized', 75),
#  ('information', 75),
#  ('figures', 75),
#  ('media', 75),
#  ('focused', 75),
#  ('neo', 75),
#  ('distinction', 75),
#  ('town', 75),
#  ('areas', 75),
#  ('leaders', 75),
#  ('done', 75),
#  ('roman', 75),
#  ('going', 75),
#  ('graduate', 75),
#  ('violence', 75),
#  ('devoted', 75),
#  ('initially', 75),
#  ('controversy', 74),
#  ('recognition', 74),
#  ('ended', 74),
#  ('learned', 74),
#  ('difficult', 74),
#  ('lifetime', 74),
#  ('foundations', 74),
#  ('un', 74),
#  ('constitutional', 74),
#  ('numerous', 74),
#  ('movements', 74),
#  ('youth', 74),
#  ('meeting', 74),
#  ('longer', 74),
#  ('methods', 73),
#  ('secretary', 73),
#  ('teacher', 73),
#  ('jean', 73),
#  ('condition', 73),
#  ('required', 73),
#  ('equality', 73),
#  ('continue', 73),
#  ('award', 73),
#  ('aim', 73),
#  ('2nd', 73),
#  ('spanish', 73),
#  ('trade', 73),
#  ('defended', 73),
#  ('powers', 73),
#  ('learning', 73),
#  ('changed', 73),
#  ('henry', 73),
#  ('turned', 72),
#  ('newspaper', 72),
#  ('alternative', 72),
#  ('range', 72),
#  ('authored', 72),
#  ('primarily', 72),
#  ('du', 72),
#  ('global', 72),
#  ('neither', 72),
#  ('complex', 72),
#  ('humanity', 72),
#  ('conception', 72),
#  ('doi', 72),
#  ('specific', 72),
#  ('light', 72),
#  ('played', 72),
#  ('offer', 72),
#  ('actually', 72),
#  ('marxist', 72),
#  ('lack', 72),
#  ('universities', 72),
#  ('identity', 71),
#  ('needs', 71),
#  ('refused', 71),
#  ('positive', 71),
#  ('studying', 71),
#  ('physical', 71),
#  ('appears', 71),
#  ('goal', 71),
#  ('comes', 71),
#  ('fully', 71),
#  ('describes', 71),
#  ('previous', 71),
#  ('thing', 71),
#  ('difference', 71),
#  ('industrial', 71),
#  ('iii', 71),
#  ('psychology', 71),
#  ('latin', 71),
#  ('really', 71),
#  ('kingdom', 71),
#  ('martin', 71),
#  ('wide', 71),
#  ('ground', 70),
#  ('grew', 70),
#  ('conference', 70),
#  ('believes', 70),
#  ('determined', 70),
#  ('ten', 70),
#  ('necessity', 70),
#  ('unable', 70),
#  ('seems', 70),
#  ('editions', 70),
#  ('promoted', 70),
#  ('differences', 70),
#  ('separate', 70),
#  ('resources', 69),
#  ('nevertheless', 69),
#  ('increasingly', 69),
#  ('routledge', 69),
#  ('practices', 69),
#  ('brief', 69),
#  ('pure', 69),
#  ('everything', 69),
#  ('workers', 69),
#  ...]

# %%
sorted(FreqDist(philosophers['aestheticians']["tokens"]).items(),key=operator.itemgetter(1),reverse=True)
# Out:
# [('university', 97),
#  ('work', 91),
#  ('also', 90),
#  ('\xe2', 90),
#  ('born', 88),
#  ('external', 88),
#  ('links', 87),
#  ('references', 87),
#  ('life', 84),
#  ('new', 84),
#  ('sophy', 84),
#  ('works', 81),
#  ('first', 80),
#  ('one', 79),
#  ('press', 78),
#  ('became', 78),
#  ('history', 77),
#  ('art', 77),
#  ('book', 76),
#  ('two', 74),
#  ('aesthetics', 74),
#  ('published', 74),
#  ('theory', 73),
#  ('world', 72),
#  ('time', 72),
#  ('many', 71),
#  ('english', 71),
#  ('known', 69),
#  ('years', 68),
#  ('e', 68),
#  ('books', 67),
#  ('professor', 67),
#  ('studies', 67),
#  ('later', 65),
#  ('sopher', 65),
#  ('sophical', 65),
#  ('ed', 64),
#  ('literature', 63),
#  ('school', 62),
#  ('wrote', 62),
#  ('study', 62),
#  ('part', 62),
#  ('thought', 62),
#  ('year', 61),
#  ('death', 61),
#  ('well', 61),
#  ('may', 61),
#  ('much', 60),
#  ('essays', 60),
#  ('influence', 60),
#  ('including', 60),
#  ('made', 60),
#  ('century', 59),
#  ('language', 59),
#  ('called', 59),
#  ('see', 58),
#  ('several', 58),
#  ('modern', 58),
#  ('career', 58),
#  ('biography', 57),
#  ('died', 57),
#  ('reading', 57),
#  ('based', 57),
#  ('important', 57),
#  ('early', 57),
#  ('studied', 56),
#  ('edition', 56),
#  ('criticism', 56),
#  ('society', 56),
#  ('notes', 56),
#  ('among', 55),
#  ('like', 55),
#  ('long', 55),
#  ('best', 55),
#  ('de', 55),
#  ('public', 55),
#  ('ideas', 55),
#  ('three', 55),
#  ('critical', 55),
#  ('york', 55),
#  ('literary', 54),
#  ('science', 54),
#  ('since', 54),
#  ('form', 54),
#  ('idea', 54),
#  ('family', 54),
#  ('human', 54),
#  ('second', 54),
#  ('would', 53),
#  ('way', 53),
#  ('german', 53),
#  ('began', 53),
#  ('others', 53),
#  ('experience', 52),
#  ('last', 52),
#  ('l', 52),
#  ('aesthetic', 52),
#  ('essay', 52),
#  ('age', 52),
#  ('received', 52),
#  ('state', 52),
#  ('american', 51),
#  ('education', 51),
#  ('however', 51),
#  ('writings', 51),
#  ('written', 51),
#  ('war', 51),
#  ('journal', 51),
#  ('mind', 51),
#  ('influenced', 51),
#  ('isbn', 51),
#  ('writing', 51),
#  ('following', 50),
#  ('author', 50),
#  ('contemporary', 50),
#  ('national', 50),
#  ('considered', 50),
#  ('college', 50),
#  ('text', 50),
#  ('could', 49),
#  ('become', 49),
#  ('rather', 49),
#  ('moved', 49),
#  ('found', 49),
#  ('man', 49),
#  ('view', 49),
#  ('london', 48),
#  ('great', 48),
#  ('use', 48),
#  ('even', 48),
#  ('often', 48),
#  ('cambridge', 48),
#  ('nature', 47),
#  ('another', 47),
#  ('culture', 47),
#  ('without', 47),
#  ('used', 47),
#  ('according', 47),
#  ('included', 47),
#  ('son', 47),
#  ('held', 47),
#  ('place', 47),
#  ('publication', 47),
#  ('french', 47),
#  ('j', 47),
#  ('knowledge', 46),
#  ('sense', 46),
#  ('led', 46),
#  ('never', 46),
#  ('taught', 46),
#  ('member', 46),
#  ('project', 46),
#  ('city', 46),
#  ('although', 46),
#  ('social', 46),
#  ('major', 46),
#  ('upon', 46),
#  ('archive', 46),
#  ('position', 46),
#  ('words', 46),
#  ('people', 45),
#  ('take', 45),
#  ('number', 45),
#  ('p', 45),
#  ('arts', 45),
#  ('took', 45),
#  ('writer', 45),
#  ('us', 45),
#  ('though', 45),
#  ('developed', 45),
#  ('c', 45),
#  ('left', 45),
#  ('music', 44),
#  ('self', 44),
#  ('john', 44),
#  ('point', 44),
#  ('four', 44),
#  ('series', 44),
#  ('came', 44),
#  ('political', 44),
#  ('thinking', 44),
#  ('movement', 44),
#  ('day', 44),
#  ('historical', 43),
#  ('library', 43),
#  ('critic', 43),
#  ('states', 43),
#  ('together', 43),
#  ('central', 43),
#  ('example', 43),
#  ('around', 43),
#  ('name', 43),
#  ('especially', 43),
#  ('general', 43),
#  ('must', 43),
#  ('concept', 42),
#  ('non', 42),
#  ('development', 42),
#  ('meaning', 42),
#  ('married', 42),
#  ('always', 42),
#  ('intellectual', 42),
#  ('end', 42),
#  ('sophers', 42),
#  ('understanding', 42),
#  ('truth', 42),
#  ('bibliography', 42),
#  ('little', 42),
#  ('february', 42),
#  ('things', 42),
#  ('old', 42),
#  ('power', 42),
#  ('complete', 42),
#  ('influential', 42),
#  ('interest', 42),
#  ('order', 42),
#  ('reality', 42),
#  ('particular', 42),
#  ('various', 42),
#  ('lived', 41),
#  ('times', 41),
#  ('personal', 41),
#  ('father', 41),
#  ('international', 41),
#  ('thus', 41),
#  ('original', 41),
#  ('established', 41),
#  ('friend', 41),
#  ('b', 41),
#  ('every', 41),
#  ('post', 41),
#  ('lectures', 41),
#  ('whose', 41),
#  ('make', 41),
#  ('present', 41),
#  ('along', 41),
#  ('h', 41),
#  ('moral', 41),
#  ('went', 41),
#  ('said', 41),
#  ('views', 41),
#  ('paris', 41),
#  ('internet', 40),
#  ('edited', 40),
#  ('group', 40),
#  ('august', 40),
#  ('w', 40),
#  ('whole', 40),
#  ('means', 40),
#  ('real', 40),
#  ('famous', 40),
#  ('throughout', 40),
#  ('la', 40),
#  ('fact', 40),
#  ('within', 40),
#  ('oxford', 40),
#  ('account', 40),
#  ('cultural', 40),
#  ('student', 40),
#  ('translated', 40),
#  ('collection', 40),
#  ('george', 40),
#  ('role', 39),
#  ('process', 39),
#  ('encyclopedia', 39),
#  ('gave', 39),
#  ('articles', 39),
#  ('volume', 39),
#  ('robert', 39),
#  ('r', 39),
#  ('september', 39),
#  ('given', 39),
#  ('reason', 39),
#  ('writers', 39),
#  ('continued', 39),
#  ('paul', 39),
#  ('law', 39),
#  ('title', 39),
#  ('living', 39),
#  ('different', 39),
#  ('find', 39),
#  ('free', 39),
#  ('editor', 38),
#  ('short', 38),
#  ('\xc3', 38),
#  ('set', 38),
#  ('article', 38),
#  ('spent', 38),
#  ('something', 38),
#  ('worked', 38),
#  ('daughter', 38),
#  ('domain', 38),
#  ('subject', 38),
#  ('character', 38),
#  ('mother', 38),
#  ('result', 38),
#  ('religion', 38),
#  ('remained', 38),
#  ('main', 38),
#  ('review', 38),
#  ('academic', 37),
#  ('november', 37),
#  ('home', 37),
#  ('selected', 37),
#  ('include', 37),
#  ('g', 37),
#  ('possible', 37),
#  ('believed', 37),
#  ('relationship', 37),
#  ('co', 37),
#  ('tradition', 37),
#  ('named', 37),
#  ('returned', 37),
#  ('ethics', 37),
#  ('introduction', 37),
#  ('stanford', 37),
#  ('attempt', 37),
#  ('style', 37),
#  ('william', 37),
#  ('teaching', 37),
#  ('active', 37),
#  ('critics', 37),
#  ('good', 37),
#  ('body', 37),
#  ('analysis', 37),
#  ('practice', 37),
#  ('letters', 36),
#  ('popular', 36),
#  ('met', 36),
#  ('third', 36),
#  ('founded', 36),
#  ('wife', 36),
#  ('research', 36),
#  ('anti', 36),
#  ('david', 36),
#  ('read', 36),
#  ('described', 36),
#  ('ii', 36),
#  ('question', 36),
#  ('politics', 36),
#  ('united', 36),
#  ('still', 36),
#  ('foundation', 36),
#  ('british', 36),
#  ('collected', 36),
#  ('common', 36),
#  ('method', 36),
#  ('five', 36),
#  ('translation', 36),
#  ('final', 36),
#  ('argues', 36),
#  ('followed', 35),
#  ('f', 35),
#  ('period', 35),
#  ('live', 35),
#  ('students', 35),
#  ('late', 35),
#  ('young', 35),
#  ('system', 35),
#  ('cannot', 35),
#  ('europe', 35),
#  ('write', 35),
#  ('institute', 35),
#  ('france', 35),
#  ('argued', 35),
#  ('fellow', 35),
#  ('working', 34),
#  ('full', 34),
#  ('michael', 34),
#  ('today', 34),
#  ('case', 34),
#  ('christian', 34),
#  ('attention', 34),
#  ('academy', 34),
#  ('government', 34),
#  ('terms', 34),
#  ('forms', 34),
#  ('friends', 34),
#  ('say', 34),
#  ('saw', 34),
#  ('certain', 34),
#  ('house', 34),
#  ('particularly', 34),
#  ('far', 34),
#  ('former', 33),
#  ('put', 33),
#  ('beginning', 33),
#  ('sciences', 33),
#  ('person', 33),
#  ('future', 33),
#  ('historian', 33),
#  ('natural', 33),
#  ('open', 33),
#  ('taken', 33),
#  ('soon', 33),
#  ('seen', 33),
#  ('either', 33),
#  ('approach', 33),
#  ('term', 33),
#  ('july', 33),
#  ('produced', 33),
#  ('principles', 33),
#  ('attended', 33),
#  ('contributions', 33),
#  ('makes', 32),
#  ('metaphysics', 32),
#  ('leading', 32),
#  ('vol', 32),
#  ('high', 32),
#  ('studying', 32),
#  ('et', 32),
#  ('poetry', 32),
#  ('appeared', 32),
#  ('regarded', 32),
#  ('field', 32),
#  ('thomas', 32),
#  ('individual', 32),
#  ('already', 32),
#  ('true', 32),
#  ('january', 32),
#  ('authors', 32),
#  ('material', 32),
#  ('artist', 32),
#  ('poet', 32),
#  ('scholars', 32),
#  ('interpretation', 32),
#  ('come', 32),
#  ('hand', 31),
#  ('men', 31),
#  ('making', 31),
#  ('child', 31),
#  ('expression', 31),
#  ('jewish', 31),
#  ('change', 31),
#  ('march', 31),
#  ('felt', 31),
#  ('des', 31),
#  ('existence', 31),
#  ('charles', 31),
#  ('center', 31),
#  ('god', 31),
#  ('pp', 31),
#  ('october', 31),
#  ('theories', 31),
#  ('presented', 31),
#  ('cause', 31),
#  ('volumes', 31),
#  ('right', 31),
#  ('ever', 31),
#  ('children', 31),
#  ('widely', 31),
#  ('past', 30),
#  ('sometimes', 30),
#  ('special', 30),
#  ('berlin', 30),
#  ('basis', 30),
#  ('yet', 30),
#  ('figure', 30),
#  ('list', 30),
#  ('available', 30),
#  ('april', 30),
#  ('recent', 30),
#  ('publications', 30),
#  ('referred', 30),
#  ('der', 30),
#  ('faculty', 30),
#  ('logic', 30),
#  ('writes', 30),
#  ('becoming', 30),
#  ('experiences', 30),
#  ('association', 30),
#  ('die', 30),
#  ('nothing', 30),
#  ('related', 30),
#  ('scholar', 30),
#  ('object', 30),
#  ('elements', 30),
#  ('word', 30),
#  ('independent', 30),
#  ('james', 30),
#  ('translations', 30),
#  ('december', 30),
#  ('know', 30),
#  ('therefore', 29),
#  ('next', 29),
#  ('religious', 29),
#  ('spirit', 29),
#  ('gutenberg', 29),
#  ('traditional', 29),
#  ('questions', 29),
#  ('difficult', 29),
#  ('play', 29),
#  ('community', 29),
#  ('notion', 29),
#  ('physical', 29),
#  ('legacy', 29),
#  ('texts', 29),
#  ('european', 29),
#  ('earlier', 29),
#  ('heart', 29),
#  ('issue', 29),
#  ('principle', 29),
#  ('think', 29),
#  ('simply', 29),
#  ('criticized', 29),
#  ('instead', 29),
#  ('scientific', 29),
#  ('richard', 29),
#  ('publishing', 29),
#  ('eventually', 29),
#  ('brother', 29),
#  ('june', 29),
#  ('germany', 28),
#  ('jean', 28),
#  ('turn', 28),
#  ('version', 28),
#  ('ability', 28),
#  ('action', 28),
#  ('anything', 28),
#  ('critique', 28),
#  ('kind', 28),
#  ('prominent', 28),
#  ('matter', 28),
#  ('greatest', 28),
#  ('due', 28),
#  ('support', 28),
#  ('st', 28),
#  ('rest', 28),
#  ('highly', 28),
#  ('created', 28),
#  ('latter', 28),
#  ('months', 28),
#  ('peter', 28),
#  ('president', 28),
#  ('reader', 28),
#  ('thing', 28),
#  ('italian', 28),
#  ('accepted', 28),
#  ('problems', 28),
#  ('class', 28),
#  ('less', 28),
#  ('magazine', 28),
#  ('kant', 28),
#  ('beyond', 28),
#  ('sources', 28),
#  ('call', 28),
#  ('claims', 28),
#  ('understood', 28),
#  ('master', 27),
#  ('opposed', 27),
#  ('despite', 27),
#  ('away', 27),
#  ('teacher', 27),
#  ('discussion', 27),
#  ('correspondence', 27),
#  ('america', 27),
#  ('close', 27),
#  ('similar', 27),
#  ('reputation', 27),
#  ('papers', 27),
#  ('degree', 27),
#  ('perhaps', 27),
#  ('act', 27),
#  ('beautiful', 27),
#  ('columbia', 27),
#  ('greek', 27),
#  ('strong', 27),
#  ('finally', 27),
#  ('towards', 27),
#  ('understand', 27),
#  ('thesis', 27),
#  ('might', 27),
#  ('large', 27),
#  ('church', 27),
#  ('inspired', 27),
#  ('conditions', 27),
#  ('remains', 27),
#  ('freedom', 27),
#  ('entitled', 27),
#  ('consciousness', 27),
#  ('topics', 27),
#  ('members', 27),
#  ('purpose', 27),
#  ('belief', 27),
#  ('limited', 27),
#  ('six', 27),
#  ('contributed', 27),
#  ('beauty', 27),
#  ('joseph', 27),
#  ('thinkers', 27),
#  ('involved', 27),
#  ('importance', 27),
#  ('thoughts', 27),
#  ('response', 27),
#  ('lecture', 27),
#  ('claimed', 27),
#  ('longer', 27),
#  ('ways', 27),
#  ('believe', 27),
#  ('problem', 26),
#  ('toward', 26),
#  ('positions', 26),
#  ('appointed', 26),
#  ('parts', 26),
#  ('necessary', 26),
#  ('universal', 26),
#  ('classical', 26),
#  ('introduced', 26),
#  ('primary', 26),
#  ('n', 26),
#  ('story', 26),
#  ('birth', 26),
#  ('love', 26),
#  ('almost', 26),
#  ('includes', 26),
#  ('line', 26),
#  ('evidence', 26),
#  ('revolution', 26),
#  ('indeed', 26),
#  ('pure', 26),
#  ('novel', 26),
#  ('near', 26),
#  ('middle', 26),
#  ('significant', 26),
#  ('back', 26),
#  ('giving', 26),
#  ('western', 26),
#  ('issues', 26),
#  ('schools', 26),
#  ('desire', 26),
#  ('laws', 26),
#  ('conception', 26),
#  ('help', 26),
#  ('frequently', 26),
#  ('show', 26),
#  ('objects', 26),
#  ('taking', 26),
#  ('attempted', 26),
#  ('psychology', 26),
#  ('latin', 26),
#  ('concepts', 26),
#  ('course', 26),
#  ('england', 26),
#  ('structure', 26),
#  ('says', 26),
#  ('originally', 25),
#  ('turned', 25),
#  ('formed', 25),
#  ('considerable', 25),
#  ('subjects', 25),
#  ('learned', 25),
#  ('grew', 25),
#  ('merely', 25),
#  ('enough', 25),
#  ('20th', 25),
#  ('shortly', 25),
#  ('refused', 25),
#  ('describes', 25),
#  ('theology', 25),
#  ('give', 25),
#  ('points', 25),
#  ('reference', 25),
#  ('titled', 25),
#  ('librivox', 25),
#  ('events', 25),
#  ('strongly', 25),
#  ('k', 25),
#  ('theoretical', 25),
#  ('using', 25),
#  ('expressed', 25),
#  ('manuscript', 25),
#  ('standard', 25),
#  ('und', 25),
#  ('done', 25),
#  ('least', 25),
#  ('single', 25),
#  ('childhood', 25),
#  ('outside', 25),
#  ('eds', 25),
#  ('light', 25),
#  ('summer', 25),
#  ('activity', 25),
#  ('need', 25),
#  ('better', 25),
#  ('audiobooks', 25),
#  ('henry', 25),
#  ('perception', 25),
#  ('objective', 24),
#  ('von', 24),
#  ('shared', 24),
#  ('develop', 24),
#  ('dissertation', 24),
#  ('guide', 24),
#  ('key', 24),
#  ('lost', 24),
#  ('previously', 24),
#  ('seven', 24),
#  ('faith', 24),
#  ('concerns', 24),
#  ('19th', 24),
#  ('revised', 24),
#  ('possibility', 24),
#  ('condition', 24),
#  ('information', 24),
#  ('marriage', 24),
#  ('dedicated', 24),
#  ('neither', 24),
#  ('addition', 24),
#  ('fall', 24),
#  ('complex', 24),
#  ('associated', 24),
#  ('logical', 24),
#  ('buried', 24),
#  ('started', 24),
#  ('served', 24),
#  ('ancient', 24),
#  ('completed', 24),
#  ('everything', 24),
#  ('stated', 24),
#  ('gives', 24),
#  ('brought', 24),
#  ('asked', 24),
#  ('scholarship', 24),
#  ('really', 24),
#  ('editions', 24),
#  ('online', 24),
#  ('relations', 24),
#  ('able', 24),
#  ('effect', 24),
#  ('youth', 24),
#  ('relation', 24),
#  ('appearance', 24),
#  ('helped', 24),
#  ('noted', 24),
#  ('women', 24),
#  ('feeling', 23),
#  ('lives', 23),
#  ('department', 23),
#  ('north', 23),
#  ('speaking', 23),
#  ('remain', 23),
#  ('republic', 23),
#  ('determined', 23),
#  ('figures', 23),
#  ('space', 23),
#  ('fully', 23),
#  ('creation', 23),
#  ('distinguished', 23),
#  ('refers', 23),
#  ('create', 23),
#  ('private', 23),
#  ('value', 23),
#  ('origin', 23),
#  ('joined', 23),
#  ('fundamental', 23),
#  ('contains', 23),
#  ('film', 23),
#  ('focus', 23),
#  ('concern', 23),
#  ('numerous', 23),
#  ('whether', 23),
#  ('played', 23),
#  ('side', 23),
#  ('artistic', 23),
#  ('opinion', 23),
#  ('suggested', 23),
#  ('radical', 23),
#  ('plays', 23),
#  ('becomes', 23),
#  ('quality', 23),
#  ('force', 23),
#  ('harvard', 23),
#  ('claim', 23),
#  ('california', 23),
#  ('maintained', 23),
#  ('mental', 23),
#  ('meeting', 23),
#  ('lines', 23),
#  ('wide', 23),
#  ('sons', 23),
#  ('return', 23),
#  ('opposition', 23),
#  ('service', 22),
#  ('intended', 22),
#  ('era', 22),
#  ('karl', 22),
#  ('party', 22),
#  ('basic', 22),
#  ('composed', 22),
#  ('king', 22),
#  ('letter', 22),
#  ('morality', 22),
#  ('defined', 22),
#  ('official', 22),
#  ('variety', 22),
#  ('reception', 22),
#  ('entirely', 22),
#  ('impossible', 22),
#  ('essence', 22),
#  ('decided', 22),
#  ('uses', 22),
#  ('specific', 22),
#  ('model', 22),
#  ('allowed', 22),
#  ('poems', 22),
#  ('argument', 22),
#  ('aspects', 22),
#  ('meant', 22),
#  ('division', 22),
#  ('supported', 22),
#  ('sees', 22),
#  ('largely', 22),
#  ('ideal', 22),
#  ('unity', 22),
#  ('alone', 22),
#  ('inspiration', 22),
#  ('devoted', 22),
#  ('tried', 22),
#  ('senses', 22),
#  ('lies', 22),
#  ('doctrine', 22),
#  ('mark', 22),
#  ('practical', 22),
#  ('distinct', 22),
#  ('visiting', 22),
#  ('wanted', 22),
#  ('christianity', 22),
#  ('lack', 22),
#  ('absolute', 21),
#  ('effects', 21),
#  ('vision', 21),
#  ('caused', 21),
#  ('small', 21),
#  ('company', 21),
#  ('identity', 21),
#  ('daniel', 21),
#  ('justice', 21),
#  ('limits', 21),
#  ('imagination', 21),
#  ('source', 21),
#  ('direction', 21),
#  ('director', 21),
#  ('routledge', 21),
#  ('higher', 21),
#  ('suggests', 21),
#  ('prize', 21),
#  ('explained', 21),
#  ('voice', 21),
#  ('go', 21),
#  ('distinction', 21),
#  ('pleasure', 21),
#  ('moment', 21),
#  ('humanity', 21),
#  ('head', 21),
#  ('deeply', 21),
#  ('controversial', 21),
#  ('perceived', 21),
#  ('appear', 21),
#  ('rational', 21),
#  ('beliefs', 21),
#  ('page', 21),
#  ('supposed', 21),
#  ('leads', 21),
#  ('subsequent', 21),
#  ('seems', 21),
#  ('influences', 21),
#  ('essential', 21),
#  ('2nd', 21),
#  ('east', 21),
#  ('quite', 21),
#  ('note', 21),
#  ('defended', 21),
#  ('concerned', 21),
#  ('etc', 21),
#  ('woman', 21),
#  ('rejected', 21),
#  ('marked', 21),
#  ('actually', 21),
#  ('clear', 21),
#  ('walter', 21),
#  ('earned', 21),
#  ('answer', 21),
#  ('generally', 21),
#  ('notable', 21),
#  ('italy', 21),
#  ('progress', 21),
#  ('memory', 21),
#  ('saying', 20),
#  ('union', 20),
#  ('west', 20),
#  ('hugh', 20),
#  ('parents', 20),
#  ('placed', 20),
#  ('trans', 20),
#  ('description', 20),
#  ('reflections', 20),
#  ('entire', 20),
#  ('representation', 20),
#  ('range', 20),
#  ('theorist', 20),
#  ('readers', 20),
#  ('current', 20),
#  ('failed', 20),
#  ('forth', 20),
#  ('brief', 20),
#  ('du', 20),
#  ('interested', 20),
#  ('conservative', 20),
#  ('greatly', 20),
#  ('hegel', 20),
#  ('required', 20),
#  ('instance', 20),
#  ('rights', 20),
#  ('britannica', 20),
#  ('le', 20),
#  ('ultimately', 20),
#  ('regarding', 20),
#  ('except', 20),
#  ('design', 20),
#  ('health', 20),
#  ('continental', 20),
#  ('spiritual', 20),
#  ('virtue', 20),
#  ('painting', 20),
#  ('elected', 20),
#  ('alexander', 20),
#  ('educated', 20),
#  ('proper', 20),
#  ('court', 20),
#  ('yale', 20),
#  ('creative', 20),
#  ('cited', 20),
#  ('dead', 20),
#  ('learning', 20),
#  ('visit', 20),
#  ('artists', 20),
#  ('contribution', 20),
#  ('qualities', 20),
#  ('soul', 20),
#  ('aspect', 20),
#  ('extensive', 20),
#  ('notably', 20),
#  ('drama', 20),
#  ('chief', 20),
#  ('permanent', 20),
#  ('awarded', 20),
#  ('calls', 20),
#  ('passed', 20),
#  ('universities', 20),
#  ('mostly', 19),
#  ('engaged', 19),
#  ('divine', 19),
#  ('paper', 19),
#  ('definition', 19),
#  ('methods', 19),
#  ('recognition', 19),
#  ('musical', 19),
#  ('produce', 19),
#  ('biographer', 19),
#  ('royal', 19),
#  ('founder', 19),
#  ('perspective', 19),
#  ('fiction', 19),
#  ('subsequently', 19),
#  ('reached', 19),
#  ('occasion', 19),
#  ('ought', 19),
#  ('days', 19),
#  ('proposed', 19),
#  ('leaving', 19),
#  ('goal', 19),
#  ('collections', 19),
#  ('exist', 19),
#  ('actions', 19),
#  ('results', 19),
#  ('sent', 19),
#  ('sister', 19),
#  ('notions', 19),
#  ('thinker', 19),
#  ('behind', 19),
#  ('else', 19),
#  ('attack', 19),
#  ('context', 19),
#  ('recognized', 19),
#  ('rome', 19),
#  ('audience', 19),
#  ('essentially', 19),
#  ('pre', 19),
#  ('emphasis', 19),
#  ('recently', 19),
#  ('respect', 19),
#  ('country', 19),
#  ('constantly', 19),
#  ('leave', 19),
#  ('mass', 19),
#  ('enlightenment', 19),
#  ('formal', 19),
#  ('continue', 19),
#  ('applied', 19),
#  ('directly', 19),
#  ...]

# %%
sorted(FreqDist(philosophers['ethicists']["tokens"]).items(),key=operator.itemgetter(1),reverse=True)
# Out:
# []

# %% [markdown]
# ** Next, we calculate IDF for every word. **
#     - What base logarithm did you use? Is that important?

# %% [markdown]
# ** We're ready to calculate TF-IDF. Do that for each branch. **
#
#     - List the 10 top words for each branch.
#     -  Are these 10 words more descriptive of the branch? If yes, what is it about IDF that makes the words more informative?

# %% [markdown]
# ** Normally, TF-IDF is used for single documents. What does TF-IDF tell us about the content of a single document in a collection. **

# %% [markdown]
# # Sentiment Analysis
#
# Sentiment analysis is another highly useful technique. It doesn't tie in strongly with our work on Wikipedia (more on that in the video), but we'll go through it here because experience shows that sentiment analysis might well be very useful when you get to the project stage of the class.

# %% [markdown]
# ** Download the LabMT wordlist. It's available as supplementary material from Temporal Patterns of Happiness and Information in a Global Social Network: Hedonometrics and Twitter (Data Set S1). Describe briefly how the list was generated. **
#
# - The dataset was constructed with human evaluations of thw top 5000 (sorted by frequency of each word in the text) from the text sources: Twitter, Google Books, music lyrics and New York times. The overall list is 10222 words. For evaluation of happyness of each word they asked users on Mechanical Turk to rate how a given word made them feel on a nine point integer scale, obtaining 50 independent evaluations per word.

# %% [markdown]
# ** Based on the LabMT word list, write a function that calculates sentiment given a list of tokens (the tokens should be lower case, etc). The function should complain if there are no words with sentiment attached. **
#
#
# The level of happiness in a text is calculated with the following equation
# $ \sum_{i=1}^{N} h_{avg}(w_i)* p_i $, where $p_i = f_i / \sum_{i=1}^{N} f_j$ and $h_{avg}(w_i)$ is the estimate of average happiness of that word.

# %% [markdown]
# We start of by getting the average happiness of each word in Data set S1 into a dictionary. We do this by reading dat set line by line and for each line (exept the first 4 lines) into a dictionary

# %%
from collections import defaultdict

# counter to count the number of lines that have been processed
counter = 0

happyness_rank = defaultdict(float)

with open('/Users/GretarAtli/Documents/GitHub/Dtu/Dtu-SocialGraphsAndInteractions/week_seven/SensitivityAnalysisDataset1/Data_Set_S1.txt') as f:
    for line in f:
        counter += 1
        
        # we want to skip the first 4 lines of the file
        if counter > 4:
            line = line.split()
            word = line[0]  # get the word from the line
            happiness_average = float(line[2]) # get the word happiness average
            happyness_rank[word] = happiness_average

# %% [markdown]
# Now we are ready to create a function that calculates the sentiment of a given list of tokens

# %%
import numpy as np

from __future__ import division

# Takes in a list of tokens and happiness_keys which is the list of words in data set 1
# returns the mean value of the happiness rank that was found in the tokens array
# if no value was found then the function returns 0
def estimateHappiness(tokens,happiness_keys):
    
    happiness_avg = [] # an array that contains the average happyness values of the tokens
    
    for token in tokens:
        if token in happiness_keys: # only include the words that can be found in the data set
            #print happyness_rank[token]
            happiness_avg.append(happyness_rank[token])

    if len(happiness_avg) == 0:
        return 0 # If no word in the tokens array is found in the dataset then we return 0
    else : 
        return np.mean(happiness_avg)

# %% [markdown]
# ** Calculate a sentiment profile for the novels in NLPP1e chapter 1. The sentiment profile has sentiment on the y-axis and position in the text on the x-axis. Use a moving average to show how the sentiment changes. Create profiles for sliding windows of length 15 words, 50 words, 100 words, 500 words. **

# %%
def getSentimentProfileData(text): 
    x = defaultdict(list) # container for the sentiment results for each sliding window length
    y = defaultdict(list) # container for the y axis for each sliding window length
    happiness_keys = set(happyness_rank.keys()) # The words in the data set 1
    steps = [15,50,100,500]

    for step in steps: 
        xkey = "x{}".format(step)
        ykey = "y{}".format(step)

        for i in range(len(text)-step):
            x[xkey].append(i)
            y[ykey].append(estimateHappiness(text[i:i + step], happiness_keys))
            
    return x, y

# %% [markdown]
# Finally everything is ready to calculate the sentiment profile for the novels in NLPP1e chapter 1. The novels are three and can be found in the nltk module under books.
#
# The novels are the following texts:
#
#     - text1: Moby Dick by Herman Melville 1851
#     - text2: Sense and Sensibility by Jane Austen 1811
#     - text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# Get the novels from the nltk module

import nltk
from nltk.book import *

novels = [text1,text2,text9]

# %% [markdown]
# Finally everything is ready to run our functions. This will result in profiles for each text for sliding windows of length 15 words, 50 words, 100 words, 500 words

# %%
colors = ["blue","red","green"]
titles = ["Moby Dick", "Sense and Sensibility", "The Man Who Was Thursday"]

for i,novel in enumerate(novels):
    
    print titles[i]
    
    # Calculate the sentiment profile for the novel
    x, y = getSentimentProfileData(novel)

    # plot the result
    plt.figure(figsize=(20,12))

    # sliding window of length 15
    plt.subplot(221)
    plt.plot(x["x15"], y["y15"], color=colors[i])
    plt.xlabel("Text position")
    plt.ylabel("Sentiment")
    plt.title('{} - sliding window of 15'.format(titles[i]))
    plt.grid(True)

    # sliding window of length 50
    plt.subplot(222)
    plt.plot(x["x50"], y["y50"], color=colors[i])
    plt.xlabel("Text position")
    plt.ylabel("Sentiment")
    plt.title('{} - sliding window of 50'.format(titles[i]))
    plt.grid(True)

    # sliding window of length 100
    plt.subplot(223)
    plt.plot(x["x100"], y["y100"], color=colors[i])
    plt.xlabel("Text position")
    plt.ylabel("Sentiment")
    plt.title('{} - sliding window of 100'.format(titles[i]))
    plt.grid(True)

    # sliding window of length 500
    plt.subplot(224)
    plt.plot(x["x500"], y["y500"], color=colors[i])
    plt.xlabel("Text position")
    plt.ylabel("Sentiment")
    plt.title('{} - sliding window of 500'.format(titles[i]))
    plt.grid(True)

    plt.show()

# %% [markdown]
# ** Comment on the sentiment profiles. Do they show a similar pattern? What is the effect of changing the size of the sliding window? **
#
# TODO Svara þessu
