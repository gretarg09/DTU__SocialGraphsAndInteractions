# %% [markdown]
# # Assignment 2

# %% [markdown]
# ### Import

# %%
import urllib2
import json
import re
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import collections
import numpy as np
from collections import Counter
from __future__ import division
import io

# %% [markdown]
# # Part I: Comunity Structure

# %% [markdown]
# ** Explain the concept of modularity in your own words. **
#
# **Modularity** is a measurement that allows us to quantify the goodness of a partition of a network into communities, where partition is a division of a network into an arbitrary number of groups such that each node belongs to one and only one group. More specifically, Modularity is a concept that measures systematic deviations from a random configuration of a network. This helps us indentifying groups that are embedded in a network, and finding nodes that interact more frequantly with each other than in a random network. Therefore modularity is simply a measurement of the systematic deviations from a random configuration. Networks with high modularity have dense connections between the nodes within modules but sparse connections between nodes in different modules
#
# The modularity of a network can be calculated with the following equation
#
# Equation 9.12
#
# $$ M_c = \sum_{c=1}^{n_c}[ \dfrac{L_c}{L} - (\dfrac{k_c}{2L}) ] $$
#
# where:
#
#     * L : total number of links in the network
#     * Lc = number of links in each community
#     * kc = total degree of the nodes

# %% [markdown]
# ** Now, calculate the modularity of the branches reported by the Wikipedia editors **

# %% [markdown]
# We start by creating a dictionary that contains the names of all philosophers in the each branch of philosophy

# %%
philosophers = {
    "aestheticians":{ "title":"title=List_of_aestheticians", "names":""},
    "epistemologists":{ "title":"title=List_of_epistemologists", "names":""},
    "ethicists":{ "title":"title=List_of_ethicists", "names":"" },
    "logicians":{ "title":"title=List_of_logicians", "names":"" },
    "metaphysicians":{ "title":"title=List_of_metaphysicians", "names":"" },
    "social and political philosophers":{ "title":"title=Index_of_sociopolitical_thinkers", "names":""}
}

# %% [markdown]
# We then loop through each branch's wikipage and collect the names of the philosophers

# %%
# set the parameters (explained in detail here https://www.mediawiki.org/wiki/API:Tutorial)
baseurl = "https://en.wikipedia.org/w/index.php?"
title = ""
action = "action=edit"

for i in philosophers:
    # construct the query
    query = "{}{}&{}".format(
        baseurl,
        philosophers[i]["title"],
        action
    )
    
    # use urllib and regex to get the list of philosophers
    wikiresponse = urllib2.urlopen(query)
    wikisource = wikiresponse.read()
    philosophers[i]["names"] = re.findall(r'\*.*?\[\[(.*?)[\]\|]', wikisource)

# Because the last 4 elements of the ethicists list and social and political philosophers are not philosophers
# they are left out
philosophers["ethicists"]["names"] = philosophers["ethicists"]["names"][:-4]
philosophers["social and political philosophers"]["names"] = philosophers["social and political philosophers"]["names"][:-4]

# %% [markdown]
# Then we loop through each philosopher's wikipage and in each page we find the links to other philosophers. From that information we create the undirected graph

# %%
G = nx.Graph() # Create a undirected graph

# First of all get all the philosophers
all_philophers = []
for i in philosophers:
    all_philophers = all_philophers + philosophers[i]["names"]

all_philosophers_uniq = set(all_philophers)
    
counter = 0

# set the parameters for the query (explained in detail here https://www.mediawiki.org/wiki/API:Tutorial)
baseurl = "https://en.wikipedia.org/w/api.php?"
actions = "action=query"
title = "titles="
content = "prop=revisions&rvprop=content"
dataformat = "format=json"

# iterate through the philosophers and for each philosphers download his wikipedia page
# The list comprehension goes through the list of philosophers and replaces " " for "_"
for philo in all_philosophers_uniq:
    query = "{}{}&{}{}&{}&{}".format(
        baseurl,
        actions,
        title,
        philo.replace(" ","_"),
        content,
        dataformat
    )
    #print(philo)
    #print(query)
    
    wikiresponse = urllib2.urlopen(query)
    theArticle = wikiresponse.read()
    
    # Add the philosopher to the graph
    G.add_node(philo)

    # use regex and the set.intersection function to find all philosophers that are linked from the 
    # wikipage of each philosopher
    linkedPhilosophers = set(re.findall(r'.*?\[\[(.*?)[\]\|]', theArticle)).intersection(all_philosophers_uniq)

    # Go through all the linked philosophers and add directed edge for each one
    for linkedPhilosopher in linkedPhilosophers:
        G.add_edge(philo,linkedPhilosopher)

# %% [markdown]
#  ** Algorithm procedure: **
#
#  - Our network has more than one component, So we need to get the giant connected component (GCC) of our network. We call it giant_G.
#  - Then we find the all of the philosophers in that network that are part of more than one branch (the overlapping_philo variable).
#  - If the philosopher is not in two branches we add him to a list of tuple pairs (name,community), we call this list philo_community_list. Therefore at this time in the program this list contains all philosophers that are only associated with one community
#  - The next step in our algorithm is to find a community for the philosophers that are in more than two branches (overlapping philosophers). The way we did it is that for each overlapping philosopher, we found all neighbours of that philosopher that are only in one branch (non overlapping neighbours). We then simply assigned the philosopher to the branch that most of his non overlapping neighbours are in, in other words we assigned the philosopher to the branch that he has most connections to. If the philosopher is not connected to any non overlapping philosopher then we simply chose a brand at random. **Note** We decided to only consider the non overlapping neighbor of the overlapping philosopher because it does not make sens to consider a neighbor that has not yet been assigned to a new branch by the rules of our algorithm
#  - Now philo_community_list contains all of the philosophers in the G_giant graph and each philosopher has been assigned to a branch
#  - Then we simply changed the philo_community_list into a dictionary and calculated the modularity of the community division.

# %%
# Get the Giant connected component (GCC)
giant_G = max(nx.connected_component_subgraphs(G), key=len)

# Get all philosophers in the giant connected component
giant_all_philosophers = giant_G.nodes()

giant_philosophers_counted = []

# Find all philosophers that appear in more than one list
for branch in philosophers.keys():
    for philo in philosophers[branch]["names"]:
        if philo in giant_all_philosophers:
            giant_philosophers_counted.append(philo)
            
giant_philosohers_counted = Counter(giant_philosophers_counted)

# The next step is to find all of the philosophers that are part of more than one branch
overlapping_philo =[philo for philo,value in giant_philosohers_counted.items() if value > 1]

# create the communities dictionary for the philosophers
philosophers_communities = {
    "aestheticians" : [],
    "epistemologists" : [],
    "ethicists" : [],
    "logicians" : [],
    "metaphysicians" : [],
    "social and political philosophers" : []
}

# Now we create a list of tuple pairs (name,community) that contain all philosophers that only appear in one list
philo_community_list = []
for community in philosophers_communities.keys():
    for name in philosophers[community]["names"]:
        # Add the philosopher if he is not overlapping 
        if name in giant_all_philosophers:
            if name not in overlapping_philo:
                philo_community_list.append((name,community))
                

# Now we go through the list of overlapping philosophers and add them to the list with a assigned community
philo_community_list_overlapping = [] # temp list that contains the added overlapping philos
for philo in overlapping_philo:
    # next we find the non overlapping neighbours of each overlapping philo.  
    neighbors = [neighbor for neighbor in philo_community_list if neighbor[0] in giant_G.neighbors(philo)]
    community = ""
    if neighbors: # check if neighbours is not an empty list
        # find the most common community
        neighbors_communities = Counter(neighbor_tuple[1] for neighbor_tuple in neighbors)
        community = max(neighbors_communities.items())
        # Check if there are communities that are equals if so then choose randomly from them
        community = np.random.choice([k for k, v in neighbors_communities.items() if v == community[1]])
    else:
        # in case of no neighbour we choose the community by random
        community = np.random.choice(["aestheticians","epistemologists","ethicists","logicians","metaphysicians","social and political philosophers"])
    
    # Add the phylosopher to the philo_community_list
    philo_community_list_overlapping.append((philo,community))

# Add the newly assingd overlapping philosophers to the philo_community_list
philo_community_list = philo_community_list + philo_community_list_overlapping

# %% [markdown]
# Now every philosopher in the giant component of our graph has been assigned to a branch. Therefore the division of the philosophers into a communities is done and we can calculate the modularity.

# %%
# We start by adding the philosophers into their communities in a dictionary
for philo in philo_community_list:
    philosophers_communities[philo[1]].append(philo[0])

# Then we loop throught the communities and calculate the modularity (Mc) for each community
modularity = []
L = len(giant_G.edges()) # L : total number of links in the network
for community in philosophers_communities.keys():
    sub_graph = giant_G.subgraph(philosophers_communities[community]) # Create a subgraph for the community
    Lc = len(sub_graph.edges()) # Total number of edges in the community
    kc = sum(sub_graph.degree().values()) # Total degree of the community
    M = (Lc/L)-((kc/(2*L))**2) # calculate the modularity for the community with equation 9.12
    modularity.append(M)

"The modularity is:    {}".format(sum(modularity))
# Out:
# 'The modularity is:    0.370380728451'

# %% [markdown]
# ** Comment on your value of $M$ for the branches. Are the branches good communities? **

# %% [markdown]
# We got the value of modularity as ~0.3704, but bare in mind there is a random factor in our algorithm so the result might vary a littlebit in each iteration but not much. As stated in Network Science in Chapter 9 there are several key properties to modularity. You can have a negative value of modularity as well as a modularity of zero, that is done by taking the whole network as a single community. Modularity can not go above 1 but the higher it is for a specific partition of the network, the better is the corresponding community structure. There are examples of optimal and suboptimal partitions in the book for a specific network. There the optimal modularity is 0.41 but the sup optimal modularity has the value 0.22. This gives us an idea of how good our partitioning is but to fully understand it we need to find the modularity of the optimal partitioning of the G_giant graph

# %% [markdown]
# **Now, let us use the Python Louvain-algorithm implementation to find communities in the full philosopher network **
#
# **Note** We did not think that it mate sens to calculate the optimal partitioning of the full network because our algorithm is only calculating the modularity of the giant component of the full network. Therefore we calculated both things but we will onlu comment on the result for the Giant component network

# %%
import community
import networkx as nx
import matplotlib.pyplot as plt


# First compute the best partition
partition_giant = community.best_partition(giant_G)
partition_full = community.best_partition(G)

# Find how many communities there are in the partition 
communities_giant = Counter([value for key,value in partition_giant.items()])
communities_full = Counter([value for key,value in partition_full.items()])

print "The full philosophy network is split up to {} communities".format(len(communities_full))
print "The modularity of this community division is {}".format(
    community.modularity(partition_full,G)
)

print "" 

print "The giant component of the philosophy network is split up to {} communities".format(len(communities))
print "The modularity of this community division is {}".format(
    community.modularity(partition_giant,giant_G)
)
# Out:
# The full philosophy network is split up to 210 communities
# The modularity of this community division is 0.454005049928
#
# The giant component of the philosophy network is split up to 12 communities
# The modularity of this community division is 0.455676160125

# %% [markdown]
# __Report the value of modularity found by the algorithm. Is it higher or lower than what you found above for the branches as communities? What does this comparison reveal about the branches?
# __

# %% [markdown]
# The **full network** is not a complete graph. The giant component of that graph contains 838 nodes but the full network contains 1047 nodes. To understand the behavior better we plotted up both the full network and the giant component. What the plot reveals is thet there are many philosophers that are not connected to any other philosophers. What the algorithm most likely does for the full network is that it creates a single community for each isolated node (philosopher) in the graph and then one community for the giant component.
#
# The optimal partition of our giant component partitiones the network into 12 communities. This division results in a modularity of 0.45401. Our algorithm is dividing the community into 6 communities, one for each brand. That division resulted in a modularity of 0.3704 which is not that far away from the optimal modularity value for the graph. Therefore we can safely concluded that the partitioning is sub optimal and quite good. We are dividing the into fewer communities but still resulting in a division with close enough modularity. This reveals that the branches division is  quite good community division but not optimal.

# %%
nx.draw(G, node_size=0.3)
plt.title("The full network")
plt.show()

nx.draw(giant_G, node_size=0.3)
plt.title("The giant component")
plt.show()

# %% [markdown]
# ** Compare the communities found by your algorithm with the branches (that you analyzed abo ve) by creating a matrix D with dimension ($B$ times $C$), where $B$ is the number of branches and $C$ is the number of communities. We set entry $D(i,j)$ to be the number of nodes that branch $i$ has in common with community $j$. The matrix D is what we call a confusion matrix. Use the confusion matrix to explain how well the communities you've detected correspond to the labeled branches of philosophy. **

# %%
import numpy as np

# We start by creating a 6*6 matrix

# Remember that philosophers dictionary contains the division from wiki
# and philosophers_communities contains our community algorithm division of the philosophers.

B = 6 # number of branches
C = 12 # number of communities in the optimal solution

confusion_matrix = np.empty((B,C,))
confusion_matrix[:] = np.NAN

for i,branch in enumerate(philosophers_communities.keys()):
    for j,community in enumerate(philosophers_communities):
        confusion_matrix[i,j] = len([philo for philo in philosophers_communities[community] 
                                 if philo in philosophers[branch]["names"]])

# %%
partition_giant
# Out:
# {'A. J. Ayer': 3,
#  'Abraham Fraenkel': 4,
#  'Abraham Joshua Heschel': 3,
#  'Abraham Robinson': 4,
#  'Abraham ibn Daud': 2,
#  'Abul Kalam Azad': 8,
#  'Adam M\xc3\xbcller': 5,
#  'Adam Smith': 5,
#  'Adolf Hitler': 1,
#  'Adolf Lindenbaum': 4,
#  'Adrian Johnston (philosopher)': 1,
#  'Al-Ghazali': 2,
#  'Alain Badiou': 1,
#  'Alan Carter (philosopher)': 6,
#  'Alan Gewirth': 1,
#  'Alan Ross Anderson': 9,
#  'Alan Ryan': 8,
#  'Alan Turing': 4,
#  'Alasdair MacIntyre': 1,
#  'Alasdair Urquhart': 9,
#  'Albert Camus': 1,
#  'Albert Schweitzer': 0,
#  'Albert of Saxony (philosopher)': 2,
#  'Alcuin': 2,
#  'Aldo Leopold': 3,
#  'Alexander Bain': 5,
#  'Alexander Campbell Fraser': 5,
#  'Alexander Gottlieb Baumgarten': 0,
#  'Alexander S. Kechris': 4,
#  'Alexander Zinoviev': 1,
#  'Alexander of Aphrodisias': 2,
#  'Alexis de Tocqueville': 5,
#  'Alfred North Whitehead': 4,
#  'Alfred Rosenberg': 1,
#  'Alfred Tarski': 4,
#  'Algernon Charles Swinburne': 8,
#  'Ali Shariati': 1,
#  'Alice Crary': 3,
#  'Allan Gibbard': 3,
#  'Alonzo Church': 4,
#  'Alvin Goldman': 3,
#  'Alvin Plantinga': 3,
#  'Amartya Sen': 5,
#  'Ambrose': 2,
#  'Anaximander': 2,
#  'Andronicus of Rhodes': 2,
#  'Andrzej Mostowski': 4,
#  'Andr\xc3\xa9 Malraux': 1,
#  'Anne Conway (philosopher)': 0,
#  'Anne Sjerp Troelstra': 4,
#  'Antonio Negri': 1,
#  'Ant\xc3\xb3nio Castanheira Neves': 3,
#  'Arda Denkel': 4,
#  'Arend Heyting': 4,
#  'Aristotle': 2,
#  'Aristoxenus': 2,
#  'Armin Mohler': 1,
#  'Arthur Danto': 3,
#  'Arthur Moeller van den Bruck': 0,
#  'Arthur Prior': 4,
#  'Arthur Schopenhauer': 0,
#  'Ashoka': 7,
#  'Auberon Herbert': 6,
#  'August Wilhelm Schlegel': 0,
#  'Augustine of Hippo': 2,
#  'Augustus De Morgan': 4,
#  'Austin Osman Spare': 1,
#  'Averroes': 2,
#  'Avicenna': 2,
#  'Axel Honneth': 1,
#  'Ayn Rand': 6,
#  'B. F. Skinner': 4,
#  'B. R. Ambedkar': 8,
#  'Bahmany\xc4\x81r': 2,
#  'Bahya ibn Paquda': 2,
#  'Barry Stroud': 3,
#  'Baruch Spinoza': 2,
#  'Benedetto Croce': 2,
#  'Benjamin Tucker': 6,
#  'Benjamin Wiker': 0,
#  'Berit Brogaard': 4,
#  'Bernard Bolzano': 0,
#  'Bernard Williams': 3,
#  'Bertrand Russell': 4,
#  'Bertrand de Jouvenel': 6,
#  'Bjarni J\xc3\xb3nsson': 4,
#  'Blaise Pascal': 1,
#  'Boethius': 2,
#  'Boris Furlan': 2,
#  'Bruno Leoni': 6,
#  'Bryan Caplan': 6,
#  'C. D. Broad': 3,
#  'C. Wright Mills': 6,
#  'Carew Arthur Meredith': 2,
#  'Carl Joachim Friedrich': 1,
#  'Carl Schmitt': 1,
#  'Carlo Lottieri': 6,
#  'Carlos Santiago Nino': 3,
#  'Categoriae decem': 2,
#  'Catherine Elgin': 4,
#  'Cesare Brandi': 1,
#  'Chanakya': 7,
#  'Charles Parsons (philosopher)': 4,
#  'Charles Sanders Peirce': 4,
#  'Charles Stevenson': 3,
#  'Charles Taylor (philosopher)': 3,
#  'Cha\xc3\xafm Perelman': 2,
#  'Cheng Hao': 7,
#  'Cheng Yi (philosopher)': 7,
#  'Christian Wolff (philosopher)': 0,
#  'Christine Korsgaard': 3,
#  'Christine Ladd-Franklin': 4,
#  'Christopher Janaway': 0,
#  'Chrysippus': 2,
#  'Cicero': 2,
#  'Clarence Irving Lewis': 4,
#  'Claude Adrien Helv\xc3\xa9tius': 5,
#  'Claude Lefort': 1,
#  'Claude L\xc3\xa9vi-Strauss': 1,
#  'Clive Bell': 6,
#  'Colin Wilson': 1,
#  'Confucius': 7,
#  'Conimbricenses': 2,
#  'Constantin R\xc4\x83dulescu-Motru': 1,
#  'Cora Diamond': 3,
#  'Cornel West': 1,
#  'Cornelius Castoriadis': 1,
#  'Costas Douzinas': 1,
#  'Dag Prawitz': 4,
#  'Dana Scott': 4,
#  'Daniel Brock': 5,
#  'Daniel Gu\xc3\xa9rin': 1,
#  'David Bohm': 4,
#  'David Chalmers': 4,
#  'David D. Friedman': 6,
#  'David Gauthier': 5,
#  'David Hilbert': 4,
#  'David Hume': 5,
#  'David K. Lewis': 4,
#  'David Kaplan (philosopher)': 4,
#  'David Kellogg Lewis': 4,
#  'David L. Norton': 2,
#  'David Lewis (philosopher)': 4,
#  'David Malet Armstrong': 3,
#  'David Miller (political theorist)': 6,
#  'David Pearce (philosopher)': 4,
#  'David Prychitko': 6,
#  'David Schmidtz': 6,
#  'David Sosa': 3,
#  'David Wiggins': 3,
#  'Dean Zimmerman': 4,
#  'Democritus': 2,
#  'Derek Parfit': 3,
#  'Dharmakirti': 8,
#  'Dick de Jongh': 10,
#  'Dietrich Bonhoeffer': 3,
#  'Dign\xc4\x81ga': 8,
#  'Dimitris Dimitrakos': 3,
#  'Diodorus Cronus': 2,
#  'Dirk van Dalen': 4,
#  'Disciples of Confucius': 7,
#  'Donna Haraway': 11,
#  'Dov Gabbay': 4,
#  'Dugald Stewart': 5,
#  'Duncan Kennedy (legal philosopher)': 8,
#  'Duns Scotus': 2,
#  'Edgar Allan Poe': 8,
#  'Edgar Morin': 1,
#  'Edmund Burke': 5,
#  'Edmund Gettier': 3,
#  'Edmund Gurney': 0,
#  'Eduard Hanslick': 3,
#  'Edward Burnett Tylor': 0,
#  'Edward Nelson': 4,
#  'Edward Said': 1,
#  'Ehud Hrushovski': 4,
#  'Eli Siegel': 2,
#  'Elizabeth Anscombe': 3,
#  'Emil Leon Post': 4,
#  'Emma Goldman': 8,
#  'Emmanuel Levinas': 1,
#  'Enrique Dussel': 1,
#  'Epicurus': 2,
#  'Eric Voegelin': 1,
#  'Erich Fromm': 1,
#  'Erich Heller': 1,
#  'Ernest Sosa': 3,
#  'Ernest Wamba dia Wamba': 1,
#  'Ernst Bloch': 1,
#  'Ernst Schr\xc3\xb6der': 4,
#  'Ernst Zermelo': 4,
#  'Ernst von Glasersfeld': 2,
#  'Eugen Rosenstock-Huessy': 1,
#  'Evert Willem Beth': 4,
#  'Felix Kaufmann': 6,
#  'Ferdinand de Saussure': 1,
#  'Ferruccio Busoni': 3,
#  'Francis Bacon': 2,
#  'Francis Fukuyama': 1,
#  'Francis Hutcheson (philosopher)': 5,
#  'Francis Jeffrey': 5,
#  'Francis Parker Yockey': 1,
#  'Francisco de Vitoria': 5,
#  'Frank Herbert': 1,
#  'Frank Meyer (political philosopher)': 6,
#  'Frank Sibley (philosopher)': 3,
#  'Franz Boas': 0,
#  'Franz Xaver von Baader': 5,
#  'Fran\xc3\xa7ois Hemsterhuis': 2,
#  'Fred Dretske': 3,
#  'Fred Poch\xc3\xa9': 1,
#  'Frederick Rowbottom': 4,
#  'Friedrich A. Hayek': 6,
#  'Friedrich Adolf Trendelenburg': 2,
#  'Friedrich Daniel Ernst Schleiermacher': 0,
#  'Friedrich Eduard Beneke': 0,
#  'Friedrich Engels': 1,
#  'Friedrich Hayek': 6,
#  'Friedrich Nietzsche': 1,
#  'Friedrich Schiller': 0,
#  'Friedrich Schleiermacher': 0,
#  'Friedrich Wilhelm Joseph von Schelling': 0,
#  'Frithjof Schuon': 2,
#  'Fr\xc3\xa9d\xc3\xa9ric Bastiat': 6,
#  'Fyodor Shcherbatskoy': 8,
#  'F\xc3\xa9lix Guattari': 1,
#  'G. E. M. Anscombe': 3,
#  'G. E. Moore': 3,
#  'G.W.F. Hegel': 1,
#  'Gabriele Taylor': 3,
#  'Galileo Galilei': 2,
#  'Gary Chartier': 6,
#  'Gary R. Mar': 4,
#  'Gautama Buddha': 7,
#  'Gene Callahan (economist)': 6,
#  'Geoffrey Sayre-McCord': 5,
#  'Georg Anton Friedrich Ast': 0,
#  'Georg Brandes': 5,
#  'Georg Cantor': 4,
#  'Georg Henrik von Wright': 3,
#  'Georg Jellinek': 1,
#  'Georg Kreisel': 4,
#  'Georg Simmel': 1,
#  'Georg W. F. Hegel': 8,
#  'Georg Wilhelm Friedrich Hegel': 1,
#  'George Berkeley': 5,
#  'George Birkhoff': 4,
#  'George Boole': 4,
#  'George Boolos': 4,
#  'George Croom Robertson': 5,
#  'George Edward Moore': 3,
#  'George Holmes Howison': 8,
#  'George Kateb': 5,
#  'George Pappas': 5,
#  'George Santayana': 8,
#  'Georges Bataille': 1,
#  'Gerald Cohen': 6,
#  'Gerald Dworkin': 3,
#  'Gerald Sacks': 4,
#  'Gerhard Gentzen': 4,
#  'Gerrard Winstanley': 1,
#  'Ghazali': 8,
#  'Giacomo Marramao': 1,
#  'Giambattista Vico': 2,
#  'Gianfranco Sanguinetti': 1,
#  'Giannina Braschi': 2,
#  'Gilbert Harman': 4,
#  'Gilbert Simondon': 1,
#  'Gilbert de la Porr\xc3\xa9e': 2,
#  'Gilles Deleuze': 1,
#  'Giorgi Japaridze': 4,
#  'Giorgio Agamben': 1,
#  'Giovanni Girolamo Saccheri': 2,
#  'Giuseppe Peano': 4,
#  'Gottfried Leibniz': 0,
#  'Gotthold Ephraim Lessing': 0,
#  'Gottlob Frege': 4,
#  'Graham Priest': 9,
#  'Gregory Chaitin': 4,
#  'Gualtiero Piccinini': 4,
#  'Gustave de Molinari': 6,
#  'Guy Aldred': 1,
#  'Guy Debord': 1,
#  'Gy\xc3\xb6rgy Luk\xc3\xa1cs': 1,
#  'H. B. Acton': 1,
#  'H. L. A. Hart': 3,
#  'H. Richard Niebuhr': 8,
#  'Hammurabi': 2,
#  'Han Fei': 7,
#  'Han Ryner': 2,
#  'Hannah Arendt': 1,
#  'Hans Achterhuis': 11,
#  'Hans Kelsen': 3,
#  'Hans K\xc3\xb6chler': 3,
#  'Hans Pfitzner': 3,
#  'Hans Singer': 1,
#  'Hans-Georg Gadamer': 1,
#  'Hans-Hermann Hoppe': 6,
#  'Hao Wang (academic)': 4,
#  'Har Dayal': 1,
#  'Harold Bloom': 8,
#  'Harriet Martineau': 5,
#  'Harriet Taylor Mill': 5,
#  'Harry Binswanger': 6,
#  'Hartry Field': 4,
#  'Harvey Friedman': 4,
#  'Haskell Curry': 4,
#  'Heinrich Gustav Hotho': 1,
#  'Heinz von Foerster': 0,
#  'Heiric of Auxerre': 2,
#  'Helena Rasiowa': 4,
#  'Hendrik Verwoerd': 8,
#  'Henk Barendregt': 4,
#  'Henri Bergson': 1,
#  'Henri Focillon': 1,
#  'Henri Lefebvre': 1,
#  'Henry David Thoreau': 8,
#  'Henry George': 5,
#  'Henry Hazlitt': 6,
#  'Henry Home, Lord Kames': 5,
#  'Henry Sidgwick': 3,
#  'Heraclitus': 2,
#  'Herbert Spencer': 1,
#  'Hermann Lotze': 0,
#  'Hermann Theodor Hettner': 1,
#  'Hierocles of Alexandria': 2,
#  'Hilary Putnam': 4,
#  'Hirata Atsutane': 7,
#  'Holly Martin Smith': 3,
#  'Houston Stewart Chamberlain': 1,
#  'Howard Jerome Keisler': 4,
#  'Howard Zinn': 8,
#  'Hsun Tzu': 7,
#  'Hugh MacColl': 4,
#  'Hugo Grotius': 5,
#  'Hui Shi': 7,
#  'Ian Rumfitt': 4,
#  'Ibn Taymiyyah': 8,
#  'Igor Pribac': 5,
#  'Immanuel Kant': 0,
#  'Inayatullah Khan Mashriqi': 1,
#  'Iris Marion Young': 1,
#  'Iris Murdoch': 3,
#  'Isaac Levi': 8,
#  'Isaac Malitz': 4,
#  'Isaac Watts': 5,
#  'Isabel Paterson': 6,
#  'Isaiah Berlin': 3,
#  'Israel Kirzner': 6,
#  'Israr Ahmed': 8,
#  'It\xc5\x8d Jinsai': 7,
#  'Ivan Orlov (philosopher)': 4,
#  'Ivan Svit\xc3\xa1k': 1,
#  'J. Barkley Rosser': 4,
#  'J. J. C. Smart': 3,
#  'J. L. Mackie': 3,
#  'J. M. E. McTaggart': 3,
#  'Jaakko Hintikka': 4,
#  'Jack Copeland': 4,
#  'Jack Russell Weinstein': 5,
#  'Jacob M. Appel': 3,
#  'Jacopo Zabarella': 2,
#  'Jacques Derrida': 1,
#  'Jacques Herbrand': 4,
#  'Jacques Lacan': 1,
#  'Jacques Maritain': 8,
#  'Jacques Ranci\xc3\xa8re': 1,
#  'James Brusseau': 1,
#  'James Childress': 5,
#  'James Earl Baumgartner': 4,
#  'James Frederick Ferrier': 5,
#  'James Joyce': 2,
#  'James Martineau': 5,
#  'James Mill': 5,
#  'James Tully (philosopher)': 3,
#  'James VI and I': 2,
#  'Jamie Whyte': 6,
#  'Jan \xc5\x81ukasiewicz': 4,
#  'Jane Jacobs': 0,
#  'Janet Biehl': 1,
#  'Jawaharlal Nehru': 8,
#  'Jay Rosenberg': 0,
#  'Jean Anthelme Brillat-Savarin': 5,
#  'Jean Bodin': 2,
#  'Jean Buridan': 2,
#  'Jean Grondin': 1,
#  'Jean Nicod': 4,
#  'Jean Piaget': 1,
#  'Jean Van Heijenoort': 4,
#  'Jean-Fran\xc3\xa7ois Lyotard': 1,
#  'Jean-Jacques Rousseau': 5,
#  'Jean-Louis Le Moigne': 2,
#  'Jean-Paul Sartre': 1,
#  'Jean-Yves B\xc3\xa9ziau': 4,
#  'Jean-Yves Girard': 4,
#  'Jeff Paris': 4,
#  'Jeffrey Stout': 1,
#  'Jennifer Lackey': 3,
#  'Jenny Teichman': 3,
#  'Jeremy Bentham': 5,
#  'Jeroen Groenendijk': 10,
#  'Jerrold Levinson': 3,
#  'Jesus': 2,
#  'Jin Yuelin': 4,
#  'Jody Azzouni': 4,
#  'Johan van Benthem (logician)': 10,
#  'Johann Albert Fabricius': 2,
#  'Johann Friedrich Herbart': 0,
#  'Johann Gottfried Herder': 0,
#  'Johann Heinrich Lambert': 0,
#  'John Anderson (philosopher)': 3,
#  'John Austin (legal philosopher)': 3,
#  'John Burnheim': 6,
#  'John Cage': 8,
#  'John Corcoran (logician)': 4,
#  'John Dewey': 8,
#  'John Dumbleton': 2,
#  'John Duns Scotus': 2,
#  'John Etchemendy': 4,
#  'John Finnis': 3,
#  'John Harsanyi': 5,
#  'John Hawthorne': 4,
#  'John Hospers': 6,
#  'John Howard Yoder': 8,
#  'John Lane Bell': 9,
#  'John Locke': 5,
#  'John M. Cooper (philosopher)': 2,
#  'John Major (philosopher)': 5,
#  'John McDowell': 3,
#  'John Oswald (activist)': 5,
#  'John Pagus': 4,
#  'John Rawls': 3,
#  'John Ruskin': 8,
#  'John Searle': 4,
#  'John Shelby Spong': 2,
#  'John Stuart Mill': 5,
#  'John Venn': 4,
#  'John William Miller': 8,
#  'John Woods (logician)': 4,
#  'John Zerzan': 1,
#  'John of St. Thomas': 8,
#  'John von Neumann': 4,
#  'John_Greco (philosopher)': 3,
#  'Jon Barwise': 4,
#  'Jonathan Dancy': 3,
#  'Jonathan Edwards (theologian)': 5,
#  'Jonathan Wolff (philosopher)': 6,
#  'Joseph Diaz Gergonne': 4,
#  'Joseph Fins': 8,
#  'Joseph Kosuth': 1,
#  'Joseph Priestley': 5,
#  'Joseph Raz': 3,
#  'Joshua Cohen (philosopher)': 3,
#  'Joxe Azurmendi': 0,
#  'Juan Luis Vives': 2,
#  'Judith Butler': 1,
#  'Judith Jarvis Thomson': 3,
#  'Jules Vuillemin': 4,
#  'Julia Annas': 2,
#  'Julian Gumperz': 1,
#  'Julian Savulescu': 3,
#  'Julien Offray de La Mettrie': 5,
#  'Julius Binder': 0,
#  'J\xc3\xbcrgen Habermas': 1,
#  'Kaibara Ekken': 7,
#  'Karel Lambert': 4,
#  'Karl Immanuel Nitzsch': 0,
#  'Karl Loewenstein': 1,
#  'Karl Marx': 1,
#  'Karl Popper': 2,
#  'Karl Wilhelm Ferdinand Solger': 0,
#  'Karl Wilhelm Friedrich von Schlegel': 0,
#  'Karl-Otto Apel': 1,
#  'Kazimierz Ajdukiewicz': 0,
#  'Kazimierz Twardowski': 0,
#  'Keith Lehrer': 6,
#  'Kendall Walton': 3,
#  'Kenneth Kunen': 4,
#  'Kevin Carson': 6,
#  'Kit Fine': 9,
#  'Kurt G\xc3\xb6del': 4,
#  'Kurt Sch\xc3\xbctte': 4,
#  'L. A. Paul': 4,
#  'L. T. F. Gamut': 10,
#  'L.A. Paul': 4,
#  'Lalita Pandit': 1,
#  'Langdon Winner': 11,
#  'Lawrence Kohlberg': 1,
#  'Leo Harrington': 4,
#  'Leo Tolstoy': 3,
#  'Leon Chwistek': 4,
#  'Leon Henkin': 4,
#  'Leonard Borgzinner': 1,
#  'Leonard Peikoff': 6,
#  'Leonard Read': 6,
#  'Leopold Kronecker': 4,
#  'Leopold L\xc3\xb6wenheim': 4,
#  'Leslie Stephen': 6,
#  'Lewis Call': 1,
#  'Lewis Carroll': 5,
#  'Lewis H. Morgan': 1,
#  'Lon L. Fuller': 3,
#  'Longinus (literature)': 2,
#  'Lorenzo Pe\xc3\xb1a': 9,
#  'Lorenzo Valla': 2,
#  'Lotfi A. Zadeh': 9,
#  'Louis Althusser': 1,
#  'Lucretius': 2,
#  'Ludwig Wittgenstein': 3,
#  'Ludwig von Mises': 6,
#  'Luitzen Egbertus Jan Brouwer': 4,
#  'Lynne Rudder Baker': 4,
#  'Lysander Spooner': 6,
#  'Magnus Hundt': 2,
#  'Maimonides': 2,
#  'Mao Zedong': 1,
#  'Margaret Canovan': 5,
#  'Margaret Mead': 0,
#  'Marianne Weber': 1,
#  'Marilyn McCord Adams': 2,
#  'Mario Bunge': 4,
#  'Mario Kopi\xc4\x87': 1,
#  'Mario Tronti': 1,
#  'Marquis de Sade': 1,
#  'Marsilius of Inghen': 2,
#  'Martha Nussbaum': 3,
#  'Martin Buber': 1,
#  'Martin Davis': 4,
#  'Martin Heidegger': 1,
#  'Martin Luther King, Jr.': 3,
#  'Martin L\xc3\xb6b': 10,
#  'Martin Stokhof': 10,
#  'Mary Daly': 1,
#  'Matthew Foreman': 4,
#  'Maurice Blanchot': 1,
#  'Maurice Brinton': 1,
#  'Maurice Cranston': 5,
#  'Max Baginski': 8,
#  'Max Black': 3,
#  'Max Horkheimer': 1,
#  'Max Scheler': 1,
#  'Max Stirner': 1,
#  'Max Weber': 1,
#  'Mazen Asfour': 2,
#  'Melvin Fitting': 4,
#  'Mencius': 7,
#  'Menedemus': 2,
#  'Michael A. Smith': 5,
#  'Michael Devitt': 4,
#  'Michael Fourman': 4,
#  'Michael J. Sandel': 3,
#  'Michael O. Rabin': 4,
#  'Michael Oakeshott': 1,
#  'Michael Otsuka': 6,
#  'Michael Sprinker': 1,
#  'Michel Foucault': 1,
#  'Michel Onfray': 1,
#  'Mihailo Markovi\xc4\x87': 3,
#  'Mikelis Avlichos': 1,
#  'Mikhail Bakunin': 1,
#  'Mohandas Gandhi': 8,
#  'Mohandas Karamchand Gandhi': 8,
#  'Moj\xc5\xbcesz Presburger': 4,
#  'Monarchomachs': 2,
#  'Montesquieu': 5,
#  'Moritz Schlick': 4,
#  'Mortimer Adler': 4,
#  'Moses': 2,
#  'Moses Sch\xc3\xb6nfinkel': 4,
#  'Moshe Chaim Luzzatto': 2,
#  'Mozi': 7,
#  'Muhammad Asad': 8,
#  'Muhammad Iqbal': 8,
#  'Murray Bookchin': 1,
#  'Murray Rothbard': 6,
#  'Nader El-Bizri': 1,
#  'Nancy Cartwright (philosopher)': 4,
#  'Nassim Nicholas Taleb': 2,
#  'Nathan Salmon': 4,
#  'Nelson Goodman': 4,
#  'Nestor Makhno': 8,
#  'Newton da Costa': 4,
#  'Niccol\xc3\xb2 Machiavelli': 2,
#  'Nick Bostrom': 4,
#  'Nicolai A. Vasiliev': 8,
#  'Nicolai Hartmann': 1,
#  'Nicolas Bourbaki': 4,
#  'Nicolas Malebranche': 2,
#  'Niklas Luhmann': 1,
#  'Noam Chomsky': 4,
#  'Norbert Bolz': 1,
#  'Norman Daniels': 5,
#  'Norman Malcolm': 3,
#  'Nosson Tzvi Finkel (Slabodka)': 2,
#  'Nuel Belnap': 9,
#  'Octave Mirbeau': 0,
#  'Oliver Wendell Holmes, Jr.': 8,
#  "Onora O'Neill, Baroness O'Neill of Bengarve": 3,
#  'Oscar Wilde': 8,
#  'Otto Casmann': 2,
#  'Otto Weininger': 3,
#  'P. F. Strawson': 4,
#  'Paolo Virno': 1,
#  'Paolo da Pergola': 2,
#  'Parmenides': 2,
#  'Paul Benacerraf': 4,
#  'Paul Bernays': 4,
#  'Paul Cohen (mathematician)': 4,
#  'Paul Grice': 4,
#  'Paul Hawken': 3,
#  'Paul Janet': 0,
#  'Paul Lorenzen': 4,
#  'Paul R. Patton': 1,
#  'Paul Tillich': 1,
#  'Paul Virilio': 1,
#  'Paul of Venice': 2,
#  'Pekka Himanen': 4,
#  'Penelope Maddy': 4,
#  'Per Bauhn': 1,
#  'Per Martin-L\xc3\xb6f': 4,
#  'Peter Abelard': 2,
#  'Peter B. Andrews (mathematician)': 4,
#  'Peter Geach': 3,
#  'Peter Glassen': 3,
#  'Peter Goldie': 3,
#  'Peter Kivy': 5,
#  'Peter Kropotkin': 1,
#  'Peter Lamborn Wilson': 1,
#  'Peter Ludlow': 4,
#  'Peter Medawar': 2,
#  'Peter Railton': 3,
#  'Peter Singer': 3,
#  'Peter Sloterdijk': 1,
#  'Peter Unger': 3,
#  'Peter of Spain (author)': 4,
#  'Peter van Inwagen': 3,
#  'Petrus Ramus': 2,
#  'Phaleas of Chalcedon': 2,
#  'Philip Doddridge': 5,
#  'Philip Jourdain': 4,
#  'Philip Pettit': 9,
#  'Philip Wicksteed': 6,
#  'Philippa Foot': 3,
#  'Philo': 2,
#  'Philo the Dialectician': 2,
#  'Piergiorgio Odifreddi': 4,
#  'Pierre Ab\xc3\xa9lard': 2,
#  'Pierre Bourdieu': 1,
#  'Pierre Teilhard de Chardin': 2,
#  'Plato': 2,
#  'Plotinus': 2,
#  'Polybius': 2,
#  'Porphyry (philosopher)': 2,
#  'Prodicus': 2,
#  'Protagoras': 2,
#  'Pythagoras': 2,
#  'Quintilian': 2,
#  'R. G. Collingwood': 1,
#  'R. M. Hare': 3,
#  'Ralf Dahrendorf': 1,
#  'Ralph Strode': 2,
#  'Ralph Waldo Emerson': 8,
#  'Ramon Llull': 2,
#  'Raphael M. Robinson': 4,
#  'Raya Dunayevskaya': 1,
#  'Raymond Frey': 3,
#  'Raymond Geuss': 1,
#  'Raymond Smullyan': 4,
#  'Ra\xc3\xbal Prebisch': 1,
#  'Reinhold Niebuhr': 8,
#  'Ren\xc3\xa9 Descartes': 2,
#  'Ren\xc3\xa9 Girard': 1,
#  'Reuben Louis Goodstein': 10,
#  'Richard Jeffrey': 4,
#  'Richard Kilvington': 2,
#  'Richard M. Weaver': 6,
#  'Richard Milton Martin': 4,
#  'Richard Montague': 4,
#  'Richard Price': 5,
#  'Richard Rorty': 1,
#  'Richard Routley': 9,
#  'Richard Shusterman': 1,
#  'Richard Swineshead': 2,
#  'Richard Sylvan': 9,
#  'Richard Whately': 5,
#  'Richard Wollheim': 3,
#  'Right Hegelians': 1,
#  'Robert Audi': 3,
#  'Robert K. Merton': 1,
#  'Robert Kilwardby': 2,
#  'Robert Lawson Vaught': 4,
#  'Robert M. Solovay': 4,
#  'Robert Merrihew Adams': 6,
#  'Robert Nozick': 6,
#  'Robert P. George': 3,
#  'Robert Paul Wolff': 4,
#  'Robert Stalnaker': 4,
#  'Roberto Esposito': 1,
#  'Roberto Mangabeira Unger': 8,
#  'Robin Gandy': 4,
#  'Roderick Long': 6,
#  'Rodolphus Agricola': 2,
#  'Roger Crisp': 3,
#  'Roger Scruton': 1,
#  'Roland Barthes': 1,
#  'Ronald Dworkin': 3,
#  'Rosa Luxemburg': 1,
#  'Rosalind Hursthouse': 3,
#  'Rudolf Arnheim': 1,
#  'Rudolf Carnap': 4,
#  'Rudolf Christoph Eucken': 2,
#  'Rudolf Steiner': 0,
#  'Ruqaiya Hasan': 1,
#  'Russell Kirk': 6,
#  'Ruth Barcan Marcus': 4,
#  'Ruth Benedict': 0,
#  'S. Barry Cooper': 4,
#  'Saharon Shelah': 4,
#  'Samuel Bailey': 5,
#  'Samuel Edward Konkin III': 6,
#  'Samuel Scheffler': 3,
#  'Sandra Harding': 11,
#  'Saul Kripke': 4,
#  'Sedulius Scottus': 2,
#  'Serge Moscovici': 2,
#  'Seyyed Hossein Nasr': 2,
#  'Shadworth Hodgson': 8,
#  'Shelly Kagan': 3,
#  'Sherrilyn Roush': 6,
#  'Simon Critchley': 1,
#  'Simone Weil': 1,
#  'Simone de Beauvoir': 1,
#  'Simplicius of Cilicia': 2,
#  'Slavoj \xc5\xbdi\xc5\xbeek': 1,
#  'Socrates': 2,
#  'Sol Garfunkel': 4,
#  'Solomon Feferman': 4,
#  'Sri Aurobindo': 8,
#  'Stanis\xc5\x82aw Ja\xc5\x9bkowski': 4,
#  'Stanis\xc5\x82aw Le\xc5\x9bniewski': 0,
#  'Stanley Cavell': 3,
#  'Stanley Hauerwas': 8,
#  'Stephen Cole Kleene': 4,
#  'Stewart Shapiro': 4,
#  'Stobaeus': 2,
#  'Sun Tzu': 1,
#  'Sun Yat-sen': 1,
#  'Susan Haack': 2,
#  'Susan Wolf': 3,
#  'Susanna Schellenberg': 4,
#  'Susanna Siegel': 4,
#  'Susanne Langer': 8,
#  'Swami Vivekananda': 8,
#  'S\xc3\xb8ren Kierkegaard': 1,
#  'T. M. Scanlon': 3,
#  'Tadeusz Cze\xc5\xbcowski': 0,
#  'Tadeusz Kotarbi\xc5\x84ski': 0,
#  'Takis Fotopoulos': 1,
#  'Talcott Parsons': 1,
#  'Tara Smith (philosopher)': 6,
#  'Terence McKenna': 2,
#  'Terence Parsons': 4,
#  'Theodor W. Adorno': 1,
#  'Theodor Zwinger': 2,
#  'Theodore Sider': 4,
#  'Theodore Slaman': 4,
#  'Theophrastus': 2,
#  'Thomas Aquinas': 2,
#  'Thomas Berry': 2,
#  'Thomas Bradwardine': 2,
#  'Thomas Henry Huxley': 5,
#  'Thomas Hill Green': 0,
#  'Thomas Hobbes': 5,
#  'Thomas Nagel': 3,
#  'Thomas Reid': 5,
#  'Thoralf Skolem': 4,
#  'Thucydides': 2,
#  'Th\xc3\xa9odore Simon Jouffroy': 5,
#  'Todd May': 1,
#  'Tom Beauchamp': 5,
#  'Tom Regan': 3,
#  'Tony Honor\xc3\xa9': 3,
#  'Trenton Merricks': 3,
#  'Tudor Vianu': 1,
#  'Umberto Eco': 2,
#  'Valentin Feldman': 1,
#  'Vernon Lee': 8,
#  'Victor Basch': 1,
#  'Victor Cousin': 5,
#  'Victor Gollancz': 3,
#  'Vilfredo Pareto': 1,
#  'Vissarion Belinsky': 3,
#  'Voltaire': 5,
#  'Voltairine de Cleyre': 8,
#  'W. D. Ross': 3,
#  'W. Hugh Woodin': 4,
#  'W.V.O. Quine': 3,
#  'Walter Benjamin': 1,
#  'Walter Burley': 2,
#  'Walter Pater': 8,
#  'Walter Pitts': 4,
#  'Walter Terence Stace': 8,
#  'Warren Buffett': 6,
#  'Wesley J. Smith': 3,
#  'Wilhelm Ackermann': 4,
#  'Wilhelm Dilthey': 1,
#  'Willard V. O. Quine': 4,
#  'Willard Van Orman Quine': 4,
#  'William Alston': 5,
#  'William Alvin Howard': 4,
#  'William Ernest Johnson': 3,
#  'William George Ward': 5,
#  'William James': 8,
#  'William Lloyd Garrison': 6,
#  'William Lycan': 4,
#  'William Paley': 5,
#  'William Stanley Jevons': 4,
#  'William Sweet': 8,
#  'William Whewell': 5,
#  'William Wollaston': 5,
#  'William of Ockham': 2,
#  'William of Sherwood': 4,
#  'Wolfgang Smith': 2,
#  'Xavier Zubiri': 2,
#  'Xenocrates': 2,
#  'Xenophanes': 2,
#  'Xun Kuang': 7,
#  'Xun Zi': 7,
#  'Yamazaki Ansai': 7,
#  'Yehoshua Bar-Hillel': 4,
#  'Yiannis N. Moschovakis': 4,
#  'Young Hegelians': 1,
#  'Yuri Matiyasevich': 4,
#  'Zeno of Elea': 2,
#  'Zhuang Zhou': 7,
#  '\xc3\x89tienne de La Bo\xc3\xa9tie': 6,
#  '\xc3\x9eorsteinn Gylfason': 3,
#  '\xc4\xb0oanna Ku\xc3\xa7uradi': 1}
